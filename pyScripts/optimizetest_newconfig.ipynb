# %%
# %load_ext autoreload
# %autoreload 2
from optimize_psi import *
from cluster_g_logit_init_acceptpsi import *
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import rpy2.robjects as robjects
import numpy as np
import os as os
from rpy2.robjects import numpy2ri
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt



# Specify the path to your data files
data_path = "/Users/sarahurbut/tensornoulli_ehr_new/data"

# Activate automatic conversion between R and NumPy arrays
numpy2ri.activate()# Load data saved as .rds files
Y = np.array(robjects.r['readRDS'](os.path.join(data_path, 'Y.rds')))
E = np.array(robjects.r['readRDS'](os.path.join(data_path, 'event_for_aladynoulli.rds')))
G = np.array(robjects.r['readRDS'](os.path.join(data_path, 'prs.rds')))

E = E.astype(int)

# G should be float64
G = G.astype(float)
G.shape
G = G.T
print("G shape after transposition:", G.shape)

# Convert to PyTorch tensors
Y_tensor = torch.FloatTensor(Y)
E_tensor = torch.FloatTensor(E)
G_tensor = torch.FloatTensor(G)

# Get dimensions
N, D, T = Y_tensor.shape
P = G_tensor.shape[1]
T = int(E_tensor.max() + 1)  # 0-indexed time
K = 10  # number of topics

# Print shapes to verify
print("Tensor shapes:")
print(f"Y: {Y_tensor.shape}")  # [N, D]
print(f"E: {E_tensor.shape}")  # [N, D]
print(f"G: {G_tensor.shape}")  # [N, P]
print(f"Time range: 0 to {T-1}")
print(T)
print(K)


import rpy2.robjects as robjects
import pandas as pd
from rpy2.robjects import pandas2ri
pandas2ri.activate()

# Load the metadata from R
disease_names = pd.DataFrame(robjects.r['readRDS']('/Users/sarahurbut/Dropbox (Personal)/disease_names.rds'))
prs_names = pd.DataFrame(robjects.r['readRDS']('/Users/sarahurbut/Dropbox (Personal)/prs_names.rds'))
disease_names_list = disease_names[0].tolist()
# Out:
# G shape after transposition: (9661, 36)
# Tensor shapes:
# Y: torch.Size([9661, 348, 51])
# E: torch.Size([9661, 348])
# G: torch.Size([9661, 36])
# Time range: 0 to 50
# 51
# 10

# %%
prevalence_t=compute_smoothed_prevalence(Y=Y,window_size=5)
K=20

# %%
        # Convert Y to tensor if it's not already
Y_tensor = torch.tensor(Y) if isinstance(Y, np.ndarray) else Y

# %%
psi_config = {'in_cluster': 1.5, 'out_cluster': -1.5, 'noise_in': 0.1, 'noise_out': 0.01}

# %%
# choosing the best

model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(N,D,T,K,P,G_tensor,Y=Y, prevalence_t=prevalence_t,disease_names=disease_names_list)
model.initialize_params(psi_config=psi_config)
# Out:
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# Lambda kernel condition number: 45200668.00
# Phi kernel condition number: 89734320.00
#
# Cluster Sizes:
# Cluster 0: 27 diseases
# Cluster 1: 32 diseases
# Cluster 2: 12 diseases
# Cluster 3: 9 diseases
# Cluster 4: 19 diseases
# Cluster 5: 74 diseases
# Cluster 6: 31 diseases
# Cluster 7: 12 diseases
# Cluster 8: 10 diseases
# Cluster 9: 8 diseases
# Cluster 10: 5 diseases
# Cluster 11: 10 diseases
# Cluster 12: 6 diseases
# Cluster 13: 12 diseases
# Cluster 14: 14 diseases
# Cluster 15: 9 diseases
# Cluster 16: 23 diseases
# Cluster 17: 5 diseases
# Cluster 18: 18 diseases
# Cluster 19: 12 diseases
# Initialization complete!
#
# Using psi configuration
# Initialization complete!

# %%
model.plot_initial_params()
model.visualize_initialization()
model.psi
# Out:
# Cluster membership for sampled diseases:
# Disease 78: Cluster 2
# Disease 62: Cluster 1
# Disease 177: Cluster 9
# Disease 333: Cluster 6
# Disease 119: Cluster 7
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi.py:617: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()
# Parameter containing:
# tensor([[-1.4829, -1.5017, -1.4809,  ..., -1.4983, -1.5111,  1.3610],
#         [-1.4877, -1.5095,  1.4098,  ..., -1.5191, -1.4969, -1.4897],
#         [-1.5092, -1.5040, -1.4803,  ..., -1.5052, -1.4944, -1.4945],
#         ...,
#         [-1.4824, -1.5086, -1.5017,  ..., -1.4995, -1.4927, -1.5036],
#         [-1.5155,  1.4073, -1.4866,  ..., -1.4821, -1.5007, -1.4957],
#         [ 1.5171, -1.5122, -1.5013,  ..., -1.4952, -1.5072, -1.4942]],
#        requires_grad=True)

# %%
history = model.fit(E_tensor, num_epochs=1000, learning_rate=1e-4, lambda_reg=1e-2)
# Out:
# Starting training...
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi.py:196: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   event_times_tensor = torch.tensor(event_times, dtype=torch.long)
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 0
# Loss: 1104.4407
# Psi gradient stats:
# Mean: 5.0804e-05
# Std:  4.7103e-03
# Max:  1.6734e-02
# Min:  -1.6462e-02
# Average psi change: 1.0002e-04
# Epoch 0, Loss: 1104.4407, Gradients - Lambda: 5.596e-01, Phi: 1.348e+01, Gamma: 6.145e-02, Psi: 1.673e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 1
# Loss: 840.1216
# Psi gradient stats:
# Mean: 5.2015e-05
# Std:  4.6979e-03
# Max:  1.6643e-02
# Min:  -1.6335e-02
# Average psi change: 9.9227e-05
# Epoch 1, Loss: 840.1216, Gradients - Lambda: 5.044e-01, Phi: 1.238e+01, Gamma: 5.981e-02, Psi: 1.664e-02
#
# Estimated total training time: 885.1 minutes
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 2
# Loss: 651.6096
# Psi gradient stats:
# Mean: 5.3314e-05
# Std:  4.6856e-03
# Max:  1.6557e-02
# Min:  -1.6201e-02
# Average psi change: 9.8869e-05
# Epoch 2, Loss: 651.6096, Gradients - Lambda: 4.735e-01, Phi: 1.126e+01, Gamma: 5.807e-02, Psi: 1.656e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 3
# Loss: 522.9117
# Psi gradient stats:
# Mean: 5.4582e-05
# Std:  4.6728e-03
# Max:  1.6438e-02
# Min:  -1.6082e-02
# Average psi change: 9.8650e-05
# Epoch 3, Loss: 522.9117, Gradients - Lambda: 4.441e-01, Phi: 1.016e+01, Gamma: 5.623e-02, Psi: 1.644e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 4
# Loss: 437.8251
# Psi gradient stats:
# Mean: 5.5823e-05
# Std:  4.6589e-03
# Max:  1.6318e-02
# Min:  -1.5978e-02
# Average psi change: 9.8386e-05
# Epoch 4, Loss: 437.8251, Gradients - Lambda: 4.134e-01, Phi: 9.106e+00, Gamma: 5.434e-02, Psi: 1.632e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 5
# Loss: 383.0874
# Psi gradient stats:
# Mean: 5.6914e-05
# Std:  4.6442e-03
# Max:  1.6385e-02
# Min:  -1.5878e-02
# Average psi change: 9.8140e-05
# Epoch 5, Loss: 383.0874, Gradients - Lambda: 3.800e-01, Phi: 8.163e+00, Gamma: 5.246e-02, Psi: 1.638e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 6
# Loss: 348.8926
# Psi gradient stats:
# Mean: 5.7878e-05
# Std:  4.6288e-03
# Max:  1.6438e-02
# Min:  -1.5777e-02
# Average psi change: 9.7847e-05
# Epoch 6, Loss: 348.8926, Gradients - Lambda: 3.450e-01, Phi: 7.421e+00, Gamma: 5.067e-02, Psi: 1.644e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 7
# Loss: 328.0755
# Psi gradient stats:
# Mean: 5.8771e-05
# Std:  4.6132e-03
# Max:  1.6482e-02
# Min:  -1.5765e-02
# Average psi change: 9.7567e-05
# Epoch 7, Loss: 328.0755, Gradients - Lambda: 3.090e-01, Phi: 6.788e+00, Gamma: 5.004e-02, Psi: 1.648e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 8
# Loss: 315.4532
# Psi gradient stats:
# Mean: 5.9704e-05
# Std:  4.5976e-03
# Max:  1.6519e-02
# Min:  -1.5833e-02
# Average psi change: 9.7316e-05
# Epoch 8, Loss: 315.4532, Gradients - Lambda: 2.728e-01, Phi: 6.191e+00, Gamma: 4.954e-02, Psi: 1.652e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 9
# Loss: 307.4630
# Psi gradient stats:
# Mean: 6.0735e-05
# Std:  4.5824e-03
# Max:  1.6546e-02
# Min:  -1.5901e-02
# Average psi change: 9.7092e-05
# Epoch 9, Loss: 307.4630, Gradients - Lambda: 2.371e-01, Phi: 5.554e+00, Gamma: 4.906e-02, Psi: 1.655e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 10
# Loss: 301.8622
# Psi gradient stats:
# Mean: 6.1940e-05
# Std:  4.5679e-03
# Max:  1.6562e-02
# Min:  -1.5960e-02
# Average psi change: 9.6840e-05
# Epoch 10, Loss: 301.8622, Gradients - Lambda: 2.183e-01, Phi: 4.889e+00, Gamma: 4.862e-02, Psi: 1.656e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 11
# Loss: 297.3556
# Psi gradient stats:
# Mean: 6.3288e-05
# Std:  4.5542e-03
# Max:  1.6571e-02
# Min:  -1.6006e-02
# Average psi change: 9.6546e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 12
# Loss: 293.2445
# Psi gradient stats:
# Mean: 6.4713e-05
# Std:  4.5414e-03
# Max:  1.6567e-02
# Min:  -1.6037e-02
# Average psi change: 9.6284e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 13
# Loss: 289.2123
# Psi gradient stats:
# Mean: 6.6157e-05
# Std:  4.5297e-03
# Max:  1.6554e-02
# Min:  -1.6056e-02
# Average psi change: 9.6060e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 14
# Loss: 285.1858
# Psi gradient stats:
# Mean: 6.7621e-05
# Std:  4.5191e-03
# Max:  1.6530e-02
# Min:  -1.6065e-02
# Average psi change: 9.5837e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 15
# Loss: 281.2427
# Psi gradient stats:
# Mean: 6.9093e-05
# Std:  4.5099e-03
# Max:  1.6496e-02
# Min:  -1.6074e-02
# Average psi change: 9.5619e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 16
# Loss: 277.4990
# Psi gradient stats:
# Mean: 7.0555e-05
# Std:  4.5019e-03
# Max:  1.6454e-02
# Min:  -1.6089e-02
# Average psi change: 9.5454e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 17
# Loss: 274.0576
# Psi gradient stats:
# Mean: 7.1931e-05
# Std:  4.4953e-03
# Max:  1.6407e-02
# Min:  -1.6114e-02
# Average psi change: 9.5327e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 18
# Loss: 270.9778
# Psi gradient stats:
# Mean: 7.3155e-05
# Std:  4.4899e-03
# Max:  1.6361e-02
# Min:  -1.6146e-02
# Average psi change: 9.5228e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 19
# Loss: 268.2900
# Psi gradient stats:
# Mean: 7.4134e-05
# Std:  4.4857e-03
# Max:  1.6320e-02
# Min:  -1.6179e-02
# Average psi change: 9.5150e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 20
# Loss: 265.9864
# Psi gradient stats:
# Mean: 7.4898e-05
# Std:  4.4823e-03
# Max:  1.6283e-02
# Min:  -1.6206e-02
# Average psi change: 9.5112e-05
# Epoch 20, Loss: 265.9864, Gradients - Lambda: 7.268e-02, Phi: 1.667e+00, Gamma: 4.464e-02, Psi: 1.628e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 21
# Loss: 264.0373
# Psi gradient stats:
# Mean: 7.5560e-05
# Std:  4.4797e-03
# Max:  1.6262e-02
# Min:  -1.6227e-02
# Average psi change: 9.5089e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 22
# Loss: 262.3876
# Psi gradient stats:
# Mean: 7.6187e-05
# Std:  4.4776e-03
# Max:  1.6282e-02
# Min:  -1.6245e-02
# Average psi change: 9.5065e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 23
# Loss: 260.9805
# Psi gradient stats:
# Mean: 7.6824e-05
# Std:  4.4758e-03
# Max:  1.6307e-02
# Min:  -1.6269e-02
# Average psi change: 9.5030e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 24
# Loss: 259.7668
# Psi gradient stats:
# Mean: 7.7384e-05
# Std:  4.4742e-03
# Max:  1.6336e-02
# Min:  -1.6299e-02
# Average psi change: 9.4996e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 25
# Loss: 258.7027
# Psi gradient stats:
# Mean: 7.7794e-05
# Std:  4.4726e-03
# Max:  1.6368e-02
# Min:  -1.6334e-02
# Average psi change: 9.4962e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 26
# Loss: 257.7496
# Psi gradient stats:
# Mean: 7.8018e-05
# Std:  4.4711e-03
# Max:  1.6400e-02
# Min:  -1.6365e-02
# Average psi change: 9.4920e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 27
# Loss: 256.8819
# Psi gradient stats:
# Mean: 7.8115e-05
# Std:  4.4697e-03
# Max:  1.6425e-02
# Min:  -1.6385e-02
# Average psi change: 9.4885e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 28
# Loss: 256.0842
# Psi gradient stats:
# Mean: 7.8169e-05
# Std:  4.4683e-03
# Max:  1.6441e-02
# Min:  -1.6393e-02
# Average psi change: 9.4853e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 29
# Loss: 255.3467
# Psi gradient stats:
# Mean: 7.8227e-05
# Std:  4.4670e-03
# Max:  1.6445e-02
# Min:  -1.6392e-02
# Average psi change: 9.4811e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 30
# Loss: 254.6586
# Psi gradient stats:
# Mean: 7.8269e-05
# Std:  4.4656e-03
# Max:  1.6439e-02
# Min:  -1.6391e-02
# Average psi change: 9.4763e-05
# Epoch 30, Loss: 254.6586, Gradients - Lambda: 3.855e-02, Phi: 9.005e-01, Gamma: 3.854e-02, Psi: 1.644e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 31
# Loss: 254.0149
# Psi gradient stats:
# Mean: 7.8213e-05
# Std:  4.4640e-03
# Max:  1.6421e-02
# Min:  -1.6391e-02
# Average psi change: 9.4701e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 32
# Loss: 253.4101
# Psi gradient stats:
# Mean: 7.8051e-05
# Std:  4.4624e-03
# Max:  1.6397e-02
# Min:  -1.6394e-02
# Average psi change: 9.4625e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 33
# Loss: 252.8474
# Psi gradient stats:
# Mean: 7.7822e-05
# Std:  4.4606e-03
# Max:  1.6372e-02
# Min:  -1.6395e-02
# Average psi change: 9.4539e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 34
# Loss: 252.3184
# Psi gradient stats:
# Mean: 7.7628e-05
# Std:  4.4589e-03
# Max:  1.6352e-02
# Min:  -1.6391e-02
# Average psi change: 9.4448e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 35
# Loss: 251.8185
# Psi gradient stats:
# Mean: 7.7515e-05
# Std:  4.4572e-03
# Max:  1.6337e-02
# Min:  -1.6384e-02
# Average psi change: 9.4355e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 36
# Loss: 251.3444
# Psi gradient stats:
# Mean: 7.7518e-05
# Std:  4.4555e-03
# Max:  1.6329e-02
# Min:  -1.6374e-02
# Average psi change: 9.4259e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 37
# Loss: 250.8950
# Psi gradient stats:
# Mean: 7.7517e-05
# Std:  4.4538e-03
# Max:  1.6323e-02
# Min:  -1.6367e-02
# Average psi change: 9.4159e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 38
# Loss: 250.4708
# Psi gradient stats:
# Mean: 7.7466e-05
# Std:  4.4522e-03
# Max:  1.6316e-02
# Min:  -1.6364e-02
# Average psi change: 9.4053e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 39
# Loss: 250.0642
# Psi gradient stats:
# Mean: 7.7333e-05
# Std:  4.4506e-03
# Max:  1.6306e-02
# Min:  -1.6362e-02
# Average psi change: 9.3946e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 40
# Loss: 249.6748
# Psi gradient stats:
# Mean: 7.7175e-05
# Std:  4.4491e-03
# Max:  1.6296e-02
# Min:  -1.6363e-02
# Average psi change: 9.3836e-05
# Epoch 40, Loss: 249.6748, Gradients - Lambda: 2.834e-02, Phi: 5.721e-01, Gamma: 3.456e-02, Psi: 1.636e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 41
# Loss: 249.3011
# Psi gradient stats:
# Mean: 7.7077e-05
# Std:  4.4475e-03
# Max:  1.6288e-02
# Min:  -1.6361e-02
# Average psi change: 9.3730e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 42
# Loss: 248.9424
# Psi gradient stats:
# Mean: 7.7062e-05
# Std:  4.4459e-03
# Max:  1.6286e-02
# Min:  -1.6358e-02
# Average psi change: 9.3629e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 43
# Loss: 248.5972
# Psi gradient stats:
# Mean: 7.7067e-05
# Std:  4.4443e-03
# Max:  1.6288e-02
# Min:  -1.6355e-02
# Average psi change: 9.3535e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 44
# Loss: 248.2632
# Psi gradient stats:
# Mean: 7.7008e-05
# Std:  4.4426e-03
# Max:  1.6292e-02
# Min:  -1.6352e-02
# Average psi change: 9.3447e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 45
# Loss: 247.9404
# Psi gradient stats:
# Mean: 7.6855e-05
# Std:  4.4409e-03
# Max:  1.6293e-02
# Min:  -1.6350e-02
# Average psi change: 9.3365e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 46
# Loss: 247.6283
# Psi gradient stats:
# Mean: 7.6671e-05
# Std:  4.4393e-03
# Max:  1.6290e-02
# Min:  -1.6347e-02
# Average psi change: 9.3288e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 47
# Loss: 247.3272
# Psi gradient stats:
# Mean: 7.6528e-05
# Std:  4.4377e-03
# Max:  1.6284e-02
# Min:  -1.6344e-02
# Average psi change: 9.3216e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 48
# Loss: 247.0333
# Psi gradient stats:
# Mean: 7.6514e-05
# Std:  4.4361e-03
# Max:  1.6280e-02
# Min:  -1.6341e-02
# Average psi change: 9.3153e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 49
# Loss: 246.7490
# Psi gradient stats:
# Mean: 7.6549e-05
# Std:  4.4344e-03
# Max:  1.6279e-02
# Min:  -1.6338e-02
# Average psi change: 9.3095e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 50
# Loss: 246.4721
# Psi gradient stats:
# Mean: 7.6553e-05
# Std:  4.4327e-03
# Max:  1.6282e-02
# Min:  -1.6334e-02
# Average psi change: 9.3041e-05
# Epoch 50, Loss: 246.4721, Gradients - Lambda: 2.948e-02, Phi: 4.676e-01, Gamma: 3.190e-02, Psi: 1.633e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 51
# Loss: 246.2008
# Psi gradient stats:
# Mean: 7.6479e-05
# Std:  4.4311e-03
# Max:  1.6284e-02
# Min:  -1.6330e-02
# Average psi change: 9.2991e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 52
# Loss: 245.9383
# Psi gradient stats:
# Mean: 7.6370e-05
# Std:  4.4294e-03
# Max:  1.6281e-02
# Min:  -1.6324e-02
# Average psi change: 9.2940e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 53
# Loss: 245.6812
# Psi gradient stats:
# Mean: 7.6338e-05
# Std:  4.4278e-03
# Max:  1.6273e-02
# Min:  -1.6316e-02
# Average psi change: 9.2894e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 54
# Loss: 245.4306
# Psi gradient stats:
# Mean: 7.6402e-05
# Std:  4.4261e-03
# Max:  1.6264e-02
# Min:  -1.6310e-02
# Average psi change: 9.2854e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 55
# Loss: 245.1841
# Psi gradient stats:
# Mean: 7.6507e-05
# Std:  4.4244e-03
# Max:  1.6258e-02
# Min:  -1.6307e-02
# Average psi change: 9.2819e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 56
# Loss: 244.9456
# Psi gradient stats:
# Mean: 7.6551e-05
# Std:  4.4227e-03
# Max:  1.6259e-02
# Min:  -1.6307e-02
# Average psi change: 9.2786e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 57
# Loss: 244.7119
# Psi gradient stats:
# Mean: 7.6486e-05
# Std:  4.4210e-03
# Max:  1.6263e-02
# Min:  -1.6311e-02
# Average psi change: 9.2753e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 58
# Loss: 244.4803
# Psi gradient stats:
# Mean: 7.6361e-05
# Std:  4.4194e-03
# Max:  1.6266e-02
# Min:  -1.6314e-02
# Average psi change: 9.2721e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 59
# Loss: 244.2567
# Psi gradient stats:
# Mean: 7.6271e-05
# Std:  4.4178e-03
# Max:  1.6263e-02
# Min:  -1.6314e-02
# Average psi change: 9.2688e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 60
# Loss: 244.0367
# Psi gradient stats:
# Mean: 7.6260e-05
# Std:  4.4161e-03
# Max:  1.6254e-02
# Min:  -1.6311e-02
# Average psi change: 9.2658e-05
# Epoch 60, Loss: 244.0367, Gradients - Lambda: 3.167e-02, Phi: 5.447e-01, Gamma: 2.967e-02, Psi: 1.631e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 61
# Loss: 243.8188
# Psi gradient stats:
# Mean: 7.6294e-05
# Std:  4.4144e-03
# Max:  1.6243e-02
# Min:  -1.6305e-02
# Average psi change: 9.2632e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 62
# Loss: 243.6074
# Psi gradient stats:
# Mean: 7.6307e-05
# Std:  4.4126e-03
# Max:  1.6237e-02
# Min:  -1.6301e-02
# Average psi change: 9.2606e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 63
# Loss: 243.4011
# Psi gradient stats:
# Mean: 7.6250e-05
# Std:  4.4109e-03
# Max:  1.6237e-02
# Min:  -1.6299e-02
# Average psi change: 9.2581e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 64
# Loss: 243.1973
# Psi gradient stats:
# Mean: 7.6164e-05
# Std:  4.4092e-03
# Max:  1.6240e-02
# Min:  -1.6300e-02
# Average psi change: 9.2555e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 65
# Loss: 242.9974
# Psi gradient stats:
# Mean: 7.6098e-05
# Std:  4.4076e-03
# Max:  1.6239e-02
# Min:  -1.6300e-02
# Average psi change: 9.2529e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 66
# Loss: 242.8016
# Psi gradient stats:
# Mean: 7.6092e-05
# Std:  4.4060e-03
# Max:  1.6234e-02
# Min:  -1.6299e-02
# Average psi change: 9.2502e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 67
# Loss: 242.6092
# Psi gradient stats:
# Mean: 7.6110e-05
# Std:  4.4043e-03
# Max:  1.6226e-02
# Min:  -1.6295e-02
# Average psi change: 9.2480e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 68
# Loss: 242.4198
# Psi gradient stats:
# Mean: 7.6071e-05
# Std:  4.4025e-03
# Max:  1.6220e-02
# Min:  -1.6292e-02
# Average psi change: 9.2459e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 69
# Loss: 242.2341
# Psi gradient stats:
# Mean: 7.5970e-05
# Std:  4.4008e-03
# Max:  1.6220e-02
# Min:  -1.6291e-02
# Average psi change: 9.2435e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 70
# Loss: 242.0518
# Psi gradient stats:
# Mean: 7.5878e-05
# Std:  4.3991e-03
# Max:  1.6223e-02
# Min:  -1.6292e-02
# Average psi change: 9.2409e-05
# Epoch 70, Loss: 242.0518, Gradients - Lambda: 3.587e-02, Phi: 6.176e-01, Gamma: 2.749e-02, Psi: 1.629e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 71
# Loss: 241.8721
# Psi gradient stats:
# Mean: 7.5848e-05
# Std:  4.3974e-03
# Max:  1.6223e-02
# Min:  -1.6293e-02
# Average psi change: 9.2383e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 72
# Loss: 241.6952
# Psi gradient stats:
# Mean: 7.5883e-05
# Std:  4.3958e-03
# Max:  1.6218e-02
# Min:  -1.6291e-02
# Average psi change: 9.2357e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 73
# Loss: 241.5235
# Psi gradient stats:
# Mean: 7.5909e-05
# Std:  4.3941e-03
# Max:  1.6210e-02
# Min:  -1.6288e-02
# Average psi change: 9.2334e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 74
# Loss: 241.3520
# Psi gradient stats:
# Mean: 7.5869e-05
# Std:  4.3923e-03
# Max:  1.6202e-02
# Min:  -1.6283e-02
# Average psi change: 9.2311e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 75
# Loss: 241.1851
# Psi gradient stats:
# Mean: 7.5751e-05
# Std:  4.3906e-03
# Max:  1.6200e-02
# Min:  -1.6279e-02
# Average psi change: 9.2285e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 76
# Loss: 241.0222
# Psi gradient stats:
# Mean: 7.5645e-05
# Std:  4.3888e-03
# Max:  1.6201e-02
# Min:  -1.6280e-02
# Average psi change: 9.2257e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 77
# Loss: 240.8600
# Psi gradient stats:
# Mean: 7.5616e-05
# Std:  4.3871e-03
# Max:  1.6202e-02
# Min:  -1.6281e-02
# Average psi change: 9.2228e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 78
# Loss: 240.6993
# Psi gradient stats:
# Mean: 7.5671e-05
# Std:  4.3855e-03
# Max:  1.6197e-02
# Min:  -1.6281e-02
# Average psi change: 9.2200e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 79
# Loss: 240.5475
# Psi gradient stats:
# Mean: 7.5734e-05
# Std:  4.3837e-03
# Max:  1.6188e-02
# Min:  -1.6277e-02
# Average psi change: 9.2176e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 80
# Loss: 240.3934
# Psi gradient stats:
# Mean: 7.5718e-05
# Std:  4.3820e-03
# Max:  1.6181e-02
# Min:  -1.6271e-02
# Average psi change: 9.2152e-05
# Epoch 80, Loss: 240.3934, Gradients - Lambda: 4.122e-02, Phi: 5.269e-01, Gamma: 2.549e-02, Psi: 1.627e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 81
# Loss: 240.2418
# Psi gradient stats:
# Mean: 7.5627e-05
# Std:  4.3803e-03
# Max:  1.6179e-02
# Min:  -1.6268e-02
# Average psi change: 9.2124e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 82
# Loss: 240.0972
# Psi gradient stats:
# Mean: 7.5505e-05
# Std:  4.3785e-03
# Max:  1.6180e-02
# Min:  -1.6268e-02
# Average psi change: 9.2092e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 83
# Loss: 239.9502
# Psi gradient stats:
# Mean: 7.5446e-05
# Std:  4.3768e-03
# Max:  1.6182e-02
# Min:  -1.6270e-02
# Average psi change: 9.2062e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 84
# Loss: 239.8079
# Psi gradient stats:
# Mean: 7.5458e-05
# Std:  4.3752e-03
# Max:  1.6179e-02
# Min:  -1.6271e-02
# Average psi change: 9.2035e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 85
# Loss: 239.6706
# Psi gradient stats:
# Mean: 7.5531e-05
# Std:  4.3734e-03
# Max:  1.6170e-02
# Min:  -1.6268e-02
# Average psi change: 9.2010e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 86
# Loss: 239.5312
# Psi gradient stats:
# Mean: 7.5558e-05
# Std:  4.3717e-03
# Max:  1.6160e-02
# Min:  -1.6262e-02
# Average psi change: 9.1982e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 87
# Loss: 239.3967
# Psi gradient stats:
# Mean: 7.5489e-05
# Std:  4.3699e-03
# Max:  1.6155e-02
# Min:  -1.6258e-02
# Average psi change: 9.1952e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 88
# Loss: 239.2664
# Psi gradient stats:
# Mean: 7.5357e-05
# Std:  4.3681e-03
# Max:  1.6157e-02
# Min:  -1.6257e-02
# Average psi change: 9.1920e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 89
# Loss: 239.1336
# Psi gradient stats:
# Mean: 7.5249e-05
# Std:  4.3665e-03
# Max:  1.6160e-02
# Min:  -1.6258e-02
# Average psi change: 9.1889e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 90
# Loss: 239.0074
# Psi gradient stats:
# Mean: 7.5238e-05
# Std:  4.3648e-03
# Max:  1.6158e-02
# Min:  -1.6258e-02
# Average psi change: 9.1864e-05
# Epoch 90, Loss: 239.0074, Gradients - Lambda: 4.520e-02, Phi: 6.060e-01, Gamma: 2.378e-02, Psi: 1.626e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 91
# Loss: 238.8822
# Psi gradient stats:
# Mean: 7.5312e-05
# Std:  4.3630e-03
# Max:  1.6151e-02
# Min:  -1.6255e-02
# Average psi change: 9.1842e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 92
# Loss: 238.7571
# Psi gradient stats:
# Mean: 7.5366e-05
# Std:  4.3612e-03
# Max:  1.6141e-02
# Min:  -1.6249e-02
# Average psi change: 9.1818e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 93
# Loss: 238.6395
# Psi gradient stats:
# Mean: 7.5312e-05
# Std:  4.3595e-03
# Max:  1.6137e-02
# Min:  -1.6245e-02
# Average psi change: 9.1786e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 94
# Loss: 238.5202
# Psi gradient stats:
# Mean: 7.5163e-05
# Std:  4.3578e-03
# Max:  1.6138e-02
# Min:  -1.6244e-02
# Average psi change: 9.1751e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 95
# Loss: 238.4010
# Psi gradient stats:
# Mean: 7.5042e-05
# Std:  4.3561e-03
# Max:  1.6141e-02
# Min:  -1.6245e-02
# Average psi change: 9.1719e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 96
# Loss: 238.2913
# Psi gradient stats:
# Mean: 7.5027e-05
# Std:  4.3544e-03
# Max:  1.6140e-02
# Min:  -1.6246e-02
# Average psi change: 9.1694e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 97
# Loss: 238.1774
# Psi gradient stats:
# Mean: 7.5122e-05
# Std:  4.3526e-03
# Max:  1.6131e-02
# Min:  -1.6243e-02
# Average psi change: 9.1672e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 98
# Loss: 238.0659
# Psi gradient stats:
# Mean: 7.5189e-05
# Std:  4.3508e-03
# Max:  1.6119e-02
# Min:  -1.6238e-02
# Average psi change: 9.1651e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 99
# Loss: 237.9609
# Psi gradient stats:
# Mean: 7.5130e-05
# Std:  4.3490e-03
# Max:  1.6112e-02
# Min:  -1.6233e-02
# Average psi change: 9.1623e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 100
# Loss: 237.8540
# Psi gradient stats:
# Mean: 7.4967e-05
# Std:  4.3473e-03
# Max:  1.6113e-02
# Min:  -1.6232e-02
# Average psi change: 9.1589e-05
# Epoch 100, Loss: 237.8540, Gradients - Lambda: 4.706e-02, Phi: 7.612e-01, Gamma: 2.205e-02, Psi: 1.623e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 101
# Loss: 237.7469
# Psi gradient stats:
# Mean: 7.4817e-05
# Std:  4.3456e-03
# Max:  1.6118e-02
# Min:  -1.6234e-02
# Average psi change: 9.1556e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 102
# Loss: 237.6472
# Psi gradient stats:
# Mean: 7.4806e-05
# Std:  4.3440e-03
# Max:  1.6119e-02
# Min:  -1.6235e-02
# Average psi change: 9.1525e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 103
# Loss: 237.5455
# Psi gradient stats:
# Mean: 7.4903e-05
# Std:  4.3422e-03
# Max:  1.6112e-02
# Min:  -1.6232e-02
# Average psi change: 9.1503e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 104
# Loss: 237.4452
# Psi gradient stats:
# Mean: 7.4980e-05
# Std:  4.3404e-03
# Max:  1.6101e-02
# Min:  -1.6226e-02
# Average psi change: 9.1484e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 105
# Loss: 237.3515
# Psi gradient stats:
# Mean: 7.4937e-05
# Std:  4.3386e-03
# Max:  1.6092e-02
# Min:  -1.6221e-02
# Average psi change: 9.1462e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 106
# Loss: 237.2556
# Psi gradient stats:
# Mean: 7.4757e-05
# Std:  4.3368e-03
# Max:  1.6091e-02
# Min:  -1.6220e-02
# Average psi change: 9.1432e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 107
# Loss: 237.1613
# Psi gradient stats:
# Mean: 7.4608e-05
# Std:  4.3351e-03
# Max:  1.6097e-02
# Min:  -1.6222e-02
# Average psi change: 9.1399e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 108
# Loss: 237.0699
# Psi gradient stats:
# Mean: 7.4584e-05
# Std:  4.3335e-03
# Max:  1.6099e-02
# Min:  -1.6223e-02
# Average psi change: 9.1365e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 109
# Loss: 236.9788
# Psi gradient stats:
# Mean: 7.4687e-05
# Std:  4.3318e-03
# Max:  1.6093e-02
# Min:  -1.6220e-02
# Average psi change: 9.1340e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 110
# Loss: 236.8900
# Psi gradient stats:
# Mean: 7.4785e-05
# Std:  4.3300e-03
# Max:  1.6081e-02
# Min:  -1.6214e-02
# Average psi change: 9.1319e-05
# Epoch 110, Loss: 236.8900, Gradients - Lambda: 4.620e-02, Phi: 7.247e-01, Gamma: 2.058e-02, Psi: 1.621e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 111
# Loss: 236.8019
# Psi gradient stats:
# Mean: 7.4751e-05
# Std:  4.3282e-03
# Max:  1.6070e-02
# Min:  -1.6208e-02
# Average psi change: 9.1299e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 112
# Loss: 236.7165
# Psi gradient stats:
# Mean: 7.4602e-05
# Std:  4.3264e-03
# Max:  1.6069e-02
# Min:  -1.6206e-02
# Average psi change: 9.1273e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 113
# Loss: 236.6324
# Psi gradient stats:
# Mean: 7.4461e-05
# Std:  4.3247e-03
# Max:  1.6074e-02
# Min:  -1.6209e-02
# Average psi change: 9.1242e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 114
# Loss: 236.5481
# Psi gradient stats:
# Mean: 7.4412e-05
# Std:  4.3230e-03
# Max:  1.6078e-02
# Min:  -1.6211e-02
# Average psi change: 9.1208e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 115
# Loss: 236.4648
# Psi gradient stats:
# Mean: 7.4477e-05
# Std:  4.3214e-03
# Max:  1.6071e-02
# Min:  -1.6209e-02
# Average psi change: 9.1178e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 116
# Loss: 236.3848
# Psi gradient stats:
# Mean: 7.4558e-05
# Std:  4.3197e-03
# Max:  1.6058e-02
# Min:  -1.6203e-02
# Average psi change: 9.1154e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 117
# Loss: 236.3045
# Psi gradient stats:
# Mean: 7.4546e-05
# Std:  4.3179e-03
# Max:  1.6045e-02
# Min:  -1.6197e-02
# Average psi change: 9.1132e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 118
# Loss: 236.2261
# Psi gradient stats:
# Mean: 7.4438e-05
# Std:  4.3160e-03
# Max:  1.6045e-02
# Min:  -1.6193e-02
# Average psi change: 9.1111e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 119
# Loss: 236.1484
# Psi gradient stats:
# Mean: 7.4322e-05
# Std:  4.3142e-03
# Max:  1.6054e-02
# Min:  -1.6194e-02
# Average psi change: 9.1085e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 120
# Loss: 236.0714
# Psi gradient stats:
# Mean: 7.4275e-05
# Std:  4.3125e-03
# Max:  1.6062e-02
# Min:  -1.6196e-02
# Average psi change: 9.1055e-05
# Epoch 120, Loss: 236.0714, Gradients - Lambda: 4.920e-02, Phi: 7.752e-01, Gamma: 1.915e-02, Psi: 1.620e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 121
# Loss: 235.9958
# Psi gradient stats:
# Mean: 7.4315e-05
# Std:  4.3109e-03
# Max:  1.6055e-02
# Min:  -1.6197e-02
# Average psi change: 9.1021e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 122
# Loss: 235.9207
# Psi gradient stats:
# Mean: 7.4370e-05
# Std:  4.3093e-03
# Max:  1.6038e-02
# Min:  -1.6193e-02
# Average psi change: 9.0993e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 123
# Loss: 235.8475
# Psi gradient stats:
# Mean: 7.4344e-05
# Std:  4.3075e-03
# Max:  1.6021e-02
# Min:  -1.6186e-02
# Average psi change: 9.0969e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 124
# Loss: 235.7753
# Psi gradient stats:
# Mean: 7.4223e-05
# Std:  4.3057e-03
# Max:  1.6020e-02
# Min:  -1.6181e-02
# Average psi change: 9.0947e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 125
# Loss: 235.7009
# Psi gradient stats:
# Mean: 7.4094e-05
# Std:  4.3039e-03
# Max:  1.6032e-02
# Min:  -1.6179e-02
# Average psi change: 9.0926e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 126
# Loss: 235.6294
# Psi gradient stats:
# Mean: 7.4067e-05
# Std:  4.3021e-03
# Max:  1.6044e-02
# Min:  -1.6181e-02
# Average psi change: 9.0900e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 127
# Loss: 235.5604
# Psi gradient stats:
# Mean: 7.4141e-05
# Std:  4.3005e-03
# Max:  1.6040e-02
# Min:  -1.6183e-02
# Average psi change: 9.0872e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 128
# Loss: 235.4886
# Psi gradient stats:
# Mean: 7.4227e-05
# Std:  4.2988e-03
# Max:  1.6020e-02
# Min:  -1.6181e-02
# Average psi change: 9.0842e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 129
# Loss: 235.4155
# Psi gradient stats:
# Mean: 7.4191e-05
# Std:  4.2971e-03
# Max:  1.5998e-02
# Min:  -1.6176e-02
# Average psi change: 9.0817e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 130
# Loss: 235.3496
# Psi gradient stats:
# Mean: 7.4028e-05
# Std:  4.2954e-03
# Max:  1.5993e-02
# Min:  -1.6169e-02
# Average psi change: 9.0797e-05
# Epoch 130, Loss: 235.3496, Gradients - Lambda: 4.916e-02, Phi: 8.091e-01, Gamma: 1.790e-02, Psi: 1.617e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 131
# Loss: 235.2802
# Psi gradient stats:
# Mean: 7.3843e-05
# Std:  4.2936e-03
# Max:  1.6006e-02
# Min:  -1.6165e-02
# Average psi change: 9.0778e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 132
# Loss: 235.2090
# Psi gradient stats:
# Mean: 7.3793e-05
# Std:  4.2919e-03
# Max:  1.6023e-02
# Min:  -1.6165e-02
# Average psi change: 9.0759e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 133
# Loss: 235.1425
# Psi gradient stats:
# Mean: 7.3913e-05
# Std:  4.2902e-03
# Max:  1.6026e-02
# Min:  -1.6168e-02
# Average psi change: 9.0735e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 134
# Loss: 235.0774
# Psi gradient stats:
# Mean: 7.4090e-05
# Std:  4.2885e-03
# Max:  1.6006e-02
# Min:  -1.6169e-02
# Average psi change: 9.0707e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 135
# Loss: 235.0074
# Psi gradient stats:
# Mean: 7.4128e-05
# Std:  4.2867e-03
# Max:  1.5979e-02
# Min:  -1.6165e-02
# Average psi change: 9.0681e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 136
# Loss: 234.9396
# Psi gradient stats:
# Mean: 7.3954e-05
# Std:  4.2849e-03
# Max:  1.5965e-02
# Min:  -1.6159e-02
# Average psi change: 9.0659e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 137
# Loss: 234.8761
# Psi gradient stats:
# Mean: 7.3656e-05
# Std:  4.2832e-03
# Max:  1.5974e-02
# Min:  -1.6153e-02
# Average psi change: 9.0641e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 138
# Loss: 234.8069
# Psi gradient stats:
# Mean: 7.3474e-05
# Std:  4.2816e-03
# Max:  1.5996e-02
# Min:  -1.6152e-02
# Average psi change: 9.0622e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 139
# Loss: 234.7391
# Psi gradient stats:
# Mean: 7.3547e-05
# Std:  4.2801e-03
# Max:  1.6009e-02
# Min:  -1.6155e-02
# Average psi change: 9.0598e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 140
# Loss: 234.6790
# Psi gradient stats:
# Mean: 7.3811e-05
# Std:  4.2784e-03
# Max:  1.5996e-02
# Min:  -1.6156e-02
# Average psi change: 9.0572e-05
# Epoch 140, Loss: 234.6790, Gradients - Lambda: 5.134e-02, Phi: 9.088e-01, Gamma: 1.661e-02, Psi: 1.616e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 141
# Loss: 234.6089
# Psi gradient stats:
# Mean: 7.4006e-05
# Std:  4.2765e-03
# Max:  1.5967e-02
# Min:  -1.6154e-02
# Average psi change: 9.0546e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 142
# Loss: 234.5400
# Psi gradient stats:
# Mean: 7.3941e-05
# Std:  4.2746e-03
# Max:  1.5946e-02
# Min:  -1.6147e-02
# Average psi change: 9.0525e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 143
# Loss: 234.4810
# Psi gradient stats:
# Mean: 7.3630e-05
# Std:  4.2727e-03
# Max:  1.5945e-02
# Min:  -1.6140e-02
# Average psi change: 9.0506e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 144
# Loss: 234.4118
# Psi gradient stats:
# Mean: 7.3311e-05
# Std:  4.2712e-03
# Max:  1.5964e-02
# Min:  -1.6137e-02
# Average psi change: 9.0483e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 145
# Loss: 234.3420
# Psi gradient stats:
# Mean: 7.3225e-05
# Std:  4.2699e-03
# Max:  1.5980e-02
# Min:  -1.6140e-02
# Average psi change: 9.0457e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 146
# Loss: 234.2812
# Psi gradient stats:
# Mean: 7.3413e-05
# Std:  4.2684e-03
# Max:  1.5975e-02
# Min:  -1.6143e-02
# Average psi change: 9.0428e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 147
# Loss: 234.2154
# Psi gradient stats:
# Mean: 7.3701e-05
# Std:  4.2666e-03
# Max:  1.5954e-02
# Min:  -1.6140e-02
# Average psi change: 9.0402e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 148
# Loss: 234.1445
# Psi gradient stats:
# Mean: 7.3837e-05
# Std:  4.2644e-03
# Max:  1.5930e-02
# Min:  -1.6133e-02
# Average psi change: 9.0380e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 149
# Loss: 234.0825
# Psi gradient stats:
# Mean: 7.3699e-05
# Std:  4.2623e-03
# Max:  1.5924e-02
# Min:  -1.6126e-02
# Average psi change: 9.0364e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 150
# Loss: 234.0173
# Psi gradient stats:
# Mean: 7.3363e-05
# Std:  4.2607e-03
# Max:  1.5937e-02
# Min:  -1.6123e-02
# Average psi change: 9.0342e-05
# Epoch 150, Loss: 234.0173, Gradients - Lambda: 5.528e-02, Phi: 8.598e-01, Gamma: 1.556e-02, Psi: 1.612e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 151
# Loss: 233.9463
# Psi gradient stats:
# Mean: 7.3073e-05
# Std:  4.2594e-03
# Max:  1.5954e-02
# Min:  -1.6126e-02
# Average psi change: 9.0313e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 152
# Loss: 233.8844
# Psi gradient stats:
# Mean: 7.3031e-05
# Std:  4.2583e-03
# Max:  1.5958e-02
# Min:  -1.6130e-02
# Average psi change: 9.0281e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 153
# Loss: 233.8188
# Psi gradient stats:
# Mean: 7.3242e-05
# Std:  4.2567e-03
# Max:  1.5941e-02
# Min:  -1.6129e-02
# Average psi change: 9.0254e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 154
# Loss: 233.7470
# Psi gradient stats:
# Mean: 7.3490e-05
# Std:  4.2546e-03
# Max:  1.5916e-02
# Min:  -1.6120e-02
# Average psi change: 9.0232e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 155
# Loss: 233.6845
# Psi gradient stats:
# Mean: 7.3574e-05
# Std:  4.2523e-03
# Max:  1.5903e-02
# Min:  -1.6111e-02
# Average psi change: 9.0216e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 156
# Loss: 233.6197
# Psi gradient stats:
# Mean: 7.3404e-05
# Std:  4.2504e-03
# Max:  1.5908e-02
# Min:  -1.6107e-02
# Average psi change: 9.0196e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 157
# Loss: 233.5472
# Psi gradient stats:
# Mean: 7.3103e-05
# Std:  4.2490e-03
# Max:  1.5923e-02
# Min:  -1.6111e-02
# Average psi change: 9.0168e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 158
# Loss: 233.4827
# Psi gradient stats:
# Mean: 7.2890e-05
# Std:  4.2479e-03
# Max:  1.5933e-02
# Min:  -1.6118e-02
# Average psi change: 9.0132e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 159
# Loss: 233.4200
# Psi gradient stats:
# Mean: 7.2906e-05
# Std:  4.2467e-03
# Max:  1.5925e-02
# Min:  -1.6118e-02
# Average psi change: 9.0103e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 160
# Loss: 233.3467
# Psi gradient stats:
# Mean: 7.3099e-05
# Std:  4.2448e-03
# Max:  1.5905e-02
# Min:  -1.6109e-02
# Average psi change: 9.0081e-05
# Epoch 160, Loss: 233.3467, Gradients - Lambda: 5.172e-02, Phi: 8.605e-01, Gamma: 1.442e-02, Psi: 1.611e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 161
# Loss: 233.2795
# Psi gradient stats:
# Mean: 7.3278e-05
# Std:  4.2426e-03
# Max:  1.5886e-02
# Min:  -1.6095e-02
# Average psi change: 9.0060e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 162
# Loss: 233.2184
# Psi gradient stats:
# Mean: 7.3271e-05
# Std:  4.2404e-03
# Max:  1.5881e-02
# Min:  -1.6090e-02
# Average psi change: 9.0043e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 163
# Loss: 233.1447
# Psi gradient stats:
# Mean: 7.3080e-05
# Std:  4.2387e-03
# Max:  1.5891e-02
# Min:  -1.6095e-02
# Average psi change: 9.0018e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 164
# Loss: 233.0751
# Psi gradient stats:
# Mean: 7.2873e-05
# Std:  4.2375e-03
# Max:  1.5905e-02
# Min:  -1.6106e-02
# Average psi change: 8.9985e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 165
# Loss: 233.0130
# Psi gradient stats:
# Mean: 7.2801e-05
# Std:  4.2364e-03
# Max:  1.5910e-02
# Min:  -1.6109e-02
# Average psi change: 8.9951e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 166
# Loss: 232.9413
# Psi gradient stats:
# Mean: 7.2892e-05
# Std:  4.2349e-03
# Max:  1.5899e-02
# Min:  -1.6100e-02
# Average psi change: 8.9929e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 167
# Loss: 232.8696
# Psi gradient stats:
# Mean: 7.3003e-05
# Std:  4.2329e-03
# Max:  1.5878e-02
# Min:  -1.6083e-02
# Average psi change: 8.9909e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 168
# Loss: 232.8059
# Psi gradient stats:
# Mean: 7.3005e-05
# Std:  4.2307e-03
# Max:  1.5861e-02
# Min:  -1.6073e-02
# Average psi change: 8.9890e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 169
# Loss: 232.7351
# Psi gradient stats:
# Mean: 7.2871e-05
# Std:  4.2288e-03
# Max:  1.5857e-02
# Min:  -1.6075e-02
# Average psi change: 8.9870e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 170
# Loss: 232.6646
# Psi gradient stats:
# Mean: 7.2709e-05
# Std:  4.2273e-03
# Max:  1.5868e-02
# Min:  -1.6088e-02
# Average psi change: 8.9839e-05
# Epoch 170, Loss: 232.6646, Gradients - Lambda: 5.216e-02, Phi: 8.839e-01, Gamma: 1.362e-02, Psi: 1.609e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 171
# Loss: 232.5995
# Psi gradient stats:
# Mean: 7.2677e-05
# Std:  4.2261e-03
# Max:  1.5881e-02
# Min:  -1.6097e-02
# Average psi change: 8.9802e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 172
# Loss: 232.5262
# Psi gradient stats:
# Mean: 7.2783e-05
# Std:  4.2247e-03
# Max:  1.5884e-02
# Min:  -1.6092e-02
# Average psi change: 8.9776e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 173
# Loss: 232.4587
# Psi gradient stats:
# Mean: 7.2891e-05
# Std:  4.2231e-03
# Max:  1.5872e-02
# Min:  -1.6075e-02
# Average psi change: 8.9757e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 174
# Loss: 232.3926
# Psi gradient stats:
# Mean: 7.2848e-05
# Std:  4.2211e-03
# Max:  1.5851e-02
# Min:  -1.6059e-02
# Average psi change: 8.9738e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 175
# Loss: 232.3172
# Psi gradient stats:
# Mean: 7.2641e-05
# Std:  4.2192e-03
# Max:  1.5835e-02
# Min:  -1.6056e-02
# Average psi change: 8.9722e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 176
# Loss: 232.2490
# Psi gradient stats:
# Mean: 7.2430e-05
# Std:  4.2174e-03
# Max:  1.5833e-02
# Min:  -1.6066e-02
# Average psi change: 8.9694e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 177
# Loss: 232.1853
# Psi gradient stats:
# Mean: 7.2402e-05
# Std:  4.2160e-03
# Max:  1.5844e-02
# Min:  -1.6079e-02
# Average psi change: 8.9656e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 178
# Loss: 232.1093
# Psi gradient stats:
# Mean: 7.2585e-05
# Std:  4.2146e-03
# Max:  1.5858e-02
# Min:  -1.6082e-02
# Average psi change: 8.9622e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 179
# Loss: 232.0381
# Psi gradient stats:
# Mean: 7.2806e-05
# Std:  4.2130e-03
# Max:  1.5862e-02
# Min:  -1.6070e-02
# Average psi change: 8.9603e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 180
# Loss: 231.9769
# Psi gradient stats:
# Mean: 7.2836e-05
# Std:  4.2113e-03
# Max:  1.5849e-02
# ...
#
# Epoch 527
# Loss: 218.3654
# Psi gradient stats:
# Mean: 6.5885e-05
# Std:  3.7558e-03
# Max:  1.4903e-02
# Min:  -1.5288e-02
# Average psi change: 8.1543e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 528
# Loss: 218.3275
# Psi gradient stats:
# Mean: 6.5757e-05
# Std:  3.7544e-03
# Max:  1.4895e-02
# Min:  -1.5289e-02
# Average psi change: 8.1523e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 529
# Loss: 218.2982
# Psi gradient stats:
# Mean: 6.5367e-05
# Std:  3.7528e-03
# Max:  1.4864e-02
# Min:  -1.5294e-02
# Average psi change: 8.1498e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 530
# Loss: 218.2859
# Psi gradient stats:
# Mean: 6.5020e-05
# Std:  3.7514e-03
# Max:  1.4832e-02
# Min:  -1.5296e-02
# Average psi change: 8.1470e-05
# Epoch 530, Loss: 218.2859, Gradients - Lambda: 6.245e-02, Phi: 1.009e+00, Gamma: 7.651e-03, Psi: 1.530e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 531
# Loss: 218.2531
# Psi gradient stats:
# Mean: 6.4991e-05
# Std:  3.7505e-03
# Max:  1.4823e-02
# Min:  -1.5294e-02
# Average psi change: 8.1439e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 532
# Loss: 218.2184
# Psi gradient stats:
# Mean: 6.5320e-05
# Std:  3.7500e-03
# Max:  1.4843e-02
# Min:  -1.5289e-02
# Average psi change: 8.1407e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 533
# Loss: 218.2061
# Psi gradient stats:
# Mean: 6.5721e-05
# Std:  3.7494e-03
# Max:  1.4874e-02
# Min:  -1.5286e-02
# Average psi change: 8.1387e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 534
# Loss: 218.1794
# Psi gradient stats:
# Mean: 6.5847e-05
# Std:  3.7484e-03
# Max:  1.4890e-02
# Min:  -1.5282e-02
# Average psi change: 8.1377e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 535
# Loss: 218.1423
# Psi gradient stats:
# Mean: 6.5574e-05
# Std:  3.7468e-03
# Max:  1.4877e-02
# Min:  -1.5278e-02
# Average psi change: 8.1358e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 536
# Loss: 218.1243
# Psi gradient stats:
# Mean: 6.5101e-05
# Std:  3.7452e-03
# Max:  1.4842e-02
# Min:  -1.5274e-02
# Average psi change: 8.1334e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 537
# Loss: 218.1058
# Psi gradient stats:
# Mean: 6.4813e-05
# Std:  3.7440e-03
# Max:  1.4813e-02
# Min:  -1.5272e-02
# Average psi change: 8.1302e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 538
# Loss: 218.0667
# Psi gradient stats:
# Mean: 6.4952e-05
# Std:  3.7433e-03
# Max:  1.4810e-02
# Min:  -1.5274e-02
# Average psi change: 8.1264e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 539
# Loss: 218.0450
# Psi gradient stats:
# Mean: 6.5393e-05
# Std:  3.7428e-03
# Max:  1.4835e-02
# Min:  -1.5279e-02
# Average psi change: 8.1235e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 540
# Loss: 218.0307
# Psi gradient stats:
# Mean: 6.5766e-05
# Std:  3.7421e-03
# Max:  1.4865e-02
# Min:  -1.5282e-02
# Average psi change: 8.1224e-05
# Epoch 540, Loss: 218.0307, Gradients - Lambda: 6.304e-02, Phi: 1.042e+00, Gamma: 7.723e-03, Psi: 1.528e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 541
# Loss: 217.9943
# Psi gradient stats:
# Mean: 6.5744e-05
# Std:  3.7409e-03
# Max:  1.4873e-02
# Min:  -1.5277e-02
# Average psi change: 8.1214e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 542
# Loss: 217.9678
# Psi gradient stats:
# Mean: 6.5309e-05
# Std:  3.7393e-03
# Max:  1.4853e-02
# Min:  -1.5266e-02
# Average psi change: 8.1197e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 543
# Loss: 217.9565
# Psi gradient stats:
# Mean: 6.4817e-05
# Std:  3.7377e-03
# Max:  1.4818e-02
# Min:  -1.5254e-02
# Average psi change: 8.1172e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 544
# Loss: 217.9245
# Psi gradient stats:
# Mean: 6.4657e-05
# Std:  3.7367e-03
# Max:  1.4794e-02
# Min:  -1.5251e-02
# Average psi change: 8.1132e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 545
# Loss: 217.8912
# Psi gradient stats:
# Mean: 6.4965e-05
# Std:  3.7361e-03
# Max:  1.4800e-02
# Min:  -1.5260e-02
# Average psi change: 8.1092e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 546
# Loss: 217.8803
# Psi gradient stats:
# Mean: 6.5478e-05
# Std:  3.7357e-03
# Max:  1.4826e-02
# Min:  -1.5274e-02
# Average psi change: 8.1071e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 547
# Loss: 217.8537
# Psi gradient stats:
# Mean: 6.5755e-05
# Std:  3.7348e-03
# Max:  1.4851e-02
# Min:  -1.5280e-02
# Average psi change: 8.1060e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 548
# Loss: 217.8177
# Psi gradient stats:
# Mean: 6.5537e-05
# Std:  3.7334e-03
# Max:  1.4852e-02
# Min:  -1.5269e-02
# Average psi change: 8.1052e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 549
# Loss: 217.8042
# Psi gradient stats:
# Mean: 6.4994e-05
# Std:  3.7318e-03
# Max:  1.4828e-02
# Min:  -1.5248e-02
# Average psi change: 8.1038e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 550
# Loss: 217.7851
# Psi gradient stats:
# Mean: 6.4568e-05
# Std:  3.7304e-03
# Max:  1.4797e-02
# Min:  -1.5231e-02
# Average psi change: 8.1003e-05
# Epoch 550, Loss: 217.7851, Gradients - Lambda: 6.300e-02, Phi: 1.071e+00, Gamma: 7.678e-03, Psi: 1.523e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 551
# Loss: 217.7475
# Psi gradient stats:
# Mean: 6.4600e-05
# Std:  3.7295e-03
# Max:  1.4783e-02
# Min:  -1.5232e-02
# Average psi change: 8.0958e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 552
# Loss: 217.7278
# Psi gradient stats:
# Mean: 6.5075e-05
# Std:  3.7291e-03
# Max:  1.4795e-02
# Min:  -1.5251e-02
# Average psi change: 8.0924e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 553
# Loss: 217.7168
# Psi gradient stats:
# Mean: 6.5582e-05
# Std:  3.7285e-03
# Max:  1.4820e-02
# Min:  -1.5270e-02
# Average psi change: 8.0907e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 554
# Loss: 217.6796
# Psi gradient stats:
# Mean: 6.5673e-05
# Std:  3.7275e-03
# Max:  1.4836e-02
# Min:  -1.5274e-02
# Average psi change: 8.0894e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 555
# Loss: 217.6522
# Psi gradient stats:
# Mean: 6.5258e-05
# Std:  3.7260e-03
# Max:  1.4830e-02
# Min:  -1.5254e-02
# Average psi change: 8.0889e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 556
# Loss: 217.6464
# Psi gradient stats:
# Mean: 6.4661e-05
# Std:  3.7243e-03
# Max:  1.4803e-02
# Min:  -1.5225e-02
# Average psi change: 8.0870e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 557
# Loss: 217.6146
# Psi gradient stats:
# Mean: 6.4377e-05
# Std:  3.7231e-03
# Max:  1.4778e-02
# Min:  -1.5209e-02
# Average psi change: 8.0828e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 558
# Loss: 217.5806
# Psi gradient stats:
# Mean: 6.4655e-05
# Std:  3.7225e-03
# Max:  1.4771e-02
# Min:  -1.5218e-02
# Average psi change: 8.0782e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 559
# Loss: 217.5733
# Psi gradient stats:
# Mean: 6.5244e-05
# Std:  3.7220e-03
# Max:  1.4788e-02
# Min:  -1.5245e-02
# Average psi change: 8.0761e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 560
# Loss: 217.5520
# Psi gradient stats:
# Mean: 6.5647e-05
# Std:  3.7213e-03
# Max:  1.4810e-02
# Min:  -1.5268e-02
# Average psi change: 8.0748e-05
# Epoch 560, Loss: 217.5520, Gradients - Lambda: 6.369e-02, Phi: 1.034e+00, Gamma: 7.664e-03, Psi: 1.527e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 561
# Loss: 217.5118
# Psi gradient stats:
# Mean: 6.5499e-05
# Std:  3.7201e-03
# Max:  1.4818e-02
# Min:  -1.5265e-02
# Average psi change: 8.0737e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 562
# Loss: 217.5002
# Psi gradient stats:
# Mean: 6.4902e-05
# Std:  3.7185e-03
# Max:  1.4804e-02
# Min:  -1.5237e-02
# Average psi change: 8.0729e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 563
# Loss: 217.4868
# Psi gradient stats:
# Mean: 6.4336e-05
# Std:  3.7170e-03
# Max:  1.4778e-02
# Min:  -1.5202e-02
# Average psi change: 8.0700e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 564
# Loss: 217.4469
# Psi gradient stats:
# Mean: 6.4274e-05
# Std:  3.7161e-03
# Max:  1.4760e-02
# Min:  -1.5189e-02
# Average psi change: 8.0652e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 565
# Loss: 217.4278
# Psi gradient stats:
# Mean: 6.4769e-05
# Std:  3.7155e-03
# Max:  1.4763e-02
# Min:  -1.5207e-02
# Average psi change: 8.0616e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 566
# Loss: 217.4214
# Psi gradient stats:
# Mean: 6.5400e-05
# Std:  3.7150e-03
# Max:  1.4783e-02
# Min:  -1.5240e-02
# Average psi change: 8.0600e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 567
# Loss: 217.3841
# Psi gradient stats:
# Mean: 6.5621e-05
# Std:  3.7141e-03
# Max:  1.4800e-02
# Min:  -1.5263e-02
# Average psi change: 8.0585e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 568
# Loss: 217.3580
# Psi gradient stats:
# Mean: 6.5219e-05
# Std:  3.7127e-03
# Max:  1.4800e-02
# Min:  -1.5253e-02
# Average psi change: 8.0576e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 569
# Loss: 217.3531
# Psi gradient stats:
# Mean: 6.4503e-05
# Std:  3.7111e-03
# Max:  1.4779e-02
# Min:  -1.5217e-02
# Average psi change: 8.0561e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 570
# Loss: 217.3244
# Psi gradient stats:
# Mean: 6.4070e-05
# Std:  3.7099e-03
# Max:  1.4754e-02
# Min:  -1.5182e-02
# Average psi change: 8.0523e-05
# Epoch 570, Loss: 217.3244, Gradients - Lambda: 6.170e-02, Phi: 1.005e+00, Gamma: 7.619e-03, Psi: 1.518e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 571
# Loss: 217.2903
# Psi gradient stats:
# Mean: 6.4279e-05
# Std:  3.7091e-03
# Max:  1.4745e-02
# Min:  -1.5174e-02
# Average psi change: 8.0472e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 572
# Loss: 217.2844
# Psi gradient stats:
# Mean: 6.4957e-05
# Std:  3.7086e-03
# Max:  1.4758e-02
# Min:  -1.5198e-02
# Average psi change: 8.0450e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 573
# Loss: 217.2644
# Psi gradient stats:
# Mean: 6.5534e-05
# Std:  3.7079e-03
# Max:  1.4780e-02
# Min:  -1.5234e-02
# Average psi change: 8.0437e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 574
# Loss: 217.2261
# Psi gradient stats:
# Mean: 6.5498e-05
# Std:  3.7068e-03
# Max:  1.4792e-02
# Min:  -1.5252e-02
# Average psi change: 8.0423e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 575
# Loss: 217.2166
# Psi gradient stats:
# Mean: 6.4862e-05
# Std:  3.7053e-03
# Max:  1.4779e-02
# Min:  -1.5236e-02
# Average psi change: 8.0413e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 576
# Loss: 217.2016
# Psi gradient stats:
# Mean: 6.4140e-05
# Std:  3.7039e-03
# Max:  1.4752e-02
# Min:  -1.5197e-02
# Average psi change: 8.0389e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 577
# Loss: 217.1645
# Psi gradient stats:
# Mean: 6.3926e-05
# Std:  3.7029e-03
# Max:  1.4730e-02
# Min:  -1.5165e-02
# Average psi change: 8.0346e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 578
# Loss: 217.1502
# Psi gradient stats:
# Mean: 6.4403e-05
# Std:  3.7022e-03
# Max:  1.4733e-02
# Min:  -1.5164e-02
# Average psi change: 8.0302e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 579
# Loss: 217.1398
# Psi gradient stats:
# Mean: 6.5179e-05
# Std:  3.7016e-03
# Max:  1.4755e-02
# Min:  -1.5191e-02
# Average psi change: 8.0287e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 580
# Loss: 217.1043
# Psi gradient stats:
# Mean: 6.5594e-05
# Std:  3.7007e-03
# Max:  1.4777e-02
# Min:  -1.5225e-02
# Average psi change: 8.0272e-05
# Epoch 580, Loss: 217.1043, Gradients - Lambda: 5.930e-02, Phi: 9.982e-01, Gamma: 7.767e-03, Psi: 1.523e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 581
# Loss: 217.0845
# Psi gradient stats:
# Mean: 6.5264e-05
# Std:  3.6995e-03
# Max:  1.4777e-02
# Min:  -1.5237e-02
# Average psi change: 8.0261e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 582
# Loss: 217.0790
# Psi gradient stats:
# Mean: 6.4442e-05
# Std:  3.6980e-03
# Max:  1.4753e-02
# Min:  -1.5216e-02
# Average psi change: 8.0246e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 583
# Loss: 217.0458
# Psi gradient stats:
# Mean: 6.3808e-05
# Std:  3.6968e-03
# Max:  1.4721e-02
# Min:  -1.5179e-02
# Average psi change: 8.0215e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 584
# Loss: 217.0199
# Psi gradient stats:
# Mean: 6.3877e-05
# Std:  3.6959e-03
# Max:  1.4708e-02
# Min:  -1.5156e-02
# Average psi change: 8.0167e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 585
# Loss: 217.0173
# Psi gradient stats:
# Mean: 6.4587e-05
# Std:  3.6953e-03
# Max:  1.4723e-02
# Min:  -1.5161e-02
# Average psi change: 8.0137e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 586
# Loss: 216.9879
# Psi gradient stats:
# Mean: 6.5345e-05
# Std:  3.6946e-03
# Max:  1.4754e-02
# Min:  -1.5188e-02
# Average psi change: 8.0120e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 587
# Loss: 216.9547
# Psi gradient stats:
# Mean: 6.5497e-05
# Std:  3.6936e-03
# Max:  1.4773e-02
# Min:  -1.5214e-02
# Average psi change: 8.0107e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 588
# Loss: 216.9551
# Psi gradient stats:
# Mean: 6.4902e-05
# Std:  3.6922e-03
# Max:  1.4760e-02
# Min:  -1.5216e-02
# Average psi change: 8.0097e-05
#
# Converged at epoch 588. Loss change: 0.0004

# %%
psi_config
# Out:
# {'in_cluster': 1.5, 'out_cluster': -1.5, 'noise_in': 0.1, 'noise_out': 0.01}

# %%
import torch

# Save complete state for R
# Save components as .rds files
save_path = '/Users/sarahurbut/Dropbox (Personal)/aladynoulli/model_complete_for_R_124_15_15_logitinit_nobg.pt'

torch.save({
    'model_state_dict': model.state_dict(),
    'clusters': model.clusters,
    'psi': model.psi,
    'Y': Y,
    'prevalence_t':prevalence_t,
    'G': G,
    'E': E,
    'disease_names': disease_names,
    'hyperparameters': {
        'N': N,
        'D': D,
        'T': T,
        'P': P,
        'K': K
    }
}, save_path)

import numpy as np
import pandas as pd
import rpy2.robjects as robjects
from rpy2.robjects import numpy2ri
numpy2ri.activate()

# Extract key components from model
with torch.no_grad():
    pi_pred, theta, phi = model.forward()
    
# Convert tensors to numpy arrays - check type first
pi_pred = pi_pred.cpu().detach().numpy()
theta = theta.cpu().detach().numpy()
phi = model.phi.cpu().detach().numpy()
psi = model.psi.cpu().detach().numpy()
lambda_vals = model.lambda_.cpu().detach().numpy()

# These are already numpy arrays
clusters = model.clusters  # Already numpy


save_path = '/Users/sarahurbut/Dropbox (Personal)/aladynoulli/Rdata/'
# Main parameters
robjects.r.saveRDS(phi, f"{save_path}phi15.rds")
robjects.r.saveRDS(psi, f"{save_path}psi15.rds")
robjects.r.saveRDS(lambda_vals, f"{save_path}lambda15.rds")
robjects.r.saveRDS(theta, f"{save_path}theta15.rds")
robjects.r.saveRDS(pi_pred, f"{save_path}pi_pred15.rds")
robjects.r.saveRDS(clusters, f"{save_path}clusters15.rds")
# Out:
# <rpy2.rinterface_lib.sexp.NULLType object at 0x17ca3c380> [RTYPES.NILSXP]

# %%
import matplotlib.pyplot as plt

# Create figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Plot loss
ax1.plot(history['loss'])
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('Training Loss')
ax1.grid(True)

# Plot gradients
ax2.plot(history['max_grad_lambda'], label='Lambda')
ax2.plot(history['max_grad_phi'], label='Phi')
ax2.plot(history['max_grad_gamma'], label='Gamma')
ax2.plot(history['max_grad_psi'], label='Psi')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Max Gradient Magnitude')
ax2.set_title('Parameter Gradients')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

# %%
def plot_signature_top_diseases_centered(model, disease_names, n_top=10):
    """
    Show top diseases for each signature, centered relative to prevalence
    """
    # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # For each signature, get top diseases
    for k in range(phi_avg.shape[0]):
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        print(f"\nTop {n_top} diseases in Signature {k} (relative to baseline):")
        for idx in top_indices:
            avg_effect = scores[idx]
            temporal_std = np.std(phi_centered[k, idx, :])
            # Convert to odds ratio for interpretability
            odds_ratio = np.exp(avg_effect)
            print(f"{disease_names[idx]}: effect={avg_effect:.3f} (OR={odds_ratio:.2f}), std={temporal_std:.3f}")

# Run visualization
plot_signature_top_diseases_centered(model, disease_names_list)
# Out:
# Top 10 diseases in Signature 0 (relative to baseline):
# Irregular menstrual bleeding: effect=4.135 (OR=62.47), std=0.675
# Benign neoplasm of ovary: effect=3.035 (OR=20.81), std=0.739
# Postmenopausal atrophic vaginitis: effect=2.854 (OR=17.35), std=0.430
# Dysmenorrhea: effect=2.384 (OR=10.85), std=0.386
# Endometriosis: effect=2.282 (OR=9.80), std=0.640
# Uterine/Uterovaginal prolapse: effect=2.110 (OR=8.25), std=0.361
# Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia]: effect=2.035 (OR=7.65), std=0.367
# Prolapse of vaginal walls: effect=1.996 (OR=7.36), std=0.655
# Ovarian cyst: effect=1.784 (OR=5.96), std=1.398
# Hypertrophy of female genital organs: effect=1.780 (OR=5.93), std=0.227
#
# Top 10 diseases in Signature 1 (relative to baseline):
# Internal derangement of knee: effect=3.213 (OR=24.84), std=0.948
# Other acquired deformities of limbs: effect=2.954 (OR=19.18), std=0.691
# Other derangement of joint: effect=2.660 (OR=14.30), std=0.264
# Hammer toe (acquired): effect=2.541 (OR=12.69), std=1.065
# Enthesopathy: effect=2.278 (OR=9.76), std=0.302
# Malunion and nonunion of fracture: effect=2.079 (OR=8.00), std=0.602
# Other disorders of synovium, tendon, and bursa: effect=2.022 (OR=7.55), std=0.381
# Ingrowing nail: effect=2.009 (OR=7.46), std=0.431
# Spondylosis and allied disorders: effect=1.750 (OR=5.75), std=0.376
# Rheumatoid arthritis: effect=1.744 (OR=5.72), std=0.203
#
# Top 10 diseases in Signature 2 (relative to baseline):
# Spondylosis without myelopathy: effect=2.906 (OR=18.28), std=0.701
# Thoracic or lumbosacral neuritis or radiculitis, unspecified: effect=2.543 (OR=12.71), std=0.662
# Neuralgia, neuritis, and radiculitis NOS: effect=2.229 (OR=9.29), std=0.517
# Degeneration of intervertebral disc: effect=2.136 (OR=8.46), std=0.557
# Displacement of intervertebral disc: effect=1.792 (OR=6.00), std=0.584
# Acquired spondylolisthesis: effect=1.696 (OR=5.45), std=0.153
# Spinal stenosis: effect=1.633 (OR=5.12), std=0.385
# Degenerative disease of the spinal cord: effect=1.526 (OR=4.60), std=0.212
# Back pain: effect=1.507 (OR=4.51), std=0.188
# Other and unspecified disc disorder: effect=1.424 (OR=4.15), std=0.439
#
# Top 10 diseases in Signature 3 (relative to baseline):
# Cholecystitis without cholelithiasis: effect=3.233 (OR=25.35), std=0.363
# Cholelithiasis with acute cholecystitis: effect=2.477 (OR=11.90), std=0.272
# Cholelithiasis with other cholecystitis: effect=2.447 (OR=11.55), std=0.483
# Peritoneal adhesions (postoperative) (postinfection): effect=1.681 (OR=5.37), std=0.184
# Cholelithiasis: effect=1.520 (OR=4.57), std=0.560
# Other disorders of biliary tract: effect=1.379 (OR=3.97), std=0.117
# Other disorders of gallbladder: effect=1.130 (OR=3.10), std=0.263
# Calculus of bile duct: effect=0.854 (OR=2.35), std=0.576
# Paroxysmal ventricular tachycardia: effect=0.833 (OR=2.30), std=0.332
# Benign neoplasm of other parts of digestive system: effect=0.646 (OR=1.91), std=0.649
#
# Top 10 diseases in Signature 4 (relative to baseline):
# Paroxysmal supraventricular tachycardia: effect=2.855 (OR=17.38), std=0.739
# Cardiomegaly: effect=2.470 (OR=11.82), std=0.286
# Right bundle branch block: effect=2.328 (OR=10.26), std=0.238
# Congenital anomalies of great vessels: effect=2.110 (OR=8.25), std=1.136
# Pericarditis: effect=1.895 (OR=6.65), std=0.144
# Disease of tricuspid valve: effect=1.715 (OR=5.56), std=0.408
# Heart failure NOS: effect=1.626 (OR=5.08), std=0.512
# Primary/intrinsic cardiomyopathies: effect=1.395 (OR=4.04), std=1.002
# Aortic valve disease: effect=1.294 (OR=3.65), std=0.441
# First degree AV block: effect=1.215 (OR=3.37), std=0.470
#
# Top 10 diseases in Signature 5 (relative to baseline):
# Viral Enteritis: effect=3.827 (OR=45.93), std=1.322
# Thyrotoxicosis with or without goiter: effect=3.054 (OR=21.20), std=0.763
# Hypothyroidism NOS: effect=2.786 (OR=16.22), std=0.882
# Ectropion or entropion: effect=2.739 (OR=15.48), std=0.745
# Chronic tonsillitis and adenoiditis: effect=2.533 (OR=12.59), std=0.384
# Allergic rhinitis: effect=2.475 (OR=11.88), std=0.582
# Neoplasm of uncertain behavior: effect=2.351 (OR=10.49), std=0.254
# Epiphora: effect=2.315 (OR=10.13), std=0.429
# Other diseases of the teeth and supporting structures: effect=2.277 (OR=9.74), std=1.187
# Parkinson's disease: effect=2.260 (OR=9.59), std=0.209
#
# Top 10 diseases in Signature 6 (relative to baseline):
# Psoriasis vulgaris: effect=2.735 (OR=15.41), std=0.387
# Hematemesis: effect=2.542 (OR=12.70), std=0.586
# Sleep apnea: effect=2.540 (OR=12.67), std=0.492
# Cyst of kidney, acquired: effect=2.385 (OR=10.86), std=0.609
# Gout: effect=2.267 (OR=9.65), std=0.565
# Duodenal ulcer: effect=2.130 (OR=8.41), std=0.574
# Epilepsy, recurrent seizures, convulsions: effect=2.003 (OR=7.41), std=0.630
# Blood in stool: effect=1.952 (OR=7.04), std=0.538
# Disorder of skin and subcutaneous tissue NOS: effect=1.853 (OR=6.38), std=0.353
# Pulmonary heart disease: effect=1.821 (OR=6.18), std=0.549
#
# Top 10 diseases in Signature 7 (relative to baseline):
# Bronchiectasis: effect=2.201 (OR=9.03), std=0.549
# Asthma: effect=2.125 (OR=8.37), std=0.406
# Postinflammatory pulmonary fibrosis: effect=1.853 (OR=6.38), std=0.409
# Empyema and pneumothorax: effect=1.728 (OR=5.63), std=0.702
# Emphysema: effect=1.652 (OR=5.22), std=0.321
# Chronic airway obstruction: effect=1.486 (OR=4.42), std=0.341
# Pneumococcal pneumonia: effect=1.354 (OR=3.87), std=0.422
# Respiratory failure: effect=1.164 (OR=3.20), std=0.693
# Obstructive chronic bronchitis: effect=0.841 (OR=2.32), std=0.383
# Pulmonary collapse; interstitial and compensatory emphysema: effect=0.815 (OR=2.26), std=1.100
#
# Top 10 diseases in Signature 8 (relative to baseline):
# Senile cataract: effect=2.921 (OR=18.55), std=0.659
# Retinal detachment with retinal defect: effect=2.101 (OR=8.18), std=0.414
# Myopia: effect=1.990 (OR=7.31), std=0.887
# Other retinal disorders: effect=1.873 (OR=6.51), std=0.516
# Primary open angle glaucoma: effect=1.572 (OR=4.82), std=0.201
# Cataract: effect=1.465 (OR=4.33), std=1.283
# Macular degeneration (senile) of retina NOS: effect=1.272 (OR=3.57), std=1.093
# Glaucoma: effect=1.125 (OR=3.08), std=0.620
# Disorders of vitreous body: effect=0.951 (OR=2.59), std=1.141
# Retinal detachments and defects: effect=0.894 (OR=2.44), std=0.297
#
# Top 10 diseases in Signature 9 (relative to baseline):
# Occlusion of cerebral arteries: effect=2.872 (OR=17.68), std=0.403
# Occlusion and stenosis of precerebral arteries: effect=2.559 (OR=12.93), std=0.412
# Hemiplegia: effect=2.032 (OR=7.63), std=0.320
# Transient cerebral ischemia: effect=1.468 (OR=4.34), std=0.991
# Cerebrovascular disease: effect=1.006 (OR=2.74), std=0.495
# Osteopenia or other disorder of bone and cartilage: effect=0.798 (OR=2.22), std=0.810
# Cerebral ischemia: effect=0.614 (OR=1.85), std=0.593
# Other diseases of respiratory system, NEC: effect=0.511 (OR=1.67), std=1.210
# Late effects of cerebrovascular disease: effect=0.500 (OR=1.65), std=1.082
# Psoriasis vulgaris: effect=0.384 (OR=1.47), std=0.745
#
# Top 10 diseases in Signature 10 (relative to baseline):
# Hypoglycemia: effect=2.294 (OR=9.91), std=0.730
# Type 2 diabetes with ophthalmic manifestations: effect=1.941 (OR=6.96), std=0.335
# Blood in stool: effect=1.390 (OR=4.01), std=0.526
# Type 1 diabetes: effect=1.312 (OR=3.71), std=0.364
# Primary/intrinsic cardiomyopathies: effect=0.884 (OR=2.42), std=0.367
# Diabetic retinopathy: effect=0.802 (OR=2.23), std=0.887
# Occlusion and stenosis of precerebral arteries: effect=0.534 (OR=1.71), std=0.300
# Cancer of prostate: effect=0.488 (OR=1.63), std=0.503
# Hyperlipidemia: effect=0.167 (OR=1.18), std=0.544
# GERD: effect=0.146 (OR=1.16), std=0.249
#
# Top 10 diseases in Signature 11 (relative to baseline):
# Malignant neoplasm of ovary: effect=2.475 (OR=11.89), std=0.626
# Secondary malignancy of bone: effect=2.410 (OR=11.13), std=0.986
# Malignant neoplasm of female breast: effect=2.161 (OR=8.68), std=1.094
# Secondary malignant neoplasm of digestive systems: effect=1.979 (OR=7.23), std=1.502
# Secondary malignancy of respiratory organs: effect=1.681 (OR=5.37), std=0.513
# Secondary malignant neoplasm of liver: effect=1.321 (OR=3.75), std=0.172
# Secondary malignant neoplasm: effect=1.119 (OR=3.06), std=0.252
# Secondary malignancy of lymph nodes: effect=0.929 (OR=2.53), std=0.101
# Cancer of bronchus; lung: effect=0.920 (OR=2.51), std=0.273
# Malignant neoplasm, other: effect=0.652 (OR=1.92), std=0.297
#
# Top 10 diseases in Signature 12 (relative to baseline):
# Other upper respiratory disease: effect=2.682 (OR=14.62), std=0.379
# Otitis media: effect=1.573 (OR=4.82), std=0.841
# Septal Deviations/Turbinate Hypertrophy: effect=1.460 (OR=4.31), std=0.391
# Chronic sinusitis: effect=1.260 (OR=3.53), std=0.514
# Hypothyroidism NOS: effect=0.910 (OR=2.48), std=0.970
# Nasal polyps: effect=0.862 (OR=2.37), std=0.885
# Chronic pharyngitis and nasopharyngitis: effect=0.482 (OR=1.62), std=0.500
# Colon cancer: effect=0.361 (OR=1.43), std=0.434
# Malignant neoplasm of rectum, rectosigmoid junction, and anus: effect=0.298 (OR=1.35), std=0.628
# Unstable angina (intermediate coronary syndrome): effect=0.274 (OR=1.32), std=0.364
#
# Top 10 diseases in Signature 13 (relative to baseline):
# Joint effusions: effect=2.492 (OR=12.08), std=0.466
# Peripheral vascular disease, unspecified: effect=2.450 (OR=11.59), std=0.800
# Streptococcus infection: effect=2.045 (OR=7.73), std=0.865
# Decubitus ulcer: effect=1.495 (OR=4.46), std=0.599
# Stricture of artery: effect=1.300 (OR=3.67), std=0.231
# Hyperlipidemia: effect=1.200 (OR=3.32), std=0.474
# Staphylococcus infections: effect=1.128 (OR=3.09), std=0.256
# Carbuncle and furuncle: effect=0.975 (OR=2.65), std=0.113
# Cellulitis and abscess of arm/hand: effect=0.904 (OR=2.47), std=0.218
# Chronic ulcer of skin: effect=0.646 (OR=1.91), std=0.609
#
# Top 10 diseases in Signature 14 (relative to baseline):
# Reflux esophagitis: effect=3.166 (OR=23.72), std=0.448
# GERD: effect=2.537 (OR=12.64), std=0.378
# Other disorders of stomach and duodenum: effect=1.564 (OR=4.78), std=1.245
# Barrett's esophagus: effect=1.506 (OR=4.51), std=0.496
# Diaphragmatic hernia: effect=1.478 (OR=4.39), std=0.715
# Esophagitis, GERD and related diseases: effect=1.258 (OR=3.52), std=0.173
# Stricture and stenosis of esophagus: effect=1.203 (OR=3.33), std=0.251
# Esophageal bleeding (varices/hemorrhage): effect=1.090 (OR=2.97), std=0.573
# Benign neoplasm of other parts of digestive system: effect=1.071 (OR=2.92), std=0.505
# Gastric ulcer: effect=0.966 (OR=2.63), std=0.463
#
# Top 10 diseases in Signature 15 (relative to baseline):
# Hypercholesterolemia: effect=2.898 (OR=18.14), std=0.379
# Angina pectoris: effect=2.025 (OR=7.58), std=0.454
# Coronary atherosclerosis: effect=1.817 (OR=6.15), std=0.690
# Essential hypertension: effect=1.234 (OR=3.44), std=0.490
# Myocardial infarction: effect=0.723 (OR=2.06), std=0.167
# Colon cancer: effect=0.654 (OR=1.92), std=0.587
# Other chronic ischemic heart disease, unspecified: effect=0.594 (OR=1.81), std=0.798
# Other acute and subacute forms of ischemic heart disease: effect=0.488 (OR=1.63), std=0.132
# Unstable angina (intermediate coronary syndrome): effect=0.317 (OR=1.37), std=0.419
# Melanomas of skin: effect=0.287 (OR=1.33), std=0.560
#
# Top 10 diseases in Signature 16 (relative to baseline):
# Orthostatic hypotension: effect=2.126 (OR=8.38), std=0.890
# Gram negative septicemia: effect=2.007 (OR=7.44), std=0.305
# Other anemias: effect=1.980 (OR=7.24), std=0.342
# Pyelonephritis: effect=1.941 (OR=6.97), std=0.384
# Chronic renal failure [CKD]: effect=1.937 (OR=6.94), std=1.011
# Acute renal failure: effect=1.933 (OR=6.91), std=0.285
# Candidiasis: effect=1.877 (OR=6.54), std=0.197
# Urinary tract infection: effect=1.560 (OR=4.76), std=0.641
# Acidosis: effect=1.558 (OR=4.75), std=0.130
# Hypovolemia: effect=1.546 (OR=4.69), std=0.352
#
# Top 10 diseases in Signature 17 (relative to baseline):
# Calculus of ureter: effect=2.444 (OR=11.52), std=0.963
# Renal colic: effect=2.370 (OR=10.70), std=0.573
# Stricture/obstruction of ureter: effect=2.005 (OR=7.42), std=0.647
# Calculus of kidney: effect=1.161 (OR=3.19), std=0.517
# Rheumatoid arthritis: effect=0.829 (OR=2.29), std=0.418
# Melanomas of skin: effect=0.693 (OR=2.00), std=0.735
# Hydronephrosis: effect=0.542 (OR=1.72), std=0.286
# Neoplasm of unspecified nature of digestive system: effect=0.477 (OR=1.61), std=0.655
# Disorders of uterus, NEC: effect=0.208 (OR=1.23), std=0.131
# Carbuncle and furuncle: effect=0.168 (OR=1.18), std=0.530
#
# Top 10 diseases in Signature 18 (relative to baseline):
# Anal and rectal conditions: effect=3.230 (OR=25.28), std=0.354
# Colon cancer: effect=2.517 (OR=12.40), std=0.891
# Anal and rectal polyp: effect=2.353 (OR=10.52), std=0.756
# Hemorrhage of gastrointestinal tract: effect=2.106 (OR=8.21), std=0.421
# Benign neoplasm of colon: effect=2.101 (OR=8.17), std=0.261
# Iron deficiency anemias, unspecified or not due to blood loss: effect=2.093 (OR=8.11), std=0.969
# Diverticulosis: effect=2.028 (OR=7.60), std=0.317
# Neoplasm of unspecified nature of digestive system: effect=1.811 (OR=6.12), std=0.322
# Noninfectious gastroenteritis: effect=1.585 (OR=4.88), std=0.830
# Ventral hernia: effect=1.481 (OR=4.40), std=0.583
#
# Top 10 diseases in Signature 19 (relative to baseline):
# Cystitis: effect=2.072 (OR=7.94), std=0.535
# Other disorders of bladder: effect=1.978 (OR=7.23), std=0.467
# Chronic prostatitis: effect=1.937 (OR=6.94), std=0.858
# Urethral stricture (not specified as infectious): effect=1.766 (OR=5.85), std=0.725
# Bladder neck obstruction: effect=1.642 (OR=5.16), std=0.792
# Other disorders of prostate: effect=1.542 (OR=4.67), std=0.358
# Functional disorders of bladder: effect=1.328 (OR=3.77), std=0.809
# Urinary incontinence: effect=1.266 (OR=3.55), std=0.558
# Chronic cystitis: effect=1.079 (OR=2.94), std=0.527
# Malignant neoplasm of bladder: effect=1.069 (OR=2.91), std=0.440

# %%
def compare_disease_rankings(model, disease_names, n_top=10):
    """
    Compare initial vs final disease rankings for each signature
    """
    # Get initial rankings from psi
    psi = model.psi.detach().numpy()  # Shape: (K, D)
    
    # Get final rankings from centered phi
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Compare rankings for each signature
    for k in range(phi_avg.shape[0]):
        print(f"\nSignature {k}:")
        
        # Get initial top diseases from psi
        initial_scores = psi[k, :]
        initial_top = np.argsort(initial_scores)[-n_top:][::-1]
        
        # Get final top diseases from phi
        final_scores = phi_avg[k, :]
        final_top = np.argsort(final_scores)[-n_top:][::-1]
        
        print("\nInitial top diseases:")
        for i, idx in enumerate(initial_top):
            print(f"{i+1}. {disease_names[idx]}: {initial_scores[idx]:.3f}")
            
        print("\nFinal top diseases:")
        for i, idx in enumerate(final_top):
            print(f"{i+1}. {disease_names[idx]}: {final_scores[idx]:.3f}")
            
        # Calculate rank changes
        initial_ranks = {disease: rank for rank, disease in enumerate(initial_top)}
        final_ranks = {disease: rank for rank, disease in enumerate(final_top)}
        
        # Find diseases that changed ranks significantly
        changed_diseases = set(initial_top) | set(final_top)
        for disease in changed_diseases:
            initial_rank = initial_ranks.get(disease, n_top+1)
            final_rank = final_ranks.get(disease, n_top+1)
            if abs(final_rank - initial_rank) > 2:  # Threshold for significant change
                print(f"\n{disease_names[disease]} changed from rank {initial_rank+1} to {final_rank+1}")

# Run comparison
compare_disease_rankings(model, disease_names_list)
# Out:
# Signature 0:
#
# Initial top diseases:
# 1. Postmenopausal atrophic vaginitis: 1.692
# 2. Cervicitis and endocervicitis: 1.668
# 3. Irregular menstrual bleeding: 1.664
# 4. Endometriosis: 1.635
# 5. Irregular menstrual cycle/bleeding: 1.609
# 6. Disorders of uterus, NEC: 1.600
# 7. Noninflammatory disorders of cervix: 1.572
# 8. Dysmenorrhea: 1.564
# 9. Polyp of corpus uteri: 1.559
# 10. Hypertrophy of female genital organs: 1.557
#
# Final top diseases:
# 1. Irregular menstrual bleeding: 4.135
# 2. Benign neoplasm of ovary: 3.035
# 3. Postmenopausal atrophic vaginitis: 2.854
# 4. Dysmenorrhea: 2.384
# 5. Endometriosis: 2.282
# 6. Uterine/Uterovaginal prolapse: 2.110
# 7. Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia]: 2.035
# 8. Prolapse of vaginal walls: 1.996
# 9. Ovarian cyst: 1.784
# 10. Hypertrophy of female genital organs: 1.780
#
# Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia] changed from rank 12 to 7
#
# Polyp of corpus uteri changed from rank 9 to 12
#
# Ovarian cyst changed from rank 12 to 9
#
# Benign neoplasm of ovary changed from rank 12 to 2
#
# Prolapse of vaginal walls changed from rank 12 to 8
#
# Irregular menstrual cycle/bleeding changed from rank 5 to 12
#
# Noninflammatory disorders of cervix changed from rank 7 to 12
#
# Cervicitis and endocervicitis changed from rank 2 to 12
#
# Disorders of uterus, NEC changed from rank 6 to 12
#
# Dysmenorrhea changed from rank 8 to 4
#
# Uterine/Uterovaginal prolapse changed from rank 12 to 6
#
# Signature 1:
#
# Initial top diseases:
# 1. Other disorders of synovium, tendon, and bursa: 1.810
# 2. Hallux valgus (Bunion): 1.778
# 3. Synovitis and tenosynovitis: 1.727
# 4. Hammer toe (acquired): 1.704
# 5. Ingrowing nail: 1.701
# 6. Other derangement of joint: 1.676
# 7. Other disorders of bone and cartilage: 1.672
# 8. Enthesopathy: 1.655
# 9. Other acquired deformities of limbs: 1.650
# 10. Malunion and nonunion of fracture: 1.650
#
# Final top diseases:
# 1. Internal derangement of knee: 3.213
# 2. Other acquired deformities of limbs: 2.954
# 3. Other derangement of joint: 2.660
# 4. Hammer toe (acquired): 2.541
# 5. Enthesopathy: 2.278
# 6. Malunion and nonunion of fracture: 2.079
# 7. Other disorders of synovium, tendon, and bursa: 2.022
# 8. Ingrowing nail: 2.009
# 9. Spondylosis and allied disorders: 1.750
# 10. Rheumatoid arthritis: 1.744
#
# Other disorders of synovium, tendon, and bursa changed from rank 1 to 7
#
# Spondylosis and allied disorders changed from rank 12 to 9
#
# Other derangement of joint changed from rank 6 to 3
#
# Enthesopathy changed from rank 8 to 5
#
# Other acquired deformities of limbs changed from rank 9 to 2
#
# Ingrowing nail changed from rank 5 to 8
#
# Hallux valgus (Bunion) changed from rank 2 to 12
#
# Synovitis and tenosynovitis changed from rank 3 to 12
#
# Internal derangement of knee changed from rank 12 to 1
#
# Malunion and nonunion of fracture changed from rank 10 to 6
#
# Other disorders of bone and cartilage changed from rank 7 to 12
#
# Signature 2:
#
# Initial top diseases:
# 1. Degeneration of intervertebral disc: 1.719
# 2. Spinal stenosis: 1.714
# 3. Spondylosis without myelopathy: 1.619
# 4. Acquired spondylolisthesis: 1.580
# 5. Degenerative disease of the spinal cord: 1.535
# 6. Neuralgia, neuritis, and radiculitis NOS: 1.529
# 7. Displacement of intervertebral disc: 1.492
# 8. Thoracic or lumbosacral neuritis or radiculitis, unspecified: 1.485
# 9. Sciatica: 1.410
# 10. Back pain: 1.393
#
# Final top diseases:
# 1. Spondylosis without myelopathy: 2.906
# 2. Thoracic or lumbosacral neuritis or radiculitis, unspecified: 2.543
# 3. Neuralgia, neuritis, and radiculitis NOS: 2.229
# 4. Degeneration of intervertebral disc: 2.136
# 5. Displacement of intervertebral disc: 1.792
# 6. Acquired spondylolisthesis: 1.696
# 7. Spinal stenosis: 1.633
# 8. Degenerative disease of the spinal cord: 1.526
# 9. Back pain: 1.507
# 10. Other and unspecified disc disorder: 1.424
#
# Spinal stenosis changed from rank 2 to 7
#
# Thoracic or lumbosacral neuritis or radiculitis, unspecified changed from rank 8 to 2
#
# Degeneration of intervertebral disc changed from rank 1 to 4
#
# Degenerative disease of the spinal cord changed from rank 5 to 8
#
# Sciatica changed from rank 9 to 12
#
# Neuralgia, neuritis, and radiculitis NOS changed from rank 6 to 3
#
# Signature 3:
#
# Initial top diseases:
# 1. Cholecystitis without cholelithiasis: 1.603
# 2. Cholelithiasis with acute cholecystitis: 1.567
# 3. Cholelithiasis: 1.551
# 4. Other disorders of biliary tract: 1.510
# 5. Cholelithiasis with other cholecystitis: 1.507
# 6. Peritoneal adhesions (postoperative) (postinfection): 1.464
# 7. Other disorders of gallbladder: 1.436
# 8. Calculus of bile duct: 1.360
# 9. Acute pancreatitis: 1.331
# 10. Acute renal failure: -1.357
#
# Final top diseases:
# 1. Cholecystitis without cholelithiasis: 3.233
# 2. Cholelithiasis with acute cholecystitis: 2.477
# 3. Cholelithiasis with other cholecystitis: 2.447
# 4. Peritoneal adhesions (postoperative) (postinfection): 1.681
# 5. Cholelithiasis: 1.520
# 6. Other disorders of biliary tract: 1.379
# 7. Other disorders of gallbladder: 1.130
# 8. Calculus of bile duct: 0.854
# 9. Paroxysmal ventricular tachycardia: 0.833
# 10. Benign neoplasm of other parts of digestive system: 0.646
#
# Paroxysmal ventricular tachycardia changed from rank 12 to 9
#
# Acute pancreatitis changed from rank 9 to 12
#
# Signature 4:
#
# Initial top diseases:
# 1. Disease of tricuspid valve: 1.757
# 2. Congenital anomalies of great vessels: 1.745
# 3. Cardiomegaly: 1.688
# 4. Primary/intrinsic cardiomyopathies: 1.679
# 5. Pleurisy; pleural effusion: 1.556
# 6. Aortic valve disease: 1.539
# 7. Paroxysmal supraventricular tachycardia: 1.534
# 8. Atrial fibrillation and flutter: 1.525
# 9. Pericarditis: 1.514
# 10. Right bundle branch block: 1.487
#
# Final top diseases:
# 1. Paroxysmal supraventricular tachycardia: 2.855
# 2. Cardiomegaly: 2.470
# 3. Right bundle branch block: 2.328
# 4. Congenital anomalies of great vessels: 2.110
# 5. Pericarditis: 1.895
# 6. Disease of tricuspid valve: 1.715
# 7. Heart failure NOS: 1.626
# 8. Primary/intrinsic cardiomyopathies: 1.395
# 9. Aortic valve disease: 1.294
# 10. First degree AV block: 1.215
#
# Pericarditis changed from rank 9 to 5
#
# Pleurisy; pleural effusion changed from rank 5 to 12
#
# Primary/intrinsic cardiomyopathies changed from rank 4 to 8
#
# Disease of tricuspid valve changed from rank 1 to 6
#
# Aortic valve disease changed from rank 6 to 9
#
# Paroxysmal supraventricular tachycardia changed from rank 7 to 1
#
# Right bundle branch block changed from rank 10 to 3
#
# Atrial fibrillation and flutter changed from rank 8 to 12
#
# Heart failure NOS changed from rank 12 to 7
#
# Signature 5:
#
# Initial top diseases:
# 1. Inflammatory and toxic neuropathy: 1.776
# 2. Migraine: 1.766
# 3. Epiphora: 1.763
# 4. Raynaud's syndrome: 1.736
# 5. Seborrheic keratosis: 1.724
# 6. Other diseases of the teeth and supporting structures: 1.721
# 7. Allergic rhinitis: 1.715
# 8. Hypertensive chronic kidney disease: 1.707
# 9. Non-Hodgkins lymphoma: 1.690
# 10. Malignant neoplasm of kidney, except pelvis: 1.684
#
# Final top diseases:
# 1. Viral Enteritis: 3.827
# 2. Thyrotoxicosis with or without goiter: 3.054
# 3. Hypothyroidism NOS: 2.786
# 4. Ectropion or entropion: 2.739
# 5. Chronic tonsillitis and adenoiditis: 2.533
# 6. Allergic rhinitis: 2.475
# 7. Neoplasm of uncertain behavior: 2.351
# 8. Epiphora: 2.315
# 9. Other diseases of the teeth and supporting structures: 2.277
# 10. Parkinson's disease: 2.260
#
# Seborrheic keratosis changed from rank 5 to 12
#
# Other diseases of the teeth and supporting structures changed from rank 6 to 9
#
# Epiphora changed from rank 3 to 8
#
# Non-Hodgkins lymphoma changed from rank 9 to 12
#
# Migraine changed from rank 2 to 12
#
# Raynaud's syndrome changed from rank 4 to 12
#
# Inflammatory and toxic neuropathy changed from rank 1 to 12
#
# Thyrotoxicosis with or without goiter changed from rank 12 to 2
#
# Neoplasm of uncertain behavior changed from rank 12 to 7
#
# Viral Enteritis changed from rank 12 to 1
#
# Chronic tonsillitis and adenoiditis changed from rank 12 to 5
#
# Hypothyroidism NOS changed from rank 12 to 3
#
# Ectropion or entropion changed from rank 12 to 4
#
# Hypertensive chronic kidney disease changed from rank 8 to 12
#
# Signature 6:
#
# Initial top diseases:
# 1. Hematemesis: 1.727
# 2. Alcoholic liver damage: 1.709
# 3. Other chronic nonalcoholic liver disease: 1.683
# 4. Cyst of kidney, acquired: 1.591
# 5. Other disorders of testis: 1.588
# 6. Duodenal ulcer: 1.575
# 7. Gout: 1.557
# 8. Pulmonary heart disease: 1.525
# 9. Disorder of skin and subcutaneous tissue NOS: 1.525
# 10. Bipolar: 1.507
#
# Final top diseases:
# 1. Psoriasis vulgaris: 2.735
# 2. Hematemesis: 2.542
# 3. Sleep apnea: 2.540
# 4. Cyst of kidney, acquired: 2.385
# 5. Gout: 2.267
# 6. Duodenal ulcer: 2.130
# 7. Epilepsy, recurrent seizures, convulsions: 2.003
# 8. Blood in stool: 1.952
# 9. Disorder of skin and subcutaneous tissue NOS: 1.853
# 10. Pulmonary heart disease: 1.821
#
# Other disorders of testis changed from rank 5 to 12
#
# Alcoholic liver damage changed from rank 2 to 12
#
# Sleep apnea changed from rank 12 to 3
#
# Epilepsy, recurrent seizures, convulsions changed from rank 12 to 7
#
# Psoriasis vulgaris changed from rank 12 to 1
#
# Other chronic nonalcoholic liver disease changed from rank 3 to 12
#
# Blood in stool changed from rank 12 to 8
#
# Signature 7:
#
# Initial top diseases:
# 1. Bronchiectasis: 1.876
# 2. Emphysema: 1.682
# 3. Chronic airway obstruction: 1.577
# 4. Empyema and pneumothorax: 1.573
# 5. Pneumonia: 1.572
# 6. Postinflammatory pulmonary fibrosis: 1.554
# 7. Respiratory failure: 1.512
# 8. Asthma: 1.511
# 9. Pneumococcal pneumonia: 1.462
# 10. Pulmonary collapse; interstitial and compensatory emphysema: 1.417
#
# Final top diseases:
# 1. Bronchiectasis: 2.201
# 2. Asthma: 2.125
# 3. Postinflammatory pulmonary fibrosis: 1.853
# 4. Empyema and pneumothorax: 1.728
# 5. Emphysema: 1.652
# 6. Chronic airway obstruction: 1.486
# 7. Pneumococcal pneumonia: 1.354
# 8. Respiratory failure: 1.164
# 9. Obstructive chronic bronchitis: 0.841
# 10. Pulmonary collapse; interstitial and compensatory emphysema: 0.815
#
# Postinflammatory pulmonary fibrosis changed from rank 6 to 3
#
# Emphysema changed from rank 2 to 5
#
# Pneumonia changed from rank 5 to 12
#
# Asthma changed from rank 8 to 2
#
# Chronic airway obstruction changed from rank 3 to 6
#
# Obstructive chronic bronchitis changed from rank 12 to 9
#
# Signature 8:
#
# Initial top diseases:
# 1. Cataract: 1.711
# 2. Retinal detachment with retinal defect: 1.700
# 3. Senile cataract: 1.645
# 4. Myopia: 1.548
# 5. Other retinal disorders: 1.524
# 6. Primary open angle glaucoma: 1.411
# 7. Disorders of vitreous body: 1.406
# 8. Macular degeneration (senile) of retina NOS: 1.362
# 9. Glaucoma: 1.350
# 10. Retinal detachments and defects: 1.326
#
# Final top diseases:
# 1. Senile cataract: 2.921
# 2. Retinal detachment with retinal defect: 2.101
# 3. Myopia: 1.990
# 4. Other retinal disorders: 1.873
# 5. Primary open angle glaucoma: 1.572
# 6. Cataract: 1.465
# 7. Macular degeneration (senile) of retina NOS: 1.272
# 8. Glaucoma: 1.125
# 9. Disorders of vitreous body: 0.951
# 10. Retinal detachments and defects: 0.894
#
# Cataract changed from rank 1 to 6
#
# Signature 9:
#
# Initial top diseases:
# 1. Occlusion of cerebral arteries: 1.717
# 2. Occlusion and stenosis of precerebral arteries: 1.632
# 3. Hemiplegia: 1.571
# 4. Cerebral ischemia: 1.402
# 5. Cerebrovascular disease: 1.347
# 6. Cerebral artery occlusion, with cerebral infarction: 1.336
# 7. Transient cerebral ischemia: 1.330
# 8. Late effects of cerebrovascular disease: 1.210
# 9. Parkinson's disease: -1.340
# 10. Pleurisy; pleural effusion: -1.356
#
# Final top diseases:
# 1. Occlusion of cerebral arteries: 2.872
# 2. Occlusion and stenosis of precerebral arteries: 2.559
# 3. Hemiplegia: 2.032
# 4. Transient cerebral ischemia: 1.468
# 5. Cerebrovascular disease: 1.006
# 6. Osteopenia or other disorder of bone and cartilage: 0.798
# 7. Cerebral ischemia: 0.614
# 8. Other diseases of respiratory system, NEC: 0.511
# 9. Late effects of cerebrovascular disease: 0.500
# 10. Psoriasis vulgaris: 0.384
#
# Other diseases of respiratory system, NEC changed from rank 12 to 8
#
# Transient cerebral ischemia changed from rank 7 to 4
#
# Cerebral artery occlusion, with cerebral infarction changed from rank 6 to 12
#
# Cerebral ischemia changed from rank 4 to 7
#
# Osteopenia or other disorder of bone and cartilage changed from rank 12 to 6
#
# Parkinson's disease changed from rank 9 to 12
#
# Signature 10:
#
# Initial top diseases:
# 1. Type 2 diabetes with ophthalmic manifestations: 1.585
# 2. Hypoglycemia: 1.573
# 3. Diabetic retinopathy: 1.525
# 4. Type 1 diabetes: 1.504
# 5. Type 2 diabetes: 1.368
# 6. Malignant neoplasm of female breast: -1.353
# 7. Irregular menstrual bleeding: -1.354
# 8. Noninfectious gastroenteritis: -1.358
# 9. Retinal vascular changes and abnomalities: -1.358
# 10. Chronic cystitis: -1.359
#
# Final top diseases:
# 1. Hypoglycemia: 2.294
# 2. Type 2 diabetes with ophthalmic manifestations: 1.941
# 3. Blood in stool: 1.390
# 4. Type 1 diabetes: 1.312
# 5. Primary/intrinsic cardiomyopathies: 0.884
# 6. Diabetic retinopathy: 0.802
# 7. Occlusion and stenosis of precerebral arteries: 0.534
# 8. Cancer of prostate: 0.488
# 9. Hyperlipidemia: 0.167
# 10. GERD: 0.146
#
# Hyperlipidemia changed from rank 12 to 9
#
# Occlusion and stenosis of precerebral arteries changed from rank 12 to 7
#
# Malignant neoplasm of female breast changed from rank 6 to 12
#
# Retinal vascular changes and abnomalities changed from rank 9 to 12
#
# Type 2 diabetes changed from rank 5 to 12
#
# Cancer of prostate changed from rank 12 to 8
#
# Primary/intrinsic cardiomyopathies changed from rank 12 to 5
#
# Diabetic retinopathy changed from rank 3 to 6
#
# Irregular menstrual bleeding changed from rank 7 to 12
#
# Noninfectious gastroenteritis changed from rank 8 to 12
#
# Blood in stool changed from rank 12 to 3
#
# Signature 11:
#
# Initial top diseases:
# 1. Malignant neoplasm of female breast: 1.784
# 2. Malignant neoplasm of ovary: 1.693
# 3. Secondary malignancy of respiratory organs: 1.665
# 4. Secondary malignancy of bone: 1.614
# 5. Secondary malignant neoplasm of liver: 1.458
# 6. Cancer of bronchus; lung: 1.452
# 7. Secondary malignant neoplasm of digestive systems: 1.439
# 8. Malignant neoplasm, other: 1.383
# 9. Secondary malignancy of lymph nodes: 1.336
# 10. Secondary malignant neoplasm: 1.302
#
# Final top diseases:
# 1. Malignant neoplasm of ovary: 2.475
# 2. Secondary malignancy of bone: 2.410
# 3. Malignant neoplasm of female breast: 2.161
# 4. Secondary malignant neoplasm of digestive systems: 1.979
# 5. Secondary malignancy of respiratory organs: 1.681
# 6. Secondary malignant neoplasm of liver: 1.321
# 7. Secondary malignant neoplasm: 1.119
# 8. Secondary malignancy of lymph nodes: 0.929
# 9. Cancer of bronchus; lung: 0.920
# 10. Malignant neoplasm, other: 0.652
#
# Secondary malignant neoplasm changed from rank 10 to 7
#
# Secondary malignant neoplasm of digestive systems changed from rank 7 to 4
#
# Cancer of bronchus; lung changed from rank 6 to 9
#
# Signature 12:
#
# Initial top diseases:
# 1. Nasal polyps: 1.686
# 2. Other upper respiratory disease: 1.578
# 3. Chronic sinusitis: 1.458
# 4. Otitis media: 1.446
# 5. Chronic pharyngitis and nasopharyngitis: 1.392
# 6. Septal Deviations/Turbinate Hypertrophy: 1.329
# 7. Urinary incontinence: -1.346
# 8. Colon cancer: -1.362
# 9. Bronchiectasis: -1.363
# 10. Migraine: -1.365
#
# Final top diseases:
# 1. Other upper respiratory disease: 2.682
# 2. Otitis media: 1.573
# 3. Septal Deviations/Turbinate Hypertrophy: 1.460
# 4. Chronic sinusitis: 1.260
# 5. Hypothyroidism NOS: 0.910
# 6. Nasal polyps: 0.862
# 7. Chronic pharyngitis and nasopharyngitis: 0.482
# 8. Colon cancer: 0.361
# 9. Malignant neoplasm of rectum, rectosigmoid junction, and anus: 0.298
# 10. Unstable angina (intermediate coronary syndrome): 0.274
#
# Nasal polyps changed from rank 1 to 6
#
# Malignant neoplasm of rectum, rectosigmoid junction, and anus changed from rank 12 to 9
#
# Septal Deviations/Turbinate Hypertrophy changed from rank 6 to 3
#
# Bronchiectasis changed from rank 9 to 12
#
# Urinary incontinence changed from rank 7 to 12
#
# Hypothyroidism NOS changed from rank 12 to 5
#
# Signature 13:
#
# Initial top diseases:
# 1. Peripheral vascular disease, unspecified: 1.814
# 2. Streptococcus infection: 1.764
# 3. Joint effusions: 1.618
# 4. Cellulitis and abscess of arm/hand: 1.605
# 5. Other local infections of skin and subcutaneous tissue: 1.553
# 6. Carbuncle and furuncle: 1.478
# 7. Staphylococcus infections: 1.423
# 8. Stricture of artery: 1.334
# 9. Decubitus ulcer: 1.309
# 10. Phlebitis and thrombophlebitis of lower extremities: 1.277
#
# Final top diseases:
# 1. Joint effusions: 2.492
# 2. Peripheral vascular disease, unspecified: 2.450
# 3. Streptococcus infection: 2.045
# 4. Decubitus ulcer: 1.495
# 5. Stricture of artery: 1.300
# 6. Hyperlipidemia: 1.200
# 7. Staphylococcus infections: 1.128
# 8. Carbuncle and furuncle: 0.975
# 9. Cellulitis and abscess of arm/hand: 0.904
# 10. Chronic ulcer of skin: 0.646
#
# Decubitus ulcer changed from rank 9 to 4
#
# Stricture of artery changed from rank 8 to 5
#
# Hyperlipidemia changed from rank 12 to 6
#
# Cellulitis and abscess of arm/hand changed from rank 4 to 9
#
# Other local infections of skin and subcutaneous tissue changed from rank 5 to 12
#
# Signature 14:
#
# Initial top diseases:
# 1. GERD: 1.729
# 2. Diaphragmatic hernia: 1.691
# 3. Barrett's esophagus: 1.655
# 4. Ulcer of esophagus: 1.561
# 5. Reflux esophagitis: 1.527
# 6. Esophageal bleeding (varices/hemorrhage): 1.515
# 7. Stricture and stenosis of esophagus: 1.515
# 8. Gastric ulcer: 1.503
# 9. Benign neoplasm of other parts of digestive system: 1.497
# 10. Other specified gastritis: 1.493
#
# Final top diseases:
# 1. Reflux esophagitis: 3.166
# 2. GERD: 2.537
# 3. Other disorders of stomach and duodenum: 1.564
# 4. Barrett's esophagus: 1.506
# 5. Diaphragmatic hernia: 1.478
# 6. Esophagitis, GERD and related diseases: 1.258
# 7. Stricture and stenosis of esophagus: 1.203
# 8. Esophageal bleeding (varices/hemorrhage): 1.090
# 9. Benign neoplasm of other parts of digestive system: 1.071
# 10. Gastric ulcer: 0.966
#
# Ulcer of esophagus changed from rank 4 to 12
#
# Esophagitis, GERD and related diseases changed from rank 12 to 6
#
# Diaphragmatic hernia changed from rank 2 to 5
#
# Reflux esophagitis changed from rank 5 to 1
#
# Other disorders of stomach and duodenum changed from rank 12 to 3
#
# Signature 15:
#
# Initial top diseases:
# 1. Hypercholesterolemia: 1.659
# 2. Angina pectoris: 1.611
# 3. Essential hypertension: 1.597
# 4. Coronary atherosclerosis: 1.591
# 5. Unstable angina (intermediate coronary syndrome): 1.577
# 6. Other acute and subacute forms of ischemic heart disease: 1.414
# 7. Hyperlipidemia: 1.395
# 8. Myocardial infarction: 1.381
# 9. Other chronic ischemic heart disease, unspecified: 1.307
# 10. Other disorders of liver: -1.363
#
# Final top diseases:
# 1. Hypercholesterolemia: 2.898
# 2. Angina pectoris: 2.025
# 3. Coronary atherosclerosis: 1.817
# 4. Essential hypertension: 1.234
# 5. Myocardial infarction: 0.723
# 6. Colon cancer: 0.654
# 7. Other chronic ischemic heart disease, unspecified: 0.594
# 8. Other acute and subacute forms of ischemic heart disease: 0.488
# 9. Unstable angina (intermediate coronary syndrome): 0.317
# 10. Melanomas of skin: 0.287
#
# Hyperlipidemia changed from rank 7 to 12
#
# Colon cancer changed from rank 12 to 6
#
# Myocardial infarction changed from rank 8 to 5
#
# Unstable angina (intermediate coronary syndrome) changed from rank 5 to 9
#
# Signature 16:
#
# Initial top diseases:
# 1. Chronic renal failure [CKD]: 1.835
# 2. Candidiasis: 1.725
# 3. Orthostatic hypotension: 1.717
# 4. Disorders of calcium/phosphorus metabolism: 1.660
# 5. E. coli: 1.556
# 6. Other anemias: 1.535
# 7. Pyelonephritis: 1.533
# 8. Hypotension NOS: 1.500
# 9. Acute renal failure: 1.496
# 10. Other diseases of respiratory system, NEC: 1.473
#
# Final top diseases:
# 1. Orthostatic hypotension: 2.126
# 2. Gram negative septicemia: 2.007
# 3. Other anemias: 1.980
# 4. Pyelonephritis: 1.941
# 5. Chronic renal failure [CKD]: 1.937
# 6. Acute renal failure: 1.933
# 7. Candidiasis: 1.877
# 8. Urinary tract infection: 1.560
# 9. Acidosis: 1.558
# 10. Hypovolemia: 1.546
#
# Acidosis changed from rank 12 to 9
#
# Other anemias changed from rank 6 to 3
#
# Hypotension NOS changed from rank 8 to 12
#
# Pyelonephritis changed from rank 7 to 4
#
# Chronic renal failure [CKD] changed from rank 1 to 5
#
# Acute renal failure changed from rank 9 to 6
#
# Gram negative septicemia changed from rank 12 to 2
#
# Disorders of calcium/phosphorus metabolism changed from rank 4 to 12
#
# E. coli changed from rank 5 to 12
#
# Candidiasis changed from rank 2 to 7
#
# Urinary tract infection changed from rank 12 to 8
#
# Signature 17:
#
# Initial top diseases:
# 1. Stricture/obstruction of ureter: 1.705
# 2. Renal colic: 1.599
# 3. Calculus of ureter: 1.544
# 4. Hydronephrosis: 1.488
# 5. Calculus of kidney: 1.480
# 6. Ingrowing nail: -1.334
# 7. Acidosis: -1.350
# 8. Non-Hodgkins lymphoma: -1.352
# 9. Parkinson's disease: -1.358
# 10. Cholecystitis without cholelithiasis: -1.358
#
# Final top diseases:
# 1. Calculus of ureter: 2.444
# 2. Renal colic: 2.370
# 3. Stricture/obstruction of ureter: 2.005
# 4. Calculus of kidney: 1.161
# 5. Rheumatoid arthritis: 0.829
# 6. Melanomas of skin: 0.693
# 7. Hydronephrosis: 0.542
# 8. Neoplasm of unspecified nature of digestive system: 0.477
# 9. Disorders of uterus, NEC: 0.208
# 10. Carbuncle and furuncle: 0.168
#
# Acidosis changed from rank 7 to 12
#
# Non-Hodgkins lymphoma changed from rank 8 to 12
#
# Melanomas of skin changed from rank 12 to 6
#
# Neoplasm of unspecified nature of digestive system changed from rank 12 to 8
#
# Ingrowing nail changed from rank 6 to 12
#
# Disorders of uterus, NEC changed from rank 12 to 9
#
# Parkinson's disease changed from rank 9 to 12
#
# Rheumatoid arthritis changed from rank 12 to 5
#
# Hydronephrosis changed from rank 4 to 7
#
# Signature 18:
#
# Initial top diseases:
# 1. Hemorrhage of gastrointestinal tract: 1.854
# 2. Benign neoplasm of colon: 1.723
# 3. Diverticulosis: 1.692
# 4. Iron deficiency anemias, unspecified or not due to blood loss: 1.623
# 5. Anal and rectal conditions: 1.610
# 6. Colon cancer: 1.559
# 7. Other intestinal obstruction: 1.533
# 8. Ulcerative colitis: 1.533
# 9. Regional enteritis: 1.525
# 10. Neoplasm of unspecified nature of digestive system: 1.518
#
# Final top diseases:
# 1. Anal and rectal conditions: 3.230
# 2. Colon cancer: 2.517
# 3. Anal and rectal polyp: 2.353
# 4. Hemorrhage of gastrointestinal tract: 2.106
# 5. Benign neoplasm of colon: 2.101
# 6. Iron deficiency anemias, unspecified or not due to blood loss: 2.093
# 7. Diverticulosis: 2.028
# 8. Neoplasm of unspecified nature of digestive system: 1.811
# 9. Noninfectious gastroenteritis: 1.585
# 10. Ventral hernia: 1.481
#
# Diverticulosis changed from rank 3 to 7
#
# Other intestinal obstruction changed from rank 7 to 12
#
# Colon cancer changed from rank 6 to 2
#
# Regional enteritis changed from rank 9 to 12
#
# Benign neoplasm of colon changed from rank 2 to 5
#
# Hemorrhage of gastrointestinal tract changed from rank 1 to 4
#
# Anal and rectal conditions changed from rank 5 to 1
#
# Ulcerative colitis changed from rank 8 to 12
#
# Anal and rectal polyp changed from rank 12 to 3
#
# Noninfectious gastroenteritis changed from rank 12 to 9
#
# Signature 19:
#
# Initial top diseases:
# 1. Bladder neck obstruction: 1.673
# 2. Chronic prostatitis: 1.632
# 3. Urethral stricture (not specified as infectious): 1.517
# 4. Other disorders of bladder: 1.507
# 5. Other disorders of prostate: 1.412
# 6. Chronic cystitis: 1.405
# 7. Cancer of prostate: 1.399
# 8. Malignant neoplasm of bladder: 1.399
# 9. Urinary incontinence: 1.394
# 10. Hyperplasia of prostate: 1.334
#
# Final top diseases:
# 1. Cystitis: 2.072
# 2. Other disorders of bladder: 1.978
# 3. Chronic prostatitis: 1.937
# 4. Urethral stricture (not specified as infectious): 1.766
# 5. Bladder neck obstruction: 1.642
# 6. Other disorders of prostate: 1.542
# 7. Functional disorders of bladder: 1.328
# 8. Urinary incontinence: 1.266
# 9. Chronic cystitis: 1.079
# 10. Malignant neoplasm of bladder: 1.069
#
# Bladder neck obstruction changed from rank 1 to 5
#
# Cancer of prostate changed from rank 7 to 12
#
# Cystitis changed from rank 12 to 1
#
# Chronic cystitis changed from rank 6 to 9
#
# Functional disorders of bladder changed from rank 12 to 7

# %%
def visualize_predictions(model, Y, event_times):
    with torch.no_grad():
        pi_pred, _, _ = model.forward()
        pi_pred = pi_pred.cpu().numpy()
    
    N, D, T = Y.shape
    at_risk = np.zeros_like(Y, dtype=bool)
    for n in range(N):
        for d in range(D):
            at_risk[n,d,:event_times[n,d]] = True
    
    # Get predictions
    event_probs = pi_pred[Y == 1 & at_risk]
    nonevent_probs = pi_pred[Y == 0 & at_risk]
    
    plt.figure(figsize=(15, 5))
    
    # 1. Density plot of predictions
    plt.subplot(131)
    plt.hist(event_probs, bins=50, density=True, alpha=0.5, label='Events', color='red')
    plt.hist(nonevent_probs, bins=50, density=True, alpha=0.5, label='Non-events', color='blue')
    plt.xlabel('Predicted Probability')
    plt.ylabel('Density')
    plt.title('Distribution of Predictions')
    plt.legend()
    
    # 2. ROC curve
    from sklearn.metrics import roc_curve, auc
    y_true = np.concatenate([np.ones_like(event_probs), np.zeros_like(nonevent_probs)])
    y_pred = np.concatenate([event_probs, nonevent_probs])
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    roc_auc = auc(fpr, tpr)
    
    plt.subplot(132)
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend()
    
    # 3. Calibration plot
    from sklearn.calibration import calibration_curve
    prob_true, prob_pred = calibration_curve(y_true, y_pred, n_bins=10)
    
    plt.subplot(133)
    plt.plot(prob_pred, prob_true, marker='o', label='Model')
    plt.plot([0, 1], [0, 1], linestyle='--', label='Perfect calibration')
    plt.xlabel('Mean predicted probability')
    plt.ylabel('Empirical probability')
    plt.title('Calibration Plot')
    plt.legend()
    
    plt.tight_layout()
    plt.show()
    
    # Print summary statistics
    print(f"Average pi for events: {event_probs.mean():.4f} (std: {event_probs.std():.4f})")
    print(f"Average pi for non-events: {nonevent_probs.mean():.4f} (std: {nonevent_probs.std():.4f})")
    print(f"AUC: {roc_auc:.4f}")
    
    return event_probs, nonevent_probs, roc_auc

# %%
visualize_predictions(model, Y, E)
# Out:
# Average pi for events: 0.0010 (std: 0.0017)
# Average pi for non-events: 0.0004 (std: 0.0009)
# AUC: 0.6917
# (array([5.6849360e-05, 5.1999676e-05, 4.6067595e-05, ..., 1.1411139e-06,
#         1.8293485e-07, 9.9999999e-09], dtype=float32),
#  array([1.e-08, 1.e-08, 1.e-08, ..., 1.e-08, 1.e-08, 1.e-08], dtype=float32),
#  0.6917139378216937)

# %%
def plot_signature_temporal_patterns(model, disease_names, n_top=10, selected_signatures=None):
    """
    Show temporal patterns of top diseases for each signature
    """
    #phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    #phi_avg = phi.mean(axis=2)  # Average over time

     # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Select which signatures to plot
    if selected_signatures is None:
        selected_signatures = range(phi_avg.shape[0])
    
    # Create subplots for each selected signature
    n_sigs = len(selected_signatures)
    fig, axes = plt.subplots(n_sigs, 1, figsize=(15, 5*n_sigs))
    if n_sigs == 1:
        axes = [axes]
    
    for i, k in enumerate(selected_signatures):
        # Get top diseases
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        # Plot temporal patterns
        ax = axes[i]
        for idx in top_indices:
            temporal_pattern = phi[k, idx, :]
            ax.plot(temporal_pattern, label=disease_names[idx])
        
        ax.set_title(f'Signature {k} - Top Disease Temporal Patterns')
        ax.set_xlabel('Time')
        ax.set_ylabel('Phi Value')
        ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# First show the top diseases


# Then show their temporal patterns
# You can select specific signatures of interest:
plot_signature_temporal_patterns(model, disease_names_list, selected_signatures=[0,1,14,15,16,13,17])

# %%
# 1. Get predictions and actual values
predicted = model.forward()
pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
pi_pred = pi_pred.cpu().detach().numpy()
Y = model.Y.cpu().detach().numpy()

# 2. Calculate marginal risks directly
# Assuming dimensions are: [N, D, T] for both Y and pi_pred
observed_risk = Y.mean(axis=0).flatten()  # average across individuals
predicted_risk = pi_pred.mean(axis=0).flatten()

# 3. Apply calibration
scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
calibrated_risk = predicted_risk * scale_factor

# 4. Plot
plt.figure(figsize=(12, 5))

# Original predictions
plt.subplot(121)
plt.scatter(observed_risk, predicted_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Original Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Predicted Risk')

# Calibrated predictions
plt.subplot(122)
plt.scatter(observed_risk, calibrated_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Calibrated Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Calibrated Risk')

plt.tight_layout()
plt.show()

# Print statistics
print(f"Mean observed risk: {np.mean(observed_risk):.6f}")
print(f"Mean predicted risk (original): {np.mean(predicted_risk):.6f}")
print(f"Mean predicted risk (calibrated): {np.mean(calibrated_risk):.6f}")
print(f"Calibration scale factor: {scale_factor:.3f}")
# Out:
# Mean observed risk: 0.000613
# Mean predicted risk (original): 0.000320
# Mean predicted risk (calibrated): 0.000613
# Calibration scale factor: 1.917

# %%
ss_res = np.sum((observed_risk - predicted_risk) ** 2)
ss_tot = np.sum((observed_risk - np.mean(observed_risk)) ** 2)
r2 = 1 - (ss_res / ss_tot)

print(f"R^2: {r2:.3f}")
# Out:
# R^2: 0.619
