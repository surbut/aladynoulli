# %%
# %load_ext autoreload
# %autoreload 2

from cluster_g_logit_init_acceptpsi import *


# %autoreload 2
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering  # Add this import

def load_model_essentials(base_path='/Users/sarahurbut/Dropbox (Personal)/data_for_running/'):
    """
    Load all essential components
    """
    print("Loading components...")
    
    # Load large matrices
    Y = torch.load(base_path + 'Y_tensor.pt')
    E = torch.load(base_path + 'E_matrix.pt')
    G = torch.load(base_path + 'G_matrix.pt')
    
    # Load other components
    essentials = torch.load(base_path + 'model_essentials.pt')
    
    print("Loaded all components successfully!")
    
    return Y, E, G, essentials

# Load and initialize model:
Y, E, G, essentials = load_model_essentials()
# Out:
# Loading components...
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_31683/1069408875.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Y = torch.load(base_path + 'Y_tensor.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_31683/1069408875.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   E = torch.load(base_path + 'E_matrix.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_31683/1069408875.py:27: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   G = torch.load(base_path + 'G_matrix.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_31683/1069408875.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   essentials = torch.load(base_path + 'model_essentials.pt')
# Loaded all components successfully!

# %%
def subset_data(Y, E, G, n_samples=50000, seed=42):
    """
    Subset the data to n_samples individuals while maintaining consistency
    
    Args:
        Y: tensor of shape [N, D, T]
        E: tensor of shape [N, D]
        G: tensor of shape [N, P]
        n_samples: number of individuals to keep
        seed: random seed for reproducibility
    
    Returns:
        Y_sub, E_sub, G_sub: subsetted tensors
    """
    torch.manual_seed(seed)
    
    # Get total number of individuals
    N = Y.shape[0]
    
    # Randomly select n_samples indices
    indices = torch.randperm(N)[:n_samples]
    
    # Subset all matrices using the same indices
    Y_sub = Y[indices]
    E_sub = E[indices]
    G_sub = G[indices]
    
    print(f"Original shapes: Y={Y.shape}, E={E.shape}, G={G.shape}")
    print(f"New shapes: Y={Y_sub.shape}, E={E_sub.shape}, G={G_sub.shape}")
    
    return Y_sub, E_sub, G_sub, indices

# Subset the data
Y_100k, E_100k, G_100k, indices = subset_data(Y, E, G, n_samples=10000)

torch.manual_seed(42)
np.random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Initialize model with subsetted data
# Out:
# Original shapes: Y=torch.Size([407878, 348, 52]), E=torch.Size([407878, 348]), G=torch.Size([407878, 36])
# New shapes: Y=torch.Size([10000, 348, 52]), E=torch.Size([10000, 348]), G=torch.Size([10000, 36])

# %%
# When initializing the model:
original_G = G_100k.clone().detach()  # Store the original G - proper tensor copy

# Now in your batch run, load and verify:
initial_psi = torch.load('initial_psi_400k.pt')
initial_clusters = torch.load('initial_clusters_400k.pt')

original_cluster_sizes = {}
unique, counts = np.unique(initial_clusters, return_counts=True)
for k, count in zip(unique, counts):
    original_cluster_sizes[k] = count
print("\nOriginal cluster sizes:")
for k, count in original_cluster_sizes.items():
    print(f"Cluster {k}: {count} diseases")
# Out:
# Original cluster sizes:
# Cluster 0: 16 diseases
# Cluster 1: 21 diseases
# Cluster 2: 15 diseases
# Cluster 3: 82 diseases
# Cluster 4: 5 diseases
# Cluster 5: 7 diseases
# Cluster 6: 8 diseases
# Cluster 7: 22 diseases
# Cluster 8: 28 diseases
# Cluster 9: 12 diseases
# Cluster 10: 11 diseases
# Cluster 11: 8 diseases
# Cluster 12: 7 diseases
# Cluster 13: 13 diseases
# Cluster 14: 10 diseases
# Cluster 15: 5 diseases
# Cluster 16: 29 diseases
# Cluster 17: 17 diseases
# Cluster 18: 9 diseases
# Cluster 19: 23 diseases
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_31683/685643090.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_psi = torch.load('initial_psi_400k.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_31683/685643090.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_clusters = torch.load('initial_clusters_400k.pt')

# %%
print("Initial psi stats:")
print(f"Shape: {initial_psi.shape}")
print(f"Range: [{initial_psi.min():.2f}, {initial_psi.max():.2f}]")
print(f"Number of positive values: {(initial_psi > 0).sum().item()}")
# Out:
# Initial psi stats:
# Shape: torch.Size([20, 348])
# Range: [-2.04, 1.33]
# Number of positive values: 348

# %%
### did not run with the new initial, we used built in clusters from the model init with the 1/2 clustering appraohc. 
torch.manual_seed(222)
np.random.seed(222)
if torch.cuda.is_available():
    torch.cuda.manual_seed(222)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Now in your batch run, load and verify:
initial_psi = torch.load('initial_psi_400k.pt')
initial_clusters = torch.load('initial_clusters_400k.pt')

model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(
    N=Y_100k.shape[0],
    D=Y_100k.shape[1],
    T=Y_100k.shape[2],
    K=essentials['K'],
    P=essentials['P'],
    G=G_100k,
    Y=Y_100k,
    prevalence_t=essentials['prevalence_t']
)

# Initialize with saved parameters
model.initialize_params(true_psi=initial_psi)
model.clusters = initial_clusters
# Out:
# Lambda kernel condition number: 56314924.00
# Phi kernel condition number: 59684776.00
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_31683/3728260001.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_psi = torch.load('initial_psi_400k.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_31683/3728260001.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_clusters = torch.load('initial_clusters_400k.pt')
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G_scaled, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi.py:35: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.Y = torch.tensor(Y, dtype=torch.float32)
# Cluster Sizes:
# Cluster 0: 11 diseases
# Cluster 1: 74 diseases
# Cluster 2: 30 diseases
# Cluster 3: 7 diseases
# Cluster 4: 23 diseases
# Cluster 5: 10 diseases
# Cluster 6: 17 diseases
# Cluster 7: 14 diseases
# Cluster 8: 21 diseases
# Cluster 9: 5 diseases
# Cluster 10: 8 diseases
# Cluster 11: 9 diseases
# Cluster 12: 12 diseases
# Cluster 13: 31 diseases
# Cluster 14: 25 diseases
# Cluster 15: 5 diseases
# Cluster 16: 9 diseases
# Cluster 17: 17 diseases
# Cluster 18: 11 diseases
# Cluster 19: 9 diseases
# Initialization complete!
#
# Using true psi from simulation
# Initialization complete!

# %%
print("\nVerifying cluster sizes match:")
new_unique, new_counts = np.unique(model.clusters, return_counts=True)
for k, count in zip(new_unique, new_counts):
    print(f"Cluster {k}: {count} diseases (Original: {original_cluster_sizes[k]} diseases)")

# Verify psi values match
print("\nVerifying psi values match:")
print(f"Psi values match: {torch.allclose(model.psi, initial_psi)}")
# Out:
# Verifying cluster sizes match:
# Cluster 0: 16 diseases (Original: 16 diseases)
# Cluster 1: 21 diseases (Original: 21 diseases)
# Cluster 2: 15 diseases (Original: 15 diseases)
# Cluster 3: 82 diseases (Original: 82 diseases)
# Cluster 4: 5 diseases (Original: 5 diseases)
# Cluster 5: 7 diseases (Original: 7 diseases)
# Cluster 6: 8 diseases (Original: 8 diseases)
# Cluster 7: 22 diseases (Original: 22 diseases)
# Cluster 8: 28 diseases (Original: 28 diseases)
# Cluster 9: 12 diseases (Original: 12 diseases)
# Cluster 10: 11 diseases (Original: 11 diseases)
# Cluster 11: 8 diseases (Original: 8 diseases)
# Cluster 12: 7 diseases (Original: 7 diseases)
# Cluster 13: 13 diseases (Original: 13 diseases)
# Cluster 14: 10 diseases (Original: 10 diseases)
# Cluster 15: 5 diseases (Original: 5 diseases)
# Cluster 16: 29 diseases (Original: 29 diseases)
# Cluster 17: 17 diseases (Original: 17 diseases)
# Cluster 18: 9 diseases (Original: 9 diseases)
# Cluster 19: 23 diseases (Original: 23 diseases)
#
# Verifying psi values match:
# Psi values match: True

# %%
def calculate_calibration_stats(model, Y):
    """Calculate calibration stats for a model"""
    with torch.no_grad():
        predicted = model.forward()
        pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
        pi_pred = pi_pred.cpu().detach().numpy()
        Y_np = Y.cpu().detach().numpy() if torch.is_tensor(Y) else Y
        
        # Convert to numpy and calculate means
        observed_risk = Y_np.mean(axis=0).flatten()
        predicted_risk = pi_pred.mean(axis=0).flatten()
        
        scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
        calibrated_risk = predicted_risk * scale_factor
        
        ss_res = np.sum((observed_risk - calibrated_risk) ** 2)
        ss_tot = np.sum((observed_risk - np.mean(observed_risk)) ** 2)
        r2 = 1 - (ss_res / ss_tot)
        
        return r2, scale_factor, observed_risk, predicted_risk, calibrated_risk

# %%
# 1. Global R² (we know it's 0.70)
print(f"Global model R² (known): 0.70")


r2_global, scale_global, obs_global, pred_global, cal_global = calculate_calibration_stats(model, Y_100k)
print(f"\nBatch model with global psi:")
print(f"R²: {r2_global:.3f}")
print(f"Calibration scale factor: {scale_global:.3f}")
# Out:
# Global model R² (known): 0.70
#
# Batch model with global psi:
# R²: 0.663
# Calibration scale factor: 2.700

# %%
# Plot both versions:
model.plot_genetic_scores(original_G)
print(model.G[:,3].mean())

print(original_G[:,3].mean())


# Check G matrix scaling
G_mean = model.G.mean(dim=0)
G_std = model.G.std(dim=0)
print("\nG matrix scaling check:")
print(f"Mean should be ~0: {G_mean.abs().max().item():.6f}")
print(f"Std should be ~1: {(G_std - 1).abs().max().item():.6f}")
# Out:
# Genetic Components Summary Statistics:
# Component  Original Mean Original Std  Trans. Mean  Trans. Std
# ------------------------------------------------------------
# 1                 -0.001        0.999        0.000       1.000
# 2                  0.011        1.003       -0.000       1.000
# 3                  0.012        0.994        0.000       1.000
# 4                  0.007        1.002       -0.000       1.000
# 5                 -0.007        0.994       -0.000       1.000
# 6                  0.008        1.006       -0.000       1.000
# 7                  0.031        0.994       -0.000       1.000
# 8                  0.003        1.009        0.000       1.000
# 9                  0.006        1.014        0.000       1.000
# 10                 0.012        0.999        0.000       1.000
# 11                 0.008        1.000       -0.000       1.000
# 12                 0.012        0.999       -0.000       1.000
# 13                -0.005        0.989       -0.000       1.000
# 14                 0.011        1.012        0.000       1.000
# 15                 0.005        0.998        0.000       1.000
# 16                -0.002        0.995       -0.000       1.000
# 17                 0.008        0.996        0.000       1.000
# 18                -0.017        0.999       -0.000       1.000
# 19                 0.005        1.018       -0.000       1.000
# 20                 0.002        1.000        0.000       1.000
# 21                 0.011        1.011       -0.000       1.000
# 22                 0.010        1.010        0.000       1.000
# 23                 0.000        1.007        0.000       1.000
# 24                 0.005        1.019        0.000       1.000
# 25                -0.013        1.003       -0.000       1.000
# 26                 0.001        0.996        0.000       1.000
# 27                -0.013        1.002        0.000       1.000
# 28                 0.015        1.003        0.000       1.000
# 29                 0.015        1.019       -0.000       1.000
# 30                -0.001        0.997        0.000       1.000
# 31                -0.011        0.994       -0.000       1.000
# 32                -0.002        0.990       -0.000       1.000
# 33                -0.014        1.008       -0.000       1.000
# 34                 0.009        1.013        0.000       1.000
# 35                 0.007        0.989        0.000       1.000
# 36                 0.028        0.990       -0.000       1.000
# tensor(-1.9073e-10)
# tensor(0.0074)
#
# G matrix scaling check:
# Mean should be ~0: 0.000000
# Std should be ~1: 0.000000

# %%
initial_gamma = model.gamma.detach().clone()
initial_phi = model.phi.detach().clone()
initial_lambda = model.lambda_.detach().clone()
initial_psi = model.psi.detach().clone()

# %%
history = model.fit(E_100k, num_epochs=2, learning_rate=1e-4, lambda_reg=1e-2)
# Out:
# Starting training...
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi.py:200: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   event_times_tensor = torch.tensor(event_times, dtype=torch.long)
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 0
# Loss: 1107.0331
# Psi gradient stats:
# Mean: -2.1786e-05
# Std:  4.7510e-03
# Max:  1.6340e-02
# Min:  -2.0144e-02
# Epoch 0, Loss: 1107.0331, Gradients - Lambda: 5.545e-01, Phi: 1.513e+01, Gamma: 5.400e-02, Psi: 2.014e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 1
# Loss: 960.4230
# Psi gradient stats:
# Mean: -2.2020e-05
# Std:  4.7429e-03
# Max:  1.6305e-02
# Min:  -2.0080e-02
# Epoch 1, Loss: 960.4230, Gradients - Lambda: 5.296e-01, Phi: 1.442e+01, Gamma: 5.334e-02, Psi: 2.008e-02
#
# Estimated total training time: 1.2 minutes

# %%
import matplotlib.pyplot as plt

# Create figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Plot loss
ax1.plot(history['loss'])
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('Training Loss')
ax1.grid(True)

# Plot gradients
ax2.plot(history['max_grad_lambda'], label='Lambda')
ax2.plot(history['max_grad_phi'], label='Phi')
ax2.plot(history['max_grad_gamma'], label='Gamma')
ax2.plot(history['max_grad_psi'], label='Psi')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Max Gradient Magnitude')
ax2.set_title('Parameter Gradients')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

# %%
disease_names=essentials['disease_names']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Convert gamma tensors to numpy arrays
initial_gamma_np = initial_gamma.detach().numpy()
final_gamma_np = model.gamma.detach().numpy()

# Create a figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plot initial gamma
sns.heatmap(initial_gamma_np, ax=ax1, cmap='RdBu_r', center=0)
ax1.set_title('Initial Gamma')

# Plot final gamma
sns.heatmap(final_gamma_np, ax=ax2, cmap='RdBu_r', center=0)
ax2.set_title('Final Gamma')

# Add a title to the figure
plt.suptitle('Comparison of Initial vs Final Gamma Values', fontsize=16)

# You can also add a colorbar
plt.tight_layout()

# To see the actual difference, you can also create a difference heatmap
plt.figure(figsize=(10, 8))
diff = final_gamma_np - initial_gamma_np
sns.heatmap(diff, cmap='RdBu_r', center=0)
plt.title('Difference (Final - Initial Gamma)')
plt.show()

# Print some summary statistics
print(f"Mean absolute difference: {np.abs(diff).mean():.4f}")
print(f"Max absolute difference: {np.abs(diff).max():.4f}")
print(f"Standard deviation of differences: {np.std(diff):.4f}")
# Out:
# Mean absolute difference: 0.0002
# Max absolute difference: 0.0002
# Standard deviation of differences: 0.0002

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Convert phi tensors to numpy arrays
initial_phi_np = initial_phi.detach().numpy()  # Shape: (K, D, T)
final_phi_np = model.phi.detach().numpy()

# Take mean over time dimension
initial_phi_mean = initial_phi_np.mean(axis=2)  # Shape: (K, D)
final_phi_mean = final_phi_np.mean(axis=2)

# Create figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plot initial phi (averaged over time)
sns.heatmap(initial_phi_mean, ax=ax1, cmap='RdBu_r', center=0)
ax1.set_title('Initial Phi (Mean over Time)')
ax1.set_xlabel('Disease')
ax1.set_ylabel('Signature')

# Plot final phi (averaged over time)
sns.heatmap(final_phi_mean, ax=ax2, cmap='RdBu_r', center=0)
ax2.set_title('Final Phi (Mean over Time)')
ax2.set_xlabel('Disease')
ax2.set_ylabel('Signature')

plt.suptitle('Comparison of Initial vs Final Phi Values (Averaged over Time)', fontsize=16)
plt.tight_layout()

# Plot difference
plt.figure(figsize=(10, 8))
diff_mean = final_phi_mean - initial_phi_mean
sns.heatmap(diff_mean, cmap='RdBu_r', center=0)
plt.title('Difference in Phi (Final - Initial), Mean over Time')
plt.xlabel('Disease')
plt.ylabel('Signature')
plt.show()

# Print summary statistics for both full tensor and time-averaged differences
print("Full tensor statistics:")
diff_full = final_phi_np - initial_phi_np
print(f"Mean absolute difference: {np.abs(diff_full).mean():.4f}")
print(f"Max absolute difference: {np.abs(diff_full).max():.4f}")
print(f"Standard deviation of differences: {np.std(diff_full):.4f}")

print("\nTime-averaged statistics:")
print(f"Mean absolute difference: {np.abs(diff_mean).mean():.4f}")
print(f"Max absolute difference: {np.abs(diff_mean).max():.4f}")
print(f"Standard deviation of differences: {np.std(diff_mean):.4f}")

# Optionally, look at temporal variation
temporal_std = np.std(diff_full, axis=2)
plt.figure(figsize=(10, 8))
sns.heatmap(temporal_std, cmap='viridis')
plt.title('Standard Deviation of Changes Across Time')
plt.xlabel('Disease')
plt.ylabel('Signature')
plt.show()
# Out:
# Full tensor statistics:
# Mean absolute difference: 0.0002
# Max absolute difference: 0.0002
# Standard deviation of differences: 0.0002
#
# Time-averaged statistics:
# Mean absolute difference: 0.0000
# Max absolute difference: 0.0001
# Standard deviation of differences: 0.0000

# %%
Y_global=Y

# %%
Y_global.shape
# Out:
# torch.Size([407878, 348, 52])

# %%
# 1. Get predictions and actual values
predicted = model.forward()
pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
pi_pred = pi_pred.cpu().detach().numpy()
Y = model.Y.cpu().detach().numpy()

# 2. Calculate marginal risks directly
# Assuming dimensions are: [N, D, T] for both Y and pi_pred
observed_risk = Y.mean(axis=0).flatten()  # average across individuals
predicted_risk = pi_pred.mean(axis=0).flatten()

# 3. Apply calibration
scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
calibrated_risk = predicted_risk * scale_factor

# 4. Plot
plt.figure(figsize=(12, 5))

# Original predictions
plt.subplot(121)
plt.scatter(observed_risk, predicted_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Original Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Predicted Risk')

# Calibrated predictions
plt.subplot(122)
plt.scatter(observed_risk, calibrated_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Calibrated Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Calibrated Risk')

plt.tight_layout()
plt.show()

# Print statistics
print(f"Mean observed risk: {np.mean(observed_risk):.6f}")
print(f"Mean predicted risk (original): {np.mean(predicted_risk):.6f}")
print(f"Mean predicted risk (calibrated): {np.mean(calibrated_risk):.6f}")
print(f"Calibration scale factor: {scale_factor:.3f}")
# Out:
# Mean observed risk: 0.000451
# Mean predicted risk (original): 0.000167
# Mean predicted risk (calibrated): 0.000451
# Calibration scale factor: 2.700

# %%
ss_res = np.sum((observed_risk - calibrated_risk) ** 2)
ss_tot = np.sum((observed_risk - np.mean(observed_risk)) ** 2)
r2 = 1 - (ss_res / ss_tot)

print(f"R^2: {r2:.3f}")
# Out:
# R^2: 0.663

# %%
def plot_signature_top_diseases_centered(model, disease_names, n_top=10):
    """
    Show top diseases for each signature, centered relative to prevalence
    """
    # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # For each signature, get top diseases
    for k in range(phi_avg.shape[0]):
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        print(f"\nTop {n_top} diseases in Signature {k} (relative to baseline):")
        for idx in top_indices:
            avg_effect = scores[idx]
            temporal_std = np.std(phi_centered[k, idx, :])
            # Convert to odds ratio for interpretability
            odds_ratio = np.exp(avg_effect)
            print(f"{disease_names[idx]}: effect={avg_effect:.3f} (OR={odds_ratio:.2f}), std={temporal_std:.3f}")

# Run visualization
plot_signature_top_diseases_centered(model, essentials['disease_names'])
# Out:
# Top 10 diseases in Signature 0 (relative to baseline):
# Rheumatic disease of the heart valves: effect=2.386 (OR=10.87), std=0.266
# Pericarditis: effect=2.060 (OR=7.84), std=0.486
# Paroxysmal supraventricular tachycardia: effect=1.899 (OR=6.68), std=0.267
# Heart failure NOS: effect=1.798 (OR=6.04), std=0.251
# Cardiomegaly: effect=1.796 (OR=6.03), std=0.451
# Congenital anomalies of great vessels: effect=1.318 (OR=3.74), std=0.810
# Other forms of chronic heart disease: effect=1.302 (OR=3.68), std=0.287
# Primary/intrinsic cardiomyopathies: effect=1.204 (OR=3.33), std=0.454
# Aortic valve disease: effect=1.199 (OR=3.32), std=0.539
# Pleurisy; pleural effusion: effect=1.177 (OR=3.24), std=0.730
#
# Top 10 diseases in Signature 1 (relative to baseline):
# Synovitis and tenosynovitis: effect=1.810 (OR=6.11), std=0.484
# Hallux valgus (Bunion): effect=1.696 (OR=5.45), std=0.923
# Other acquired deformities of limbs: effect=1.491 (OR=4.44), std=0.660
# Osteoarthritis; localized: effect=1.230 (OR=3.42), std=0.534
# Internal derangement of knee: effect=1.129 (OR=3.09), std=0.268
# Peripheral enthesopathies and allied syndromes: effect=1.062 (OR=2.89), std=0.285
# Osteoarthrosis NOS: effect=0.946 (OR=2.58), std=0.272
# Enthesopathy: effect=0.927 (OR=2.53), std=0.779
# Hallux rigidus: effect=0.910 (OR=2.48), std=0.393
# Joint effusions: effect=0.768 (OR=2.16), std=0.733
#
# Top 10 diseases in Signature 2 (relative to baseline):
# Diaphragmatic hernia: effect=2.320 (OR=10.18), std=0.308
# Duodenal ulcer: effect=2.108 (OR=8.23), std=0.633
# Benign neoplasm of other parts of digestive system: effect=1.949 (OR=7.02), std=0.334
# Esophagitis, GERD and related diseases: effect=1.669 (OR=5.31), std=0.314
# Other specified gastritis: effect=1.403 (OR=4.07), std=0.798
# Reflux esophagitis: effect=1.294 (OR=3.65), std=0.326
# Other disorders of stomach and duodenum: effect=1.270 (OR=3.56), std=0.683
# Gastric ulcer: effect=1.070 (OR=2.91), std=0.466
# Stricture and stenosis of esophagus: effect=1.031 (OR=2.80), std=0.843
# Ulcer of esophagus: effect=1.002 (OR=2.72), std=0.579
#
# Top 10 diseases in Signature 3 (relative to baseline):
# Polymyalgia Rheumatica: effect=2.560 (OR=12.93), std=0.499
# Malignant neoplasm of kidney, except pelvis: effect=2.513 (OR=12.34), std=0.448
# Chronic periodontitis: effect=2.431 (OR=11.37), std=0.740
# Allergic rhinitis: effect=2.316 (OR=10.14), std=0.749
# Raynaud's syndrome: effect=2.311 (OR=10.08), std=0.577
# Ganglion and cyst of synovium, tendon, and bursa: effect=2.287 (OR=9.85), std=0.813
# Facial nerve disorders [CN7]: effect=2.158 (OR=8.65), std=0.147
# Bursitis: effect=2.151 (OR=8.59), std=1.079
# Diseases and other conditions of the tongue: effect=2.141 (OR=8.50), std=0.143
# Contracture of palmar fascia [Dupuytren's disease]: effect=2.140 (OR=8.50), std=0.283
#
# Top 10 diseases in Signature 4 (relative to baseline):
# Chronic sinusitis: effect=1.662 (OR=5.27), std=0.399
# Septal Deviations/Turbinate Hypertrophy: effect=1.532 (OR=4.63), std=0.341
# Chronic pharyngitis and nasopharyngitis: effect=0.512 (OR=1.67), std=0.434
# Other upper respiratory disease: effect=0.478 (OR=1.61), std=0.600
# Sepsis: effect=0.244 (OR=1.28), std=0.230
# Cervicitis and endocervicitis: effect=-0.017 (OR=0.98), std=0.508
# Viral warts & HPV: effect=-0.026 (OR=0.97), std=0.795
# Nasal polyps: effect=-0.096 (OR=0.91), std=0.799
# Sleep disorders: effect=-0.433 (OR=0.65), std=0.322
# Hypertensive chronic kidney disease: effect=-0.457 (OR=0.63), std=0.857
#
# Top 10 diseases in Signature 5 (relative to baseline):
# Coronary atherosclerosis: effect=2.187 (OR=8.91), std=0.452
# Unstable angina (intermediate coronary syndrome): effect=2.029 (OR=7.61), std=1.190
# Hypercholesterolemia: effect=1.557 (OR=4.75), std=0.412
# Myocardial infarction: effect=1.436 (OR=4.20), std=0.639
# Other chronic ischemic heart disease, unspecified: effect=1.358 (OR=3.89), std=0.493
# Other acute and subacute forms of ischemic heart disease: effect=1.012 (OR=2.75), std=0.942
# Hypopotassemia: effect=0.393 (OR=1.48), std=0.537
# Symptoms and disorders of the joints: effect=0.263 (OR=1.30), std=1.533
# Angina pectoris: effect=0.151 (OR=1.16), std=0.833
# Hypoglycemia: effect=-0.142 (OR=0.87), std=0.521
#
# Top 10 diseases in Signature 6 (relative to baseline):
# Secondary malignancy of bone: effect=3.532 (OR=34.18), std=0.566
# Malignant neoplasm, other: effect=2.686 (OR=14.67), std=0.524
# Secondary malignant neoplasm of digestive systems: effect=1.500 (OR=4.48), std=0.244
# Secondary malignancy of respiratory organs: effect=1.438 (OR=4.21), std=0.555
# Secondary malignant neoplasm of liver: effect=0.655 (OR=1.93), std=0.075
# Secondary malignancy of lymph nodes: effect=0.633 (OR=1.88), std=0.133
# Urinary incontinence: effect=0.507 (OR=1.66), std=0.390
# Cancer of bronchus; lung: effect=0.405 (OR=1.50), std=0.719
# Disorders of menstruation and other abnormal bleeding from female genital tract: effect=0.224 (OR=1.25), std=0.912
# Pain and other symptoms associated with female genital organs: effect=0.193 (OR=1.21), std=0.702
#
# Top 10 diseases in Signature 7 (relative to baseline):
# Obesity: effect=2.414 (OR=11.18), std=0.416
# Abdominal pain: effect=2.160 (OR=8.67), std=0.221
# Other disorders of soft tissues: effect=1.836 (OR=6.27), std=0.849
# Other disorders of bone and cartilage: effect=1.687 (OR=5.41), std=0.839
# Major depressive disorder: effect=1.684 (OR=5.38), std=0.240
# Myalgia and myositis unspecified: effect=1.450 (OR=4.27), std=0.244
# Hypothyroidism NOS: effect=1.325 (OR=3.76), std=0.590
# Hyperlipidemia: effect=1.044 (OR=2.84), std=0.322
# Synovitis and tenosynovitis: effect=0.995 (OR=2.71), std=0.325
# GERD: effect=0.973 (OR=2.65), std=0.560
#
# Top 10 diseases in Signature 8 (relative to baseline):
# Excessive or frequent menstruation: effect=2.357 (OR=10.56), std=0.349
# Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia]: effect=2.349 (OR=10.48), std=0.422
# Postmenopausal bleeding: effect=2.204 (OR=9.06), std=0.690
# Irregular menstrual cycle: effect=2.142 (OR=8.51), std=0.850
# Pain and other symptoms associated with female genital organs: effect=1.831 (OR=6.24), std=1.083
# Uterine leiomyoma: effect=1.684 (OR=5.39), std=0.537
# Malignant neoplasm of ovary: effect=1.545 (OR=4.69), std=0.445
# Mucous polyp of cervix: effect=1.539 (OR=4.66), std=0.527
# Postmenopausal atrophic vaginitis: effect=1.326 (OR=3.77), std=0.459
# Dyspareunia: effect=1.307 (OR=3.70), std=0.624
#
# Top 10 diseases in Signature 9 (relative to baseline):
# Kyphoscoliosis and scoliosis: effect=2.050 (OR=7.77), std=0.156
# Back pain: effect=1.603 (OR=4.97), std=0.163
# Acquired spondylolisthesis: effect=1.478 (OR=4.38), std=0.227
# Spondylosis without myelopathy: effect=1.378 (OR=3.97), std=0.212
# Degenerative disease of the spinal cord: effect=1.072 (OR=2.92), std=0.664
# Displacement of intervertebral disc: effect=1.071 (OR=2.92), std=0.792
# Thoracic or lumbosacral neuritis or radiculitis, unspecified: effect=1.006 (OR=2.73), std=0.507
# Spinal stenosis: effect=0.933 (OR=2.54), std=0.259
# Neuralgia, neuritis, and radiculitis NOS: effect=0.859 (OR=2.36), std=0.546
# Degeneration of intervertebral disc: effect=0.497 (OR=1.64), std=0.266
#
# Top 10 diseases in Signature 10 (relative to baseline):
# Macular degeneration (senile) of retina NOS: effect=2.325 (OR=10.23), std=0.692
# Retinal vascular changes and abnomalities: effect=2.109 (OR=8.24), std=0.734
# Cataract: effect=1.923 (OR=6.84), std=0.182
# Primary open angle glaucoma: effect=1.535 (OR=4.64), std=0.215
# Retinal detachments and defects: effect=1.427 (OR=4.17), std=0.257
# Retinal detachment with retinal defect: effect=1.076 (OR=2.93), std=0.680
# Glaucoma: effect=0.815 (OR=2.26), std=0.595
# Myopia: effect=0.746 (OR=2.11), std=0.471
# Pericarditis: effect=0.100 (OR=1.10), std=0.205
# Other retinal disorders: effect=0.046 (OR=1.05), std=0.496
#
# Top 10 diseases in Signature 11 (relative to baseline):
# Cerebrovascular disease: effect=1.721 (OR=5.59), std=0.293
# Occlusion and stenosis of precerebral arteries: effect=1.641 (OR=5.16), std=0.352
# Cerebral artery occlusion, with cerebral infarction: effect=1.280 (OR=3.60), std=0.814
# Hemiplegia: effect=1.029 (OR=2.80), std=0.449
# Occlusion of cerebral arteries: effect=0.717 (OR=2.05), std=0.330
# Cerebral ischemia: effect=0.616 (OR=1.85), std=0.423
# Other tests: effect=0.543 (OR=1.72), std=0.327
# Late effects of cerebrovascular disease: effect=0.397 (OR=1.49), std=0.434
# Coronary atherosclerosis: effect=0.241 (OR=1.27), std=0.464
# Transient cerebral ischemia: effect=0.215 (OR=1.24), std=0.377
#
# Top 10 diseases in Signature 12 (relative to baseline):
# Other disorders of the kidney and ureters: effect=1.907 (OR=6.73), std=0.579
# Stricture/obstruction of ureter: effect=1.484 (OR=4.41), std=0.186
# Hydronephrosis: effect=1.304 (OR=3.68), std=0.671
# Calculus of ureter: effect=1.075 (OR=2.93), std=0.375
# Renal colic: effect=0.980 (OR=2.66), std=0.220
# Osteoarthritis; localized: effect=0.353 (OR=1.42), std=0.630
# Phlebitis and thrombophlebitis of lower extremities: effect=-0.119 (OR=0.89), std=0.707
# Hypovolemia: effect=-0.212 (OR=0.81), std=0.818
# Pyelonephritis: effect=-0.238 (OR=0.79), std=0.732
# Calculus of kidney: effect=-0.262 (OR=0.77), std=0.704
#
# Top 10 diseases in Signature 13 (relative to baseline):
# Hyperplasia of prostate: effect=2.182 (OR=8.87), std=0.660
# Chronic prostatitis: effect=1.837 (OR=6.28), std=0.192
# Malignant neoplasm of bladder: effect=1.634 (OR=5.13), std=0.471
# Cancer of prostate: effect=1.513 (OR=4.54), std=1.070
# Other disorders of bladder: effect=1.014 (OR=2.76), std=0.280
# Urinary incontinence: effect=0.930 (OR=2.53), std=0.758
# Cystitis: effect=0.862 (OR=2.37), std=0.642
# Chronic cystitis: effect=0.698 (OR=2.01), std=0.537
# Other disorders of prostate: effect=0.426 (OR=1.53), std=1.199
# Other symptoms/disorders or the urinary system: effect=0.413 (OR=1.51), std=0.562
#
# Top 10 diseases in Signature 14 (relative to baseline):
# Pneumonia: effect=1.523 (OR=4.59), std=0.507
# Emphysema: effect=1.378 (OR=3.97), std=0.206
# Pneumococcal pneumonia: effect=1.357 (OR=3.88), std=1.181
# Chronic airway obstruction: effect=1.221 (OR=3.39), std=1.418
# Bronchiectasis: effect=1.148 (OR=3.15), std=0.409
# Tobacco use disorder: effect=1.088 (OR=2.97), std=1.593
# Postinflammatory pulmonary fibrosis: effect=1.030 (OR=2.80), std=0.804
# Obstructive chronic bronchitis: effect=0.638 (OR=1.89), std=0.472
# Other specified gastritis: effect=0.112 (OR=1.12), std=0.659
# Chronic periodontitis: effect=-0.071 (OR=0.93), std=0.441
#
# Top 10 diseases in Signature 15 (relative to baseline):
# Hypoglycemia: effect=1.744 (OR=5.72), std=0.264
# Type 2 diabetes: effect=1.267 (OR=3.55), std=0.241
# Type 2 diabetes with ophthalmic manifestations: effect=1.051 (OR=2.86), std=0.396
# Type 1 diabetes: effect=1.016 (OR=2.76), std=1.229
# Other tests: effect=0.536 (OR=1.71), std=0.712
# Diabetic retinopathy: effect=0.406 (OR=1.50), std=0.201
# Other disorders of male genital organs: effect=0.374 (OR=1.45), std=0.646
# Other chronic nonalcoholic liver disease: effect=-0.205 (OR=0.81), std=0.255
# Chronic pharyngitis and nasopharyngitis: effect=-0.210 (OR=0.81), std=0.568
# First degree AV block: effect=-0.249 (OR=0.78), std=1.330
#
# Top 10 diseases in Signature 16 (relative to baseline):
# Orthostatic hypotension: effect=2.050 (OR=7.77), std=0.292
# Bacterial infection NOS: effect=1.921 (OR=6.83), std=0.656
# Other diseases of respiratory system, NEC: effect=1.851 (OR=6.37), std=0.646
# Acidosis: effect=1.786 (OR=5.97), std=1.215
# Streptococcus infection: effect=1.489 (OR=4.43), std=0.275
# Peritonitis and retroperitoneal infections: effect=1.400 (OR=4.06), std=0.178
# Thrombocytopenia: effect=1.385 (OR=3.99), std=1.313
# Pulmonary collapse; interstitial and compensatory emphysema: effect=1.381 (OR=3.98), std=0.200
# Other anemias: effect=1.262 (OR=3.53), std=0.216
# Decubitus ulcer: effect=1.177 (OR=3.24), std=0.366
#
# Top 10 diseases in Signature 17 (relative to baseline):
# Regional enteritis: effect=2.902 (OR=18.22), std=0.770
# Diverticulosis: effect=2.580 (OR=13.19), std=0.375
# Hemorrhoids: effect=1.989 (OR=7.31), std=0.234
# Hemorrhage of gastrointestinal tract: effect=1.649 (OR=5.20), std=0.504
# Ventral hernia: effect=1.419 (OR=4.13), std=1.263
# Malignant neoplasm of rectum, rectosigmoid junction, and anus: effect=1.187 (OR=3.28), std=0.767
# Benign neoplasm of colon: effect=1.126 (OR=3.08), std=0.745
# Hemorrhage of rectum and anus: effect=0.940 (OR=2.56), std=0.474
# Noninfectious gastroenteritis: effect=0.929 (OR=2.53), std=0.432
# Other intestinal obstruction: effect=0.831 (OR=2.30), std=0.534
#
# Top 10 diseases in Signature 18 (relative to baseline):
# Calculus of bile duct: effect=1.268 (OR=3.55), std=0.125
# Other disorders of gallbladder: effect=1.026 (OR=2.79), std=0.619
# Cholecystitis without cholelithiasis: effect=0.930 (OR=2.54), std=0.229
# Cholelithiasis with acute cholecystitis: effect=0.796 (OR=2.22), std=0.736
# Acute pancreatitis: effect=0.566 (OR=1.76), std=0.572
# Cholelithiasis: effect=0.507 (OR=1.66), std=0.430
# Other disorders of biliary tract: effect=0.418 (OR=1.52), std=0.412
# Cholelithiasis with other cholecystitis: effect=0.354 (OR=1.43), std=0.446
# Hemorrhoids: effect=0.060 (OR=1.06), std=0.548
# Peritoneal adhesions (postoperative) (postinfection): effect=-0.008 (OR=0.99), std=0.397
#
# Top 10 diseases in Signature 19 (relative to baseline):
# Chronic Kidney Disease, Stage III: effect=2.511 (OR=12.32), std=0.647
# Renal failure NOS: effect=2.187 (OR=8.91), std=0.117
# Chronic glomerulonephritis, NOS: effect=2.023 (OR=7.56), std=0.896
# Malignant neoplasm of female breast: effect=1.969 (OR=7.16), std=0.774
# Epiphora: effect=1.813 (OR=6.13), std=0.921
# Disorders of lacrimal system: effect=1.573 (OR=4.82), std=0.465
# Actinic keratosis: effect=1.499 (OR=4.48), std=0.497
# Breast cancer [female]: effect=1.421 (OR=4.14), std=0.203
# Other hypertrophic and atrophic conditions of skin: effect=1.348 (OR=3.85), std=0.486
# Thyrotoxicosis with or without goiter: effect=1.302 (OR=3.68), std=0.487

# %%
def compare_disease_rankings(model, disease_names, n_top=10):
    """
    Compare initial vs final disease rankings for each signature
    """
    # Get initial rankings from psi
    psi = model.psi.detach().numpy()  # Shape: (K, D)
    
    # Get final rankings from centered phi
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Compare rankings for each signature
    for k in range(phi_avg.shape[0]):
        print(f"\nSignature {k}:")
        
        # Get initial top diseases from psi
        initial_scores = psi[k, :]
        initial_top = np.argsort(initial_scores)[-n_top:][::-1]
        
        # Get final top diseases from phi
        final_scores = phi_avg[k, :]
        final_top = np.argsort(final_scores)[-n_top:][::-1]
        
        print("\nInitial top diseases:")
        for i, idx in enumerate(initial_top):
            print(f"{i+1}. {disease_names[idx]}: {initial_scores[idx]:.3f}")
            
        print("\nFinal top diseases:")
        for i, idx in enumerate(final_top):
            print(f"{i+1}. {disease_names[idx]}: {final_scores[idx]:.3f}")
            
        # Calculate rank changes
        initial_ranks = {disease: rank for rank, disease in enumerate(initial_top)}
        final_ranks = {disease: rank for rank, disease in enumerate(final_top)}
        
        # Find diseases that changed ranks significantly
        changed_diseases = set(initial_top) | set(final_top)
        for disease in changed_diseases:
            initial_rank = initial_ranks.get(disease, n_top+1)
            final_rank = final_ranks.get(disease, n_top+1)
            if abs(final_rank - initial_rank) > 2:  # Threshold for significant change
                print(f"\n{disease_names[disease]} changed from rank {initial_rank+1} to {final_rank+1}")

# Run comparison
compare_disease_rankings(model, essentials['disease_names'])
# Out:
# Signature 0:
#
# Initial top diseases:
# 1. Aortic valve disease: 1.180
# 2. Heart failure NOS: 1.147
# 3. Paroxysmal ventricular tachycardia: 1.106
# 4. Left bundle branch block: 1.072
# 5. Congestive heart failure (CHF) NOS: 1.044
# 6. Congenital anomalies of great vessels: 1.033
# 7. Atrial fibrillation and flutter: 1.028
# 8. Pericarditis: 1.004
# 9. Cardiomegaly: 0.999
# 10. Mitral valve disease: 0.982
#
# Final top diseases:
# 1. Rheumatic disease of the heart valves: 2.386
# 2. Pericarditis: 2.060
# 3. Paroxysmal supraventricular tachycardia: 1.899
# 4. Heart failure NOS: 1.798
# 5. Cardiomegaly: 1.796
# 6. Congenital anomalies of great vessels: 1.318
# 7. Other forms of chronic heart disease: 1.302
# 8. Primary/intrinsic cardiomyopathies: 1.204
# 9. Aortic valve disease: 1.199
# 10. Pleurisy; pleural effusion: 1.177
#
# Congestive heart failure (CHF) NOS changed from rank 5 to 12
#
# Rheumatic disease of the heart valves changed from rank 12 to 1
#
# Aortic valve disease changed from rank 1 to 9
#
# Other forms of chronic heart disease changed from rank 12 to 7
#
# Cardiomegaly changed from rank 9 to 5
#
# Pericarditis changed from rank 8 to 2
#
# Primary/intrinsic cardiomyopathies changed from rank 12 to 8
#
# Left bundle branch block changed from rank 4 to 12
#
# Paroxysmal supraventricular tachycardia changed from rank 12 to 3
#
# Paroxysmal ventricular tachycardia changed from rank 3 to 12
#
# Atrial fibrillation and flutter changed from rank 7 to 12
#
# Signature 1:
#
# Initial top diseases:
# 1. Other disorders of synovium, tendon, and bursa: 1.295
# 2. Hallux valgus (Bunion): 1.194
# 3. Enthesopathy: 1.136
# 4. Acquired toe deformities: 1.082
# 5. Peripheral enthesopathies and allied syndromes: 1.071
# 6. Rheumatoid arthritis: 1.067
# 7. Pain in joint: 1.059
# 8. Hallux rigidus: 1.036
# 9. Other peripheral nerve disorders: 1.033
# 10. Osteoarthrosis, generalized: 1.006
#
# Final top diseases:
# 1. Synovitis and tenosynovitis: 1.810
# 2. Hallux valgus (Bunion): 1.696
# 3. Other acquired deformities of limbs: 1.491
# 4. Osteoarthritis; localized: 1.230
# 5. Internal derangement of knee: 1.129
# 6. Peripheral enthesopathies and allied syndromes: 1.062
# 7. Osteoarthrosis NOS: 0.946
# 8. Enthesopathy: 0.927
# 9. Hallux rigidus: 0.910
# 10. Joint effusions: 0.768
#
# Other acquired deformities of limbs changed from rank 12 to 3
#
# Osteoarthritis; localized changed from rank 12 to 4
#
# Osteoarthrosis NOS changed from rank 12 to 7
#
# Pain in joint changed from rank 7 to 12
#
# Other peripheral nerve disorders changed from rank 9 to 12
#
# Internal derangement of knee changed from rank 12 to 5
#
# Rheumatoid arthritis changed from rank 6 to 12
#
# Enthesopathy changed from rank 3 to 8
#
# Other disorders of synovium, tendon, and bursa changed from rank 1 to 12
#
# Synovitis and tenosynovitis changed from rank 12 to 1
#
# Acquired toe deformities changed from rank 4 to 12
#
# Signature 2:
#
# Initial top diseases:
# 1. Gastric ulcer: 1.178
# 2. Gastritis and duodenitis: 1.157
# 3. Other disorders of stomach and duodenum: 1.034
# 4. Reflux esophagitis: 1.026
# 5. Duodenitis: 1.013
# 6. Stricture and stenosis of esophagus: 1.002
# 7. Barrett's esophagus: 0.980
# 8. Other specified gastritis: 0.976
# 9. Iron deficiency anemias, unspecified or not due to blood loss: 0.971
# 10. Esophageal bleeding (varices/hemorrhage): 0.955
#
# Final top diseases:
# 1. Diaphragmatic hernia: 2.320
# 2. Duodenal ulcer: 2.108
# 3. Benign neoplasm of other parts of digestive system: 1.949
# 4. Esophagitis, GERD and related diseases: 1.669
# 5. Other specified gastritis: 1.403
# 6. Reflux esophagitis: 1.294
# 7. Other disorders of stomach and duodenum: 1.270
# 8. Gastric ulcer: 1.070
# 9. Stricture and stenosis of esophagus: 1.031
# 10. Ulcer of esophagus: 1.002
#
# Other disorders of stomach and duodenum changed from rank 3 to 7
#
# Diaphragmatic hernia changed from rank 12 to 1
#
# Benign neoplasm of other parts of digestive system changed from rank 12 to 3
#
# Esophagitis, GERD and related diseases changed from rank 12 to 4
#
# Barrett's esophagus changed from rank 7 to 12
#
# Stricture and stenosis of esophagus changed from rank 6 to 9
#
# Gastric ulcer changed from rank 1 to 8
#
# Duodenal ulcer changed from rank 12 to 2
#
# Gastritis and duodenitis changed from rank 2 to 12
#
# Iron deficiency anemias, unspecified or not due to blood loss changed from rank 9 to 12
#
# Duodenitis changed from rank 5 to 12
#
# Other specified gastritis changed from rank 8 to 5
#
# Signature 3:
#
# Initial top diseases:
# 1. Celiac disease: 1.220
# 2. Other tests: 1.190
# 3. Peripheral vascular disease, unspecified: 1.173
# 4. Atopic/contact dermatitis due to other or unspecified: 1.169
# 5. Blood in stool: 1.164
# 6. Redundant prepuce and phimosis/BXO: 1.150
# 7. Hypertrophy of breast (Gynecomastia): 1.139
# 8. Inflammation of eyelids: 1.130
# 9. Diseases of the larynx and vocal cords: 1.113
# 10. Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue: 1.111
#
# Final top diseases:
# 1. Polymyalgia Rheumatica: 2.560
# 2. Malignant neoplasm of kidney, except pelvis: 2.513
# 3. Chronic periodontitis: 2.431
# 4. Allergic rhinitis: 2.316
# 5. Raynaud's syndrome: 2.311
# 6. Ganglion and cyst of synovium, tendon, and bursa: 2.287
# 7. Facial nerve disorders [CN7]: 2.158
# 8. Bursitis: 2.151
# 9. Diseases and other conditions of the tongue: 2.141
# 10. Contracture of palmar fascia [Dupuytren's disease]: 2.140
#
# Hypertrophy of breast (Gynecomastia) changed from rank 7 to 12
#
# Celiac disease changed from rank 1 to 12
#
# Raynaud's syndrome changed from rank 12 to 5
#
# Peripheral vascular disease, unspecified changed from rank 3 to 12
#
# Facial nerve disorders [CN7] changed from rank 12 to 7
#
# Malignant neoplasm of kidney, except pelvis changed from rank 12 to 2
#
# Diseases of the larynx and vocal cords changed from rank 9 to 12
#
# Atopic/contact dermatitis due to other or unspecified changed from rank 4 to 12
#
# Other tests changed from rank 2 to 12
#
# Allergic rhinitis changed from rank 12 to 4
#
# Inflammation of eyelids changed from rank 8 to 12
#
# Blood in stool changed from rank 5 to 12
#
# Polymyalgia Rheumatica changed from rank 12 to 1
#
# Chronic periodontitis changed from rank 12 to 3
#
# Diseases and other conditions of the tongue changed from rank 12 to 9
#
# Bursitis changed from rank 12 to 8
#
# Ganglion and cyst of synovium, tendon, and bursa changed from rank 12 to 6
#
# Redundant prepuce and phimosis/BXO changed from rank 6 to 12
#
# Signature 4:
#
# Initial top diseases:
# 1. Other upper respiratory disease: 1.015
# 2. Septal Deviations/Turbinate Hypertrophy: 0.927
# 3. Chronic sinusitis: 0.903
# 4. Nasal polyps: 0.860
# 5. Chronic pharyngitis and nasopharyngitis: 0.851
# 6. Raynaud's syndrome: -1.971
# 7. Arrhythmia (cardiac) NOS: -1.974
# 8. Visual disturbances: -1.974
# 9. Type 2 diabetes: -1.975
# 10. Cholecystitis without cholelithiasis: -1.976
#
# Final top diseases:
# 1. Chronic sinusitis: 1.662
# 2. Septal Deviations/Turbinate Hypertrophy: 1.532
# 3. Chronic pharyngitis and nasopharyngitis: 0.512
# 4. Other upper respiratory disease: 0.478
# 5. Sepsis: 0.244
# 6. Cervicitis and endocervicitis: -0.017
# 7. Viral warts & HPV: -0.026
# 8. Nasal polyps: -0.096
# 9. Sleep disorders: -0.433
# 10. Hypertensive chronic kidney disease: -0.457
#
# Arrhythmia (cardiac) NOS changed from rank 7 to 12
#
# Cervicitis and endocervicitis changed from rank 12 to 6
#
# Viral warts & HPV changed from rank 12 to 7
#
# Sleep disorders changed from rank 12 to 9
#
# Raynaud's syndrome changed from rank 6 to 12
#
# Nasal polyps changed from rank 4 to 8
#
# Sepsis changed from rank 12 to 5
#
# Visual disturbances changed from rank 8 to 12
#
# Other upper respiratory disease changed from rank 1 to 4
#
# Type 2 diabetes changed from rank 9 to 12
#
# Signature 5:
#
# Initial top diseases:
# 1. Coronary atherosclerosis: 1.179
# 2. Other acute and subacute forms of ischemic heart disease: 1.108
# 3. Hypercholesterolemia: 1.072
# 4. Other chronic ischemic heart disease, unspecified: 0.907
# 5. Myocardial infarction: 0.868
# 6. Angina pectoris: 0.840
# 7. Unstable angina (intermediate coronary syndrome): 0.820
# 8. Lipoma: -1.973
# 9. Bladder neck obstruction: -1.977
# 10. Dental caries: -1.978
#
# Final top diseases:
# 1. Coronary atherosclerosis: 2.187
# 2. Unstable angina (intermediate coronary syndrome): 2.029
# 3. Hypercholesterolemia: 1.557
# 4. Myocardial infarction: 1.436
# 5. Other chronic ischemic heart disease, unspecified: 1.358
# 6. Other acute and subacute forms of ischemic heart disease: 1.012
# 7. Hypopotassemia: 0.393
# 8. Symptoms and disorders of the joints: 0.263
# 9. Angina pectoris: 0.151
# 10. Hypoglycemia: -0.142
#
# Symptoms and disorders of the joints changed from rank 12 to 8
#
# Lipoma changed from rank 8 to 12
#
# Unstable angina (intermediate coronary syndrome) changed from rank 7 to 2
#
# Angina pectoris changed from rank 6 to 9
#
# Other acute and subacute forms of ischemic heart disease changed from rank 2 to 6
#
# Bladder neck obstruction changed from rank 9 to 12
#
# Hypopotassemia changed from rank 12 to 7
#
# Signature 6:
#
# Initial top diseases:
# 1. Secondary malignant neoplasm of digestive systems: 1.081
# 2. Secondary malignancy of lymph nodes: 1.055
# 3. Secondary malignancy of bone: 1.047
# 4. Secondary malignant neoplasm of liver: 1.005
# 5. Malignant neoplasm, other: 1.004
# 6. Secondary malignant neoplasm: 0.981
# 7. Cancer of bronchus; lung: 0.966
# 8. Secondary malignancy of respiratory organs: 0.809
# 9. Lump or mass in breast: -1.973
# 10. Urinary incontinence: -1.974
#
# Final top diseases:
# 1. Secondary malignancy of bone: 3.532
# 2. Malignant neoplasm, other: 2.686
# 3. Secondary malignant neoplasm of digestive systems: 1.500
# 4. Secondary malignancy of respiratory organs: 1.438
# 5. Secondary malignant neoplasm of liver: 0.655
# 6. Secondary malignancy of lymph nodes: 0.633
# 7. Urinary incontinence: 0.507
# 8. Cancer of bronchus; lung: 0.405
# 9. Disorders of menstruation and other abnormal bleeding from female genital tract: 0.224
# 10. Pain and other symptoms associated with female genital organs: 0.193
#
# Lump or mass in breast changed from rank 9 to 12
#
# Disorders of menstruation and other abnormal bleeding from female genital tract changed from rank 12 to 9
#
# Malignant neoplasm, other changed from rank 5 to 2
#
# Secondary malignant neoplasm changed from rank 6 to 12
#
# Secondary malignancy of lymph nodes changed from rank 2 to 6
#
# Secondary malignancy of respiratory organs changed from rank 8 to 4
#
# Urinary incontinence changed from rank 10 to 7
#
# Signature 7:
#
# Initial top diseases:
# 1. Asthma: 1.328
# 2. Migraine: 1.253
# 3. Myalgia and myositis unspecified: 1.186
# 4. Osteoporosis NOS: 1.155
# 5. Major depressive disorder: 1.136
# 6. Spondylosis and allied disorders: 1.116
# 7. Abdominal pain: 1.109
# 8. Essential hypertension: 1.109
# 9. Hyperlipidemia: 1.094
# 10. Obesity: 1.091
#
# Final top diseases:
# 1. Obesity: 2.414
# 2. Abdominal pain: 2.160
# 3. Other disorders of soft tissues: 1.836
# 4. Other disorders of bone and cartilage: 1.687
# 5. Major depressive disorder: 1.684
# 6. Myalgia and myositis unspecified: 1.450
# 7. Hypothyroidism NOS: 1.325
# 8. Hyperlipidemia: 1.044
# 9. Synovitis and tenosynovitis: 0.995
# 10. GERD: 0.973
#
# Migraine changed from rank 2 to 12
#
# Osteoporosis NOS changed from rank 4 to 12
#
# Myalgia and myositis unspecified changed from rank 3 to 6
#
# Abdominal pain changed from rank 7 to 2
#
# Asthma changed from rank 1 to 12
#
# Essential hypertension changed from rank 8 to 12
#
# Spondylosis and allied disorders changed from rank 6 to 12
#
# Hypothyroidism NOS changed from rank 12 to 7
#
# Other disorders of bone and cartilage changed from rank 12 to 4
#
# Synovitis and tenosynovitis changed from rank 12 to 9
#
# Other disorders of soft tissues changed from rank 12 to 3
#
# Obesity changed from rank 10 to 1
#
# Signature 8:
#
# Initial top diseases:
# 1. Ovarian cyst: 1.210
# 2. Malignant neoplasm of uterus: 1.141
# 3. Polyp of corpus uteri: 1.103
# 4. Hypertrophy of female genital organs: 1.087
# 5. Noninflammatory disorders of cervix: 1.086
# 6. Excessive or frequent menstruation: 1.080
# 7. Cervicitis and endocervicitis: 1.075
# 8. Noninflammatory disorders of vagina: 1.051
# 9. Uterine/Uterovaginal prolapse: 1.044
# 10. Endometrial hyperplasia: 1.010
#
# Final top diseases:
# 1. Excessive or frequent menstruation: 2.357
# 2. Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia]: 2.349
# 3. Postmenopausal bleeding: 2.204
# 4. Irregular menstrual cycle: 2.142
# 5. Pain and other symptoms associated with female genital organs: 1.831
# 6. Uterine leiomyoma: 1.684
# 7. Malignant neoplasm of ovary: 1.545
# 8. Mucous polyp of cervix: 1.539
# 9. Postmenopausal atrophic vaginitis: 1.326
# 10. Dyspareunia: 1.307
#
# Cervicitis and endocervicitis changed from rank 7 to 12
#
# Uterine/Uterovaginal prolapse changed from rank 9 to 12
#
# Noninflammatory disorders of cervix changed from rank 5 to 12
#
# Noninflammatory disorders of vagina changed from rank 8 to 12
#
# Polyp of corpus uteri changed from rank 3 to 12
#
# Mucous polyp of cervix changed from rank 12 to 8
#
# Hypertrophy of female genital organs changed from rank 4 to 12
#
# Pain and other symptoms associated with female genital organs changed from rank 12 to 5
#
# Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia] changed from rank 12 to 2
#
# Malignant neoplasm of uterus changed from rank 2 to 12
#
# Excessive or frequent menstruation changed from rank 6 to 1
#
# Irregular menstrual cycle changed from rank 12 to 4
#
# Malignant neoplasm of ovary changed from rank 12 to 7
#
# Postmenopausal bleeding changed from rank 12 to 3
#
# Postmenopausal atrophic vaginitis changed from rank 12 to 9
#
# Ovarian cyst changed from rank 1 to 12
#
# Uterine leiomyoma changed from rank 12 to 6
#
# Signature 9:
#
# Initial top diseases:
# 1. Back pain: 1.242
# 2. Thoracic or lumbosacral neuritis or radiculitis, unspecified: 1.071
# 3. Neuralgia, neuritis, and radiculitis NOS: 1.055
# 4. Degenerative disease of the spinal cord: 1.009
# 5. Spondylosis without myelopathy: 1.000
# 6. Displacement of intervertebral disc: 0.980
# 7. Acquired spondylolisthesis: 0.968
# 8. Kyphoscoliosis and scoliosis: 0.955
# 9. Other and unspecified disc disorder: 0.934
# 10. Sciatica: 0.921
#
# Final top diseases:
# 1. Kyphoscoliosis and scoliosis: 2.050
# 2. Back pain: 1.603
# 3. Acquired spondylolisthesis: 1.478
# 4. Spondylosis without myelopathy: 1.378
# 5. Degenerative disease of the spinal cord: 1.072
# 6. Displacement of intervertebral disc: 1.071
# 7. Thoracic or lumbosacral neuritis or radiculitis, unspecified: 1.006
# 8. Spinal stenosis: 0.933
# 9. Neuralgia, neuritis, and radiculitis NOS: 0.859
# 10. Degeneration of intervertebral disc: 0.497
#
# Kyphoscoliosis and scoliosis changed from rank 8 to 1
#
# Acquired spondylolisthesis changed from rank 7 to 3
#
# Thoracic or lumbosacral neuritis or radiculitis, unspecified changed from rank 2 to 7
#
# Neuralgia, neuritis, and radiculitis NOS changed from rank 3 to 9
#
# Spinal stenosis changed from rank 12 to 8
#
# Other and unspecified disc disorder changed from rank 9 to 12
#
# Signature 10:
#
# Initial top diseases:
# 1. Macular degeneration (senile) of retina NOS: 1.173
# 2. Retinal vascular changes and abnomalities: 1.167
# 3. Other retinal disorders: 1.109
# 4. Primary open angle glaucoma: 1.081
# 5. Glaucoma: 1.028
# 6. Myopia: 1.001
# 7. Disorders of vitreous body: 0.986
# 8. Cataract: 0.972
# 9. Senile cataract: 0.960
# 10. Retinal detachments and defects: 0.840
#
# Final top diseases:
# 1. Macular degeneration (senile) of retina NOS: 2.325
# 2. Retinal vascular changes and abnomalities: 2.109
# 3. Cataract: 1.923
# 4. Primary open angle glaucoma: 1.535
# 5. Retinal detachments and defects: 1.427
# 6. Retinal detachment with retinal defect: 1.076
# 7. Glaucoma: 0.815
# 8. Myopia: 0.746
# 9. Pericarditis: 0.100
# 10. Other retinal disorders: 0.046
#
# Retinal detachments and defects changed from rank 10 to 5
#
# Retinal detachment with retinal defect changed from rank 12 to 6
#
# Other retinal disorders changed from rank 3 to 10
#
# Cataract changed from rank 8 to 3
#
# Senile cataract changed from rank 9 to 12
#
# Disorders of vitreous body changed from rank 7 to 12
#
# Pericarditis changed from rank 12 to 9
#
# Signature 11:
#
# Initial top diseases:
# 1. Hemiplegia: 1.111
# 2. Cerebral ischemia: 1.052
# 3. Occlusion of cerebral arteries: 1.030
# 4. Late effects of cerebrovascular disease: 1.016
# 5. Cerebrovascular disease: 0.967
# 6. Transient cerebral ischemia: 0.940
# 7. Cerebral artery occlusion, with cerebral infarction: 0.928
# 8. Occlusion and stenosis of precerebral arteries: 0.783
# 9. Osteoarthrosis, generalized: -1.973
# 10. Anxiety disorder: -1.974
#
# Final top diseases:
# 1. Cerebrovascular disease: 1.721
# 2. Occlusion and stenosis of precerebral arteries: 1.641
# 3. Cerebral artery occlusion, with cerebral infarction: 1.280
# 4. Hemiplegia: 1.029
# 5. Occlusion of cerebral arteries: 0.717
# 6. Cerebral ischemia: 0.616
# 7. Other tests: 0.543
# 8. Late effects of cerebrovascular disease: 0.397
# 9. Coronary atherosclerosis: 0.241
# 10. Transient cerebral ischemia: 0.215
#
# Cerebrovascular disease changed from rank 5 to 1
#
# Occlusion and stenosis of precerebral arteries changed from rank 8 to 2
#
# Cerebral artery occlusion, with cerebral infarction changed from rank 7 to 3
#
# Cerebral ischemia changed from rank 2 to 6
#
# Transient cerebral ischemia changed from rank 6 to 10
#
# Late effects of cerebrovascular disease changed from rank 4 to 8
#
# Osteoarthrosis, generalized changed from rank 9 to 12
#
# Hemiplegia changed from rank 1 to 4
#
# Other tests changed from rank 12 to 7
#
# Coronary atherosclerosis changed from rank 12 to 9
#
# Signature 12:
#
# Initial top diseases:
# 1. Renal colic: 1.232
# 2. Calculus of ureter: 1.092
# 3. Stricture/obstruction of ureter: 1.065
# 4. Hydronephrosis: 1.017
# 5. Other disorders of the kidney and ureters: 1.017
# 6. Pyelonephritis: 0.906
# 7. Calculus of kidney: 0.854
# 8. Streptococcus infection: -1.955
# 9. Back pain: -1.972
# 10. Other disorders of bladder: -1.973
#
# Final top diseases:
# 1. Other disorders of the kidney and ureters: 1.907
# 2. Stricture/obstruction of ureter: 1.484
# 3. Hydronephrosis: 1.304
# 4. Calculus of ureter: 1.075
# 5. Renal colic: 0.980
# 6. Osteoarthritis; localized: 0.353
# 7. Phlebitis and thrombophlebitis of lower extremities: -0.119
# 8. Hypovolemia: -0.212
# 9. Pyelonephritis: -0.238
# 10. Calculus of kidney: -0.262
#
# Streptococcus infection changed from rank 8 to 12
#
# Osteoarthritis; localized changed from rank 12 to 6
#
# Phlebitis and thrombophlebitis of lower extremities changed from rank 12 to 7
#
# Back pain changed from rank 9 to 12
#
# Other disorders of the kidney and ureters changed from rank 5 to 1
#
# Pyelonephritis changed from rank 6 to 9
#
# Calculus of kidney changed from rank 7 to 10
#
# Renal colic changed from rank 1 to 5
#
# Hypovolemia changed from rank 12 to 8
#
# Signature 13:
#
# Initial top diseases:
# 1. Cystitis: 1.161
# 2. Urethral stricture (not specified as infectious): 1.144
# 3. Cancer of prostate: 1.079
# 4. Malignant neoplasm of bladder: 1.010
# 5. Other disorders of bladder: 1.005
# 6. Urinary incontinence: 0.992
# 7. Other symptoms/disorders or the urinary system: 0.990
# 8. Functional disorders of bladder: 0.984
# 9. Hyperplasia of prostate: 0.962
# 10. Chronic prostatitis: 0.943
#
# Final top diseases:
# 1. Hyperplasia of prostate: 2.182
# 2. Chronic prostatitis: 1.837
# 3. Malignant neoplasm of bladder: 1.634
# 4. Cancer of prostate: 1.513
# 5. Other disorders of bladder: 1.014
# 6. Urinary incontinence: 0.930
# 7. Cystitis: 0.862
# 8. Chronic cystitis: 0.698
# 9. Other disorders of prostate: 0.426
# 10. Other symptoms/disorders or the urinary system: 0.413
#
# Cystitis changed from rank 1 to 7
#
# Chronic cystitis changed from rank 12 to 8
#
# Functional disorders of bladder changed from rank 8 to 12
#
# Urethral stricture (not specified as infectious) changed from rank 2 to 12
#
# Other symptoms/disorders or the urinary system changed from rank 7 to 10
#
# Hyperplasia of prostate changed from rank 9 to 1
#
# Chronic prostatitis changed from rank 10 to 2
#
# Other disorders of prostate changed from rank 12 to 9
#
# Signature 14:
#
# Initial top diseases:
# 1. Emphysema: 1.145
# 2. Bronchiectasis: 1.055
# 3. Pneumonia: 1.043
# 4. Empyema and pneumothorax: 1.030
# 5. Tobacco use disorder: 0.920
# 6. Pneumococcal pneumonia: 0.920
# 7. Postinflammatory pulmonary fibrosis: 0.874
# 8. Chronic airway obstruction: 0.871
# 9. Respiratory failure: 0.815
# 10. Obstructive chronic bronchitis: 0.812
#
# Final top diseases:
# 1. Pneumonia: 1.523
# 2. Emphysema: 1.378
# 3. Pneumococcal pneumonia: 1.357
# 4. Chronic airway obstruction: 1.221
# 5. Bronchiectasis: 1.148
# 6. Tobacco use disorder: 1.088
# 7. Postinflammatory pulmonary fibrosis: 1.030
# 8. Obstructive chronic bronchitis: 0.638
# 9. Other specified gastritis: 0.112
# 10. Chronic periodontitis: -0.071
#
# Pneumococcal pneumonia changed from rank 6 to 3
#
# Chronic airway obstruction changed from rank 8 to 4
#
# Bronchiectasis changed from rank 2 to 5
#
# Empyema and pneumothorax changed from rank 4 to 12
#
# Respiratory failure changed from rank 9 to 12
#
# Other specified gastritis changed from rank 12 to 9
#
# Signature 15:
#
# Initial top diseases:
# 1. Hypoglycemia: 1.163
# 2. Type 1 diabetes: 1.118
# 3. Type 2 diabetes with ophthalmic manifestations: 1.046
# 4. Type 2 diabetes: 0.941
# 5. Diabetic retinopathy: 0.908
# 6. Varicose veins of lower extremity: -1.975
# 7. Disorders of calcium/phosphorus metabolism: -1.975
# 8. Congenital anomalies of great vessels: -1.977
# 9. Esophageal bleeding (varices/hemorrhage): -1.978
# 10. Secondary malignant neoplasm: -1.978
#
# Final top diseases:
# 1. Hypoglycemia: 1.744
# 2. Type 2 diabetes: 1.267
# 3. Type 2 diabetes with ophthalmic manifestations: 1.051
# 4. Type 1 diabetes: 1.016
# 5. Other tests: 0.536
# 6. Diabetic retinopathy: 0.406
# 7. Other disorders of male genital organs: 0.374
# 8. Other chronic nonalcoholic liver disease: -0.205
# 9. Chronic pharyngitis and nasopharyngitis: -0.210
# 10. First degree AV block: -0.249
#
# Congenital anomalies of great vessels changed from rank 8 to 12
#
# Varicose veins of lower extremity changed from rank 6 to 12
#
# Other chronic nonalcoholic liver disease changed from rank 12 to 8
#
# Chronic pharyngitis and nasopharyngitis changed from rank 12 to 9
#
# Other tests changed from rank 12 to 5
#
# Disorders of calcium/phosphorus metabolism changed from rank 7 to 12
#
# Esophageal bleeding (varices/hemorrhage) changed from rank 9 to 12
#
# Other disorders of male genital organs changed from rank 12 to 7
#
# Signature 16:
#
# Initial top diseases:
# 1. Other diseases of respiratory system, NEC: 1.107
# 2. Peritonitis and retroperitoneal infections: 1.105
# 3. Hypopotassemia: 1.076
# 4. Chronic ulcer of skin: 1.062
# 5. Acute renal failure: 1.042
# 6. Gram negative septicemia: 1.030
# 7. Bacterial pneumonia: 1.030
# 8. Hyperpotassemia: 1.024
# 9. Orthostatic hypotension: 0.999
# 10. Hypotension NOS: 0.998
#
# Final top diseases:
# 1. Orthostatic hypotension: 2.050
# 2. Bacterial infection NOS: 1.921
# 3. Other diseases of respiratory system, NEC: 1.851
# 4. Acidosis: 1.786
# 5. Streptococcus infection: 1.489
# 6. Peritonitis and retroperitoneal infections: 1.400
# 7. Thrombocytopenia: 1.385
# 8. Pulmonary collapse; interstitial and compensatory emphysema: 1.381
# 9. Other anemias: 1.262
# 10. Decubitus ulcer: 1.177
#
# Gram negative septicemia changed from rank 6 to 12
#
# Bacterial infection NOS changed from rank 12 to 2
#
# Streptococcus infection changed from rank 12 to 5
#
# Peritonitis and retroperitoneal infections changed from rank 2 to 6
#
# Orthostatic hypotension changed from rank 9 to 1
#
# Bacterial pneumonia changed from rank 7 to 12
#
# Acute renal failure changed from rank 5 to 12
#
# Chronic ulcer of skin changed from rank 4 to 12
#
# Pulmonary collapse; interstitial and compensatory emphysema changed from rank 12 to 8
#
# Hyperpotassemia changed from rank 8 to 12
#
# Hypopotassemia changed from rank 3 to 12
#
# Acidosis changed from rank 12 to 4
#
# Other anemias changed from rank 12 to 9
#
# Thrombocytopenia changed from rank 12 to 7
#
# Signature 17:
#
# Initial top diseases:
# 1. Regional enteritis: 1.187
# 2. Ventral hernia: 1.174
# 3. Hemorrhoids: 1.116
# 4. Hemorrhage of gastrointestinal tract: 1.115
# 5. Hemorrhage of rectum and anus: 1.099
# 6. Benign neoplasm of colon: 1.077
# 7. Diverticulosis: 1.050
# 8. Neoplasm of unspecified nature of digestive system: 1.040
# 9. Noninfectious gastroenteritis: 1.029
# 10. Other intestinal obstruction: 0.996
#
# Final top diseases:
# 1. Regional enteritis: 2.902
# 2. Diverticulosis: 2.580
# 3. Hemorrhoids: 1.989
# 4. Hemorrhage of gastrointestinal tract: 1.649
# 5. Ventral hernia: 1.419
# 6. Malignant neoplasm of rectum, rectosigmoid junction, and anus: 1.187
# 7. Benign neoplasm of colon: 1.126
# 8. Hemorrhage of rectum and anus: 0.940
# 9. Noninfectious gastroenteritis: 0.929
# 10. Other intestinal obstruction: 0.831
#
# Ventral hernia changed from rank 2 to 5
#
# Diverticulosis changed from rank 7 to 2
#
# Neoplasm of unspecified nature of digestive system changed from rank 8 to 12
#
# Malignant neoplasm of rectum, rectosigmoid junction, and anus changed from rank 12 to 6
#
# Hemorrhage of rectum and anus changed from rank 5 to 8
#
# Signature 18:
#
# Initial top diseases:
# 1. Other disorders of gallbladder: 1.181
# 2. Cholelithiasis with acute cholecystitis: 1.054
# 3. Acute pancreatitis: 1.050
# 4. Peritoneal adhesions (postoperative) (postinfection): 1.046
# 5. Calculus of bile duct: 1.011
# 6. Other disorders of biliary tract: 1.000
# 7. Cholelithiasis: 0.984
# 8. Cholelithiasis with other cholecystitis: 0.914
# 9. Cholecystitis without cholelithiasis: 0.876
# 10. Anal and rectal polyp: -1.973
#
# Final top diseases:
# 1. Calculus of bile duct: 1.268
# 2. Other disorders of gallbladder: 1.026
# 3. Cholecystitis without cholelithiasis: 0.930
# 4. Cholelithiasis with acute cholecystitis: 0.796
# 5. Acute pancreatitis: 0.566
# 6. Cholelithiasis: 0.507
# 7. Other disorders of biliary tract: 0.418
# 8. Cholelithiasis with other cholecystitis: 0.354
# 9. Hemorrhoids: 0.060
# 10. Peritoneal adhesions (postoperative) (postinfection): -0.008
#
# Hemorrhoids changed from rank 12 to 9
#
# Peritoneal adhesions (postoperative) (postinfection) changed from rank 4 to 10
#
# Calculus of bile duct changed from rank 5 to 1
#
# Cholecystitis without cholelithiasis changed from rank 9 to 3
#
# Signature 19:
#
# Initial top diseases:
# 1. Other disorders of eyelids: 1.175
# 2. Chronic glomerulonephritis, NOS: 1.160
# 3. Seborrheic keratosis: 1.152
# 4. Thyrotoxicosis with or without goiter: 1.135
# 5. Disorders of lacrimal system: 1.126
# 6. Other non-epithelial cancer of skin: 1.095
# 7. Ectropion or entropion: 1.088
# 8. Hypertensive chronic kidney disease: 1.079
# 9. Breast cancer [female]: 1.050
# 10. Viral warts & HPV: 1.038
#
# Final top diseases:
# 1. Chronic Kidney Disease, Stage III: 2.511
# 2. Renal failure NOS: 2.187
# 3. Chronic glomerulonephritis, NOS: 2.023
# 4. Malignant neoplasm of female breast: 1.969
# 5. Epiphora: 1.813
# 6. Disorders of lacrimal system: 1.573
# 7. Actinic keratosis: 1.499
# 8. Breast cancer [female]: 1.421
# 9. Other hypertrophic and atrophic conditions of skin: 1.348
# 10. Thyrotoxicosis with or without goiter: 1.302
#
# Other non-epithelial cancer of skin changed from rank 6 to 12
#
# Malignant neoplasm of female breast changed from rank 12 to 4
#
# Other disorders of eyelids changed from rank 1 to 12
#
# Ectropion or entropion changed from rank 7 to 12
#
# Other hypertrophic and atrophic conditions of skin changed from rank 12 to 9
#
# Seborrheic keratosis changed from rank 3 to 12
#
# Epiphora changed from rank 12 to 5
#
# Renal failure NOS changed from rank 12 to 2
#
# Actinic keratosis changed from rank 12 to 7
#
# Chronic Kidney Disease, Stage III changed from rank 12 to 1
#
# Thyrotoxicosis with or without goiter changed from rank 4 to 10
#
# Hypertensive chronic kidney disease changed from rank 8 to 12

# %%
def plot_signature_temporal_patterns(model, disease_names, n_top=10, selected_signatures=None):
    """
    Show temporal patterns of top diseases for each signature
    """
    #phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    #phi_avg = phi.mean(axis=2)  # Average over time

     # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Select which signatures to plot
    if selected_signatures is None:
        selected_signatures = range(phi_avg.shape[0])
    
    # Create subplots for each selected signature
    n_sigs = len(selected_signatures)
    fig, axes = plt.subplots(n_sigs, 1, figsize=(15, 5*n_sigs))
    if n_sigs == 1:
        axes = [axes]
    
    for i, k in enumerate(selected_signatures):
        # Get top diseases
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        # Plot temporal patterns
        ax = axes[i]
        for idx in top_indices:
            temporal_pattern = phi[k, idx, :]
            ax.plot(temporal_pattern, label=disease_names[idx])
        
        ax.set_title(f'Signature {k} - Top Disease Temporal Patterns')
        ax.set_xlabel('Time')
        ax.set_ylabel('Phi Value')
        ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# First show the top diseases


# Then show their temporal patterns
# You can select specific signatures of interest:
disease_names=essentials['disease_names']
plot_signature_temporal_patterns(model, disease_names, selected_signatures=[0,1,14,15,16,13,17])

# %%
Y_avg_global = torch.mean(torch.tensor(Y_global) if isinstance(Y_global, np.ndarray) else Y_global, dim=2)
Y_avg_batch = torch.mean(torch.tensor(Y_100k) if isinstance(Y_100k, np.ndarray) else Y_100k, dim=2)

# %%
def compare_disease_patterns(k, true_psi, Y_avg_global, Y_avg_batch):
    """Compare disease patterns between global and batch data"""
    strong_diseases = (true_psi[k] > 0)
    
    # Get mean pattern for each dataset (average across patients)
    pattern_large = Y_avg_global[:, strong_diseases].mean(dim=0)  # Average across all patients
    pattern_small = Y_avg_batch[:, strong_diseases].mean(dim=0)  # Average across batch patients
    
    # Now both patterns are just length of strong_diseases
    correlation = torch.corrcoef(
        torch.stack([pattern_large, pattern_small])
    )[0,1]
    
    print(f"Signature {k} pattern correlation: {correlation:.3f}")
    print(f"Mean pattern difference: {(pattern_large - pattern_small).abs().mean():.3f}")

# Now use it
print("Comparing disease sharing patterns between global and batch data:")
for k in range(model.K):
    print(f"\nSignature {k}:")
    compare_disease_patterns(k, model.psi, Y_avg_global, Y_avg_batch)
# Out:
# Comparing disease sharing patterns between global and batch data:
#
# Signature 0:
# Signature 0 pattern correlation: 0.999
# Mean pattern difference: 0.000
#
# Signature 1:
# Signature 1 pattern correlation: 1.000
# Mean pattern difference: 0.000
#
# Signature 2:
# Signature 2 pattern correlation: 0.999
# Mean pattern difference: 0.000
#
# Signature 3:
# Signature 3 pattern correlation: 0.996
# Mean pattern difference: 0.000
#
# Signature 4:
# Signature 4 pattern correlation: 0.982
# Mean pattern difference: 0.000
#
# Signature 5:
# Signature 5 pattern correlation: 1.000
# Mean pattern difference: 0.000
#
# Signature 6:
# Signature 6 pattern correlation: 0.992
# Mean pattern difference: 0.000
#
# Signature 7:
# Signature 7 pattern correlation: 1.000
# Mean pattern difference: 0.000
#
# Signature 8:
# Signature 8 pattern correlation: 0.995
# Mean pattern difference: 0.000
#
# Signature 9:
# Signature 9 pattern correlation: 0.996
# Mean pattern difference: 0.000
#
# Signature 10:
# Signature 10 pattern correlation: 0.999
# Mean pattern difference: 0.000
#
# Signature 11:
# Signature 11 pattern correlation: 0.958
# Mean pattern difference: 0.000
#
# Signature 12:
# Signature 12 pattern correlation: 0.979
# Mean pattern difference: 0.000
#
# Signature 13:
# Signature 13 pattern correlation: 0.999
# Mean pattern difference: 0.000
#
# Signature 14:
# Signature 14 pattern correlation: 0.995
# Mean pattern difference: 0.000
#
# Signature 15:
# Signature 15 pattern correlation: 1.000
# Mean pattern difference: 0.000
#
# Signature 16:
# Signature 16 pattern correlation: 0.999
# Mean pattern difference: 0.000
#
# Signature 17:
# Signature 17 pattern correlation: 0.999
# Mean pattern difference: 0.000
#
# Signature 18:
# Signature 18 pattern correlation: 0.997
# Mean pattern difference: 0.000
#
# Signature 19:
# Signature 19 pattern correlation: 0.995
# Mean pattern difference: 0.000
