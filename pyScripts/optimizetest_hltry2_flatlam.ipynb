# %%
# %load_ext autoreload
# %autoreload 2

from cluster_g_logit_init_acceptpsi_flatlam_healthtoo import *

# %%
# %load_ext autoreload
# %autoreload 2



# %autoreload 2
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering  # Add this import

def load_model_essentials(base_path='/Users/sarahurbut/Dropbox (Personal)/data_for_running/'):
    """
    Load all essential components
    """
    print("Loading components...")
    
    # Load large matrices
    Y = torch.load(base_path + 'Y_tensor.pt')
    E = torch.load(base_path + 'E_matrix.pt')
    G = torch.load(base_path + 'G_matrix.pt')
    
    # Load other components
    essentials = torch.load(base_path + 'model_essentials.pt')
    
    print("Loaded all components successfully!")
    
    return Y, E, G, essentials

# Load and initialize model:
Y, E, G, essentials = load_model_essentials()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Loading components...
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_91758/1184199116.py:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Y = torch.load(base_path + 'Y_tensor.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_91758/1184199116.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   E = torch.load(base_path + 'E_matrix.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_91758/1184199116.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   G = torch.load(base_path + 'G_matrix.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_91758/1184199116.py:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   essentials = torch.load(base_path + 'model_essentials.pt')
# Loaded all components successfully!

# %%
# Subset the data
Y_100k, E_100k, G_100k, indices = subset_data(Y, E, G, n_samples=10000,seed=1)

torch.manual_seed(42)
np.random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Initialize model with subsetted data
# Out:
# Original shapes: Y=torch.Size([407878, 348, 52]), E=torch.Size([407878, 348]), G=torch.Size([407878, 36])
# New shapes: Y=torch.Size([10000, 348, 52]), E=torch.Size([10000, 348]), G=torch.Size([10000, 36])

# %%
# When initializing the model:
original_G = G_100k # Store the original G - proper tensor copy

# Now in your batch run, load and verify:
initial_psi = torch.load('initial_psi_400k.pt')
initial_clusters = torch.load('initial_clusters_400k.pt')

original_cluster_sizes = {}
unique, counts = np.unique(initial_clusters, return_counts=True)
for k, count in zip(unique, counts):
    original_cluster_sizes[k] = count
print("\nOriginal cluster sizes:")
for k, count in original_cluster_sizes.items():
    print(f"Cluster {k}: {count} diseases")
# Out:
# Original cluster sizes:
# Cluster 0: 16 diseases
# Cluster 1: 21 diseases
# Cluster 2: 15 diseases
# Cluster 3: 82 diseases
# Cluster 4: 5 diseases
# Cluster 5: 7 diseases
# Cluster 6: 8 diseases
# Cluster 7: 22 diseases
# Cluster 8: 28 diseases
# Cluster 9: 12 diseases
# Cluster 10: 11 diseases
# Cluster 11: 8 diseases
# Cluster 12: 7 diseases
# Cluster 13: 13 diseases
# Cluster 14: 10 diseases
# Cluster 15: 5 diseases
# Cluster 16: 29 diseases
# Cluster 17: 17 diseases
# Cluster 18: 9 diseases
# Cluster 19: 23 diseases
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_91758/1949801412.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_psi = torch.load('initial_psi_400k.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_91758/1949801412.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_clusters = torch.load('initial_clusters_400k.pt')

# %%
print("Initial psi stats:")
print(f"Shape: {initial_psi.shape}")
print(f"Range: [{initial_psi.min():.2f}, {initial_psi.max():.2f}]")
print(f"Number of positive values: {(initial_psi > 0).sum().item()}")
# Out:
# Initial psi stats:
# Shape: torch.Size([20, 348])
# Range: [-2.04, 1.33]
# Number of positive values: 348

# %%
# Load references (signatures only, no healthy)
refs = torch.load('reference_trajectories.pt')
signature_refs = refs['signature_refs']

torch.manual_seed(7)
np.random.seed(4)
# Create model without healthy reference
model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(
    N=Y_100k.shape[0], 
    D=Y_100k.shape[1], 
    T=Y_100k.shape[2], 
    K=20,
    P=G_100k.shape[1],
    G=G_100k, 
    Y=Y_100k,
    genetic_scale=3,
    flat_lambda=True,
    init_var_scaler=1,
    prevalence_t=essentials['prevalence_t'],
   
    healthy_reference=None,  # Explicitly set to None
    disease_names=essentials['disease_names']
)

torch.manual_seed(4)
np.random.seed(4)
# Initialize with psi and clusters
model.initialize_params(true_psi=initial_psi)
model.clusters = initial_clusters
# Verify clusters match
clusters_match = np.array_equal(initial_clusters, model.clusters)
print(f"\nClusters match exactly: {clusters_match}")
# Out:
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_91758/3716884885.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   refs = torch.load('reference_trajectories.pt')
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi_flatlam_healthtoo.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi_flatlam_healthtoo.py:52: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G_scaled, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi_flatlam_healthtoo.py:54: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.Y = torch.tensor(Y, dtype=torch.float32)
# Lambda kernel condition number: 56314924.00
# Phi kernel condition number: 59684776.00
#
# Cluster Sizes:
# Cluster 0: 11 diseases
# Cluster 1: 6 diseases
# Cluster 2: 13 diseases
# Cluster 3: 97 diseases
# Cluster 4: 22 diseases
# Cluster 5: 22 diseases
# Cluster 6: 15 diseases
# Cluster 7: 17 diseases
# Cluster 8: 35 diseases
# Cluster 9: 6 diseases
# Cluster 10: 13 diseases
# Cluster 11: 9 diseases
# Cluster 12: 11 diseases
# Cluster 13: 6 diseases
# Cluster 14: 17 diseases
# Cluster 15: 5 diseases
# Cluster 16: 15 diseases
# Cluster 17: 8 diseases
# Cluster 18: 17 diseases
# Cluster 19: 3 diseases
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-18.4207, -17.1035, -15.7863, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.3847,  0.9324,  2.2496, -0.3847, -0.3847])
# Base value centered mean: 4.0349959817831405e-07
# Gamma init for k=0 (first 5): tensor([ 0.0017,  0.0129, -0.0278, -0.0078,  0.0008])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 6
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1524, -0.1524, -0.1524, -0.1524, -0.1524])
# Base value centered mean: 2.1617888705804944e-06
# Gamma init for k=1 (first 5): tensor([-0.0078, -0.0002, -0.0140,  0.0062,  0.0005])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 13
# Base value (first 5): tensor([-18.4207, -18.4207, -17.3062, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2099, -0.2099,  0.9047, -0.2099, -0.2099])
# Base value centered mean: 1.808452566365304e-06
# Gamma init for k=2 (first 5): tensor([ 0.0058,  0.0004, -0.0085,  0.0127, -0.0053])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 97
# Base value (first 5): tensor([-18.4207, -17.8232, -18.1219, -17.8232, -18.2713])
# Base value centered (first 5): tensor([-0.1558,  0.4416,  0.1429,  0.4416, -0.0065])
# Base value centered mean: -2.099037146763294e-06
# Gamma init for k=3 (first 5): tensor([ 0.0003,  0.0013, -0.0013,  0.0009,  0.0023])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 22
# Base value (first 5): tensor([-18.4207, -17.7621, -15.1278, -17.7621, -18.4207])
# Base value centered (first 5): tensor([-0.3732,  0.2854,  2.9198,  0.2854, -0.3732])
# Base value centered mean: 3.078460792949045e-07
# Gamma init for k=4 (first 5): tensor([ 0.0082,  0.0070,  0.0071, -0.0045, -0.0048])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 22
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1835, -0.1835, -0.1835, -0.1835, -0.1835])
# Base value centered mean: 1.4454841448241496e-06
# Gamma init for k=5 (first 5): tensor([ 0.0128, -0.0085, -0.0167,  0.0006, -0.0008])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 15
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.5667, -0.5667, -0.5667, -0.5667, -0.5667])
# Base value centered mean: -2.4986266566884296e-07
# Gamma init for k=6 (first 5): tensor([-0.0126,  0.0152,  0.0192,  0.0115,  0.0020])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 17
# Base value (first 5): tensor([-18.4207, -17.5684, -17.5684, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2553,  0.5970,  0.5970, -0.2553, -0.2553])
# Base value centered mean: 1.050567675520142e-06
# Gamma init for k=7 (first 5): tensor([ 0.0070,  0.0021, -0.0016, -0.0026,  0.0410])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 35
# Base value (first 5): tensor([-18.0067, -16.7648, -17.5927, -15.9369, -18.4207])
# Base value centered (first 5): tensor([-0.3356,  0.9063,  0.0783,  1.7342, -0.7496])
# Base value centered mean: 1.6441344996565022e-07
# Gamma init for k=8 (first 5): tensor([-0.0037,  0.0009, -0.0141,  0.0259, -0.0076])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 6
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1468, -0.1468, -0.1468, -0.1468, -0.1468])
# Base value centered mean: 2.3044585759635083e-06
# Gamma init for k=9 (first 5): tensor([ 0.0129,  0.0178, -0.0027,  0.0339, -0.0083])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 13
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -17.3062, -18.4207])
# Base value centered (first 5): tensor([-0.3050, -0.3050, -0.3050,  0.8095, -0.3050])
# Base value centered mean: 5.588531593048174e-08
# Gamma init for k=10 (first 5): tensor([-0.0161, -0.0048, -0.0061,  0.0133, -0.0077])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 9
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2331, -0.2331, -0.2331, -0.2331, -0.2331])
# Base value centered mean: 1.1062621751989354e-06
# Gamma init for k=11 (first 5): tensor([-0.0162,  0.0023, -0.0202, -0.0005, -0.0045])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-18.4207, -17.1035, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.3584,  0.9588, -0.3584, -0.3584, -0.3584])
# Base value centered mean: 1.3365745417104336e-06
# Gamma init for k=12 (first 5): tensor([ 0.0035,  0.0122,  0.0018,  0.0084, -0.0224])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 6
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2572, -0.2572, -0.2572, -0.2572, -0.2572])
# Base value centered mean: -6.942749308791463e-08
# Gamma init for k=13 (first 5): tensor([-0.0039,  0.0034,  0.0116, -0.0019,  0.0161])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 17
# Base value (first 5): tensor([-17.5684, -16.7161, -18.4207, -17.5684, -18.4207])
# Base value centered (first 5): tensor([ 0.2530,  1.1052, -0.5993,  0.2530, -0.5993])
# Base value centered mean: 3.859520063542732e-07
# Gamma init for k=14 (first 5): tensor([ 0.0037,  0.0023, -0.0012, -0.0016,  0.0140])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 5
# Base value (first 5): tensor([-18.4207, -18.4207,  -9.7274, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.3996, -0.3996,  8.2937, -0.3996, -0.3996])
# Base value centered mean: 3.6293029097578255e-06
# Gamma init for k=15 (first 5): tensor([-0.0219, -0.0045, -0.0280, -0.0213, -0.0033])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 15
# Base value (first 5): tensor([-18.4207, -18.4207, -16.4888, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2005, -0.2005,  1.7313, -0.2005, -0.2005])
# Base value centered mean: 4.268646307536983e-07
# Gamma init for k=16 (first 5): tensor([-0.0053,  0.0034, -0.0017, -0.0122, -0.0025])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 8
# Base value (first 5): tensor([-18.4207, -16.6096, -12.9874, -16.6096, -18.4207])
# Base value centered (first 5): tensor([-0.9876,  0.8235,  4.4457,  0.8235, -0.9876])
# Base value centered mean: 2.362060513405595e-06
# Gamma init for k=17 (first 5): tensor([ 0.0024,  0.0018, -0.0230, -0.0050, -0.0241])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 17
# Base value (first 5): tensor([-18.4207, -17.5684, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2697,  0.5825, -0.2697, -0.2697, -0.2697])
# Base value centered mean: 1.6757965113356477e-06
# Gamma init for k=18 (first 5): tensor([ 0.0025,  0.0010, -0.0088,  0.0021, -0.0040])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 3
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1937, -0.1937, -0.1937, -0.1937, -0.1937])
# Base value centered mean: 3.179931582053541e-06
# Gamma init for k=19 (first 5): tensor([-0.0138,  0.0087, -0.0050,  0.0135,  0.0098])
# Initializing with 20 disease states only
# Initialization complete!
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 16.0
# Base value (first 5): tensor([-18.4207, -17.5151, -17.5151, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2656,  0.6400,  0.6400, -0.2656, -0.2656])
# Base value centered mean: 6.359100552799646e-07
# Gamma init for k=0 (first 5): tensor([ 0.0075,  0.0025, -0.0024, -0.0024,  0.0416])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 21.0
# Base value (first 5): tensor([-17.7307, -17.7307, -17.7307, -17.7307, -18.4207])
# Base value centered (first 5): tensor([ 0.2193,  0.2193,  0.2193,  0.2193, -0.4706])
# Base value centered mean: 2.13127145798353e-06
# Gamma init for k=1 (first 5): tensor([-2.5005e-06, -2.3957e-03, -2.4260e-02,  2.0265e-02, -7.0649e-03])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 15.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.5667, -0.5667, -0.5667, -0.5667, -0.5667])
# Base value centered mean: -2.4986266566884296e-07
# Gamma init for k=2 (first 5): tensor([-0.0126,  0.0152,  0.0192,  0.0115,  0.0020])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 82.0
# Base value (first 5): tensor([-18.4207, -17.8906, -18.0673, -18.2440, -18.4207])
# Base value centered (first 5): tensor([-0.1526,  0.3775,  0.2008,  0.0241, -0.1526])
# Base value centered mean: 2.290534894200391e-06
# Gamma init for k=3 (first 5): tensor([ 0.0006,  0.0020, -0.0011,  0.0026,  0.0016])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1640, -0.1640, -0.1640, -0.1640, -0.1640])
# Base value centered mean: 9.56726125878049e-07
# Gamma init for k=4 (first 5): tensor([ 0.0170,  0.0167, -0.0036,  0.0401, -0.0092])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-18.4207, -16.3508, -12.2112, -16.3508, -18.4207])
# Base value centered (first 5): tensor([-1.0567,  1.0132,  5.1529,  1.0132, -1.0567])
# Base value centered mean: -1.300811760529541e-07
# Gamma init for k=5 (first 5): tensor([ 5.5867e-05,  7.5741e-04, -2.3455e-02, -6.3306e-03, -2.4462e-02])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2416, -0.2416, -0.2416, -0.2416, -0.2416])
# Base value centered mean: -1.8920898980923084e-07
# Gamma init for k=6 (first 5): tensor([-0.0048, -0.0006,  0.0111, -0.0032,  0.0114])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 22.0
# Base value (first 5): tensor([-18.4207, -15.7863, -17.7621, -14.4692, -18.4207])
# Base value centered (first 5): tensor([-0.8129,  1.8214, -0.1543,  3.1386, -0.8129])
# Base value centered mean: -1.0910034120570344e-07
# Gamma init for k=7 (first 5): tensor([-0.0092,  0.0009, -0.0024,  0.0218, -0.0032])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 28.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1712, -0.1712, -0.1712, -0.1712, -0.1712])
# Base value centered mean: 8.738517749407038e-07
# Gamma init for k=8 (first 5): tensor([ 0.0104, -0.0067, -0.0143,  0.0017, -0.0015])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 12.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -17.2133, -18.4207])
# Base value centered (first 5): tensor([-0.3052, -0.3052, -0.3052,  0.9022, -0.3052])
# Base value centered mean: 8.817672778604901e-07
# Gamma init for k=9 (first 5): tensor([-0.0142, -0.0034, -0.0060,  0.0141, -0.0083])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 11.0
# Base value (first 5): tensor([-18.4207, -17.1035, -15.7863, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.3847,  0.9324,  2.2496, -0.3847, -0.3847])
# Base value centered mean: 4.0349959817831405e-07
# Gamma init for k=10 (first 5): tensor([ 0.0017,  0.0129, -0.0278, -0.0078,  0.0008])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-18.4207, -16.6096, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1592,  1.6519, -0.1592, -0.1592, -0.1592])
# Base value centered mean: 3.319835741422139e-06
# Gamma init for k=11 (first 5): tensor([-0.0057, -0.0003, -0.0138,  0.0043,  0.0013])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1331, -0.1331, -0.1331, -0.1331, -0.1331])
# Base value centered mean: 1.4870643099129666e-06
# Gamma init for k=12 (first 5): tensor([-1.6081e-03,  8.4591e-05, -3.2553e-03, -1.3995e-02, -1.9559e-03])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 13.0
# Base value (first 5): tensor([-18.4207, -17.3062, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2497,  0.8649, -0.2497, -0.2497, -0.2497])
# Base value centered mean: 3.136062559860875e-06
# Gamma init for k=13 (first 5): tensor([-0.0004, -0.0006, -0.0094,  0.0045, -0.0051])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 10.0
# Base value (first 5): tensor([-18.4207, -16.9718, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.3705,  1.0784, -0.3705, -0.3705, -0.3705])
# Base value centered mean: 2.3533821149612777e-06
# Gamma init for k=14 (first 5): tensor([ 0.0067,  0.0169, -0.0005,  0.0079, -0.0234])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-18.4207, -18.4207,  -9.7274, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.3996, -0.3996,  8.2937, -0.3996, -0.3996])
# Base value centered mean: 3.6293029097578255e-06
# Gamma init for k=15 (first 5): tensor([-0.0219, -0.0045, -0.0280, -0.0213, -0.0033])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 29.0
# Base value (first 5): tensor([-18.4207, -18.4207, -14.9234, -17.9211, -18.4207])
# Base value centered (first 5): tensor([-0.3621, -0.3621,  3.1352,  0.1375, -0.3621])
# Base value centered mean: 3.344821834616596e-06
# Gamma init for k=16 (first 5): tensor([ 0.0070,  0.0068,  0.0027, -0.0013, -0.0051])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 17.0
# Base value (first 5): tensor([-17.5684, -16.7161, -18.4207, -17.5684, -18.4207])
# Base value centered (first 5): tensor([ 0.2530,  1.1052, -0.5993,  0.2530, -0.5993])
# Base value centered mean: 3.859520063542732e-07
# Gamma init for k=17 (first 5): tensor([ 0.0037,  0.0023, -0.0012, -0.0016,  0.0140])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 9.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2331, -0.2331, -0.2331, -0.2331, -0.2331])
# Base value centered mean: 1.1062621751989354e-06
# Gamma init for k=18 (first 5): tensor([-0.0162,  0.0023, -0.0202, -0.0005, -0.0045])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 23.0
# Base value (first 5): tensor([-18.4207, -18.4207, -17.7907, -17.1608, -17.7907])
# Base value centered (first 5): tensor([-0.2259, -0.2259,  0.4041,  1.0340,  0.4041])
# Base value centered mean: 1.327228574155015e-06
# Gamma init for k=19 (first 5): tensor([-7.4955e-05,  3.4724e-03,  6.4879e-05, -3.7299e-03,  1.5206e-03])
# Initializing with 20 disease states only
# Initialization complete!
#
# Clusters match exactly: True

# %%
model.genetic_scale
# Out:
# 1

# %%
model.plot_initial_params()
# Convert disease names to list if it's not already
disease_names_list = list(essentials['disease_names'])

# Now visualize clusters
model.visualize_clusters(disease_names=disease_names_list)
# Out:
# Cluster membership for sampled diseases:
# Disease 63: Cluster 16
# Disease 34: Cluster 3
# Disease 146: Cluster 16
# Disease 223: Cluster 3
# Disease 134: Cluster 11
#
# Cluster Assignments:
#
# Cluster 0:
#   - Rheumatic disease of the heart valves (prevalence: 0.0002)
#   - Mitral valve disease (prevalence: 0.0003)
#   - Aortic valve disease (prevalence: 0.0001)
#   - Disease of tricuspid valve (prevalence: 0.0003)
#   - Other forms of chronic heart disease (prevalence: 0.0004)
#   - Cardiomegaly (prevalence: 0.0005)
#   - Pericarditis (prevalence: 0.0001)
#   - Primary/intrinsic cardiomyopathies (prevalence: 0.0001)
#   - Left bundle branch block (prevalence: 0.0003)
#   - Paroxysmal supraventricular tachycardia (prevalence: 0.0002)
#   - Paroxysmal ventricular tachycardia (prevalence: 0.0001)
#   - Atrial fibrillation and flutter (prevalence: 0.0009)
#   - Congestive heart failure (CHF) NOS (prevalence: 0.0003)
#   - Heart failure NOS (prevalence: 0.0007)
#   - Pleurisy; pleural effusion (prevalence: 0.0008)
#   - Congenital anomalies of great vessels (prevalence: 0.0003)
#
# Cluster 1:
#   - Other peripheral nerve disorders (prevalence: 0.0009)
#   - Rheumatoid arthritis (prevalence: 0.0005)
#   - Arthropathy NOS (prevalence: 0.0040)
#   - Peripheral enthesopathies and allied syndromes (prevalence: 0.0005)
#   - Enthesopathy (prevalence: 0.0009)
#   - Other disorders of synovium, tendon, and bursa (prevalence: 0.0001)
#   - Synovitis and tenosynovitis (prevalence: 0.0003)
#   - Acquired toe deformities (prevalence: 0.0002)
#   - Hammer toe (acquired) (prevalence: 0.0002)
#   - Hallux rigidus (prevalence: 0.0001)
#   - Hallux valgus (Bunion) (prevalence: 0.0005)
#   - Other acquired deformities of limbs (prevalence: 0.0002)
#   - Osteoarthritis; localized (prevalence: 0.0010)
#   - Osteoarthrosis, localized, primary (prevalence: 0.0007)
#   - Osteoarthrosis, generalized (prevalence: 0.0006)
#   - Osteoarthrosis NOS (prevalence: 0.0001)
#   - Symptoms and disorders of the joints (prevalence: 0.0001)
#   - Joint effusions (prevalence: 0.0002)
#   - Other derangement of joint (prevalence: 0.0002)
#   - Pain in joint (prevalence: 0.0008)
#   - Internal derangement of knee (prevalence: 0.0011)
#
# Cluster 2:
#   - Benign neoplasm of other parts of digestive system (prevalence: 0.0007)
#   - Iron deficiency anemias, unspecified or not due to blood loss (prevalence: 0.0010)
#   - Esophagitis, GERD and related diseases (prevalence: 0.0008)
#   - Ulcer of esophagus (prevalence: 0.0004)
#   - Barrett's esophagus (prevalence: 0.0003)
#   - Reflux esophagitis (prevalence: 0.0009)
#   - Esophageal bleeding (varices/hemorrhage) (prevalence: 0.0002)
#   - Stricture and stenosis of esophagus (prevalence: 0.0002)
#   - Gastric ulcer (prevalence: 0.0004)
#   - Duodenal ulcer (prevalence: 0.0003)
#   - Gastritis and duodenitis (prevalence: 0.0016)
#   - Duodenitis (prevalence: 0.0007)
#   - Other specified gastritis (prevalence: 0.0009)
#   - Other disorders of stomach and duodenum (prevalence: 0.0003)
#   - Diaphragmatic hernia (prevalence: 0.0025)
#
# Cluster 3:
#   - Bacterial enteritis (prevalence: 0.0002)
#   - Viral Enteritis (prevalence: 0.0001)
#   - Viral infection (prevalence: 0.0004)
#   - Malignant neoplasm of kidney, except pelvis (prevalence: 0.0001)
#   - Neoplasm of uncertain behavior (prevalence: 0.0001)
#   - Non-Hodgkins lymphoma (prevalence: 0.0002)
#   - Benign neoplasm of lip, oral cavity, and pharynx (prevalence: 0.0001)
#   - Lipoma (prevalence: 0.0002)
#   - Lipoma of skin and subcutaneous tissue (prevalence: 0.0004)
#   - Other benign neoplasm of connective and other soft tissue (prevalence: 0.0001)
#   - Hemangioma and lymphangioma, any site (prevalence: 0.0001)
#   - Gout (prevalence: 0.0004)
#   - Bipolar (prevalence: 0.0001)
#   - Alcohol-related disorders (prevalence: 0.0006)
#   - Alcoholic liver damage (prevalence: 0.0001)
#   - Sleep disorders (prevalence: 0.0001)
#   - Parkinson's disease (prevalence: 0.0002)
#   - Multiple sclerosis (prevalence: 0.0001)
#   - Epilepsy, recurrent seizures, convulsions (prevalence: 0.0003)
#   - Facial nerve disorders [CN7] (prevalence: 0.0001)
#   - Inflammatory and toxic neuropathy (prevalence: 0.0002)
#   - Visual disturbances (prevalence: 0.0001)
#   - Inflammation of eyelids (prevalence: 0.0002)
#   - Disorders of conjunctiva (prevalence: 0.0001)
#   - Ptosis of eyelid (prevalence: 0.0002)
#   - Strabismus (not specified as paralytic) (prevalence: 0.0001)
#   - Otitis media (prevalence: 0.0001)
#   - Perforation of tympanic membrane (prevalence: 0.0001)
#   - Hearing loss (prevalence: 0.0005)
#   - Pulmonary heart disease (prevalence: 0.0004)
#   - First degree AV block (prevalence: 0.0002)
#   - Right bundle branch block (prevalence: 0.0002)
#   - Cardiac arrest (prevalence: 0.0001)
#   - Arrhythmia (cardiac) NOS (prevalence: 0.0001)
#   - Abdominal aortic aneurysm (prevalence: 0.0001)
#   - Raynaud's syndrome (prevalence: 0.0001)
#   - Peripheral vascular disease, unspecified (prevalence: 0.0003)
#   - Stricture of artery (prevalence: 0.0001)
#   - Phlebitis and thrombophlebitis of lower extremities (prevalence: 0.0004)
#   - Varicose veins of lower extremity (prevalence: 0.0007)
#   - Acute upper respiratory infections of multiple or unspecified sites (prevalence: 0.0001)
#   - Acute pharyngitis (prevalence: 0.0001)
#   - Diseases of the larynx and vocal cords (prevalence: 0.0001)
#   - Chronic tonsillitis and adenoiditis (prevalence: 0.0001)
#   - Allergic rhinitis (prevalence: 0.0002)
#   - Disturbances in tooth eruption (prevalence: 0.0001)
#   - Dental caries (prevalence: 0.0003)
#   - Periapical abscess (prevalence: 0.0001)
#   - Chronic periodontitis (prevalence: 0.0001)
#   - Other diseases of the teeth and supporting structures (prevalence: 0.0002)
#   - Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue (prevalence: 0.0002)
#   - Diseases and other conditions of the tongue (prevalence: 0.0001)
#   - Acute gastritis (prevalence: 0.0001)
#   - Acute appendicitis (prevalence: 0.0002)
#   - Inguinal hernia (prevalence: 0.0013)
#   - Umbilical hernia (prevalence: 0.0003)
#   - Celiac disease (prevalence: 0.0002)
#   - Functional digestive disorders (prevalence: 0.0001)
#   - Other disorders of liver (prevalence: 0.0003)
#   - Hematemesis (prevalence: 0.0002)
#   - Blood in stool (prevalence: 0.0003)
#   - Cyst of kidney, acquired (prevalence: 0.0002)
#   - Other disorders of testis (prevalence: 0.0001)
#   - Hydrocele (prevalence: 0.0001)
#   - Redundant prepuce and phimosis/BXO (prevalence: 0.0002)
#   - Other disorders of male genital organs (prevalence: 0.0002)
#   - Benign neoplasm of breast (prevalence: 0.0001)
#   - Hypertrophy of breast (Gynecomastia) (prevalence: 0.0001)
#   - Noninflammatory disorders of vulva and perineum (prevalence: 0.0001)
#   - Infertility, female (prevalence: 0.0000)
#   - Carbuncle and furuncle (prevalence: 0.0002)
#   - Psoriasis vulgaris (prevalence: 0.0002)
#   - Ingrowing nail (prevalence: 0.0001)
#   - Sebaceous cyst (prevalence: 0.0006)
#   - Polymyalgia Rheumatica (prevalence: 0.0002)
#   - Bursitis (prevalence: 0.0001)
#   - Ganglion and cyst of synovium, tendon, and bursa (prevalence: 0.0002)
#   - Contracture of palmar fascia [Dupuytren's disease] (prevalence: 0.0003)
#   - Malunion and nonunion of fracture (prevalence: 0.0001)
#   - Osteopenia or other disorder of bone and cartilage (prevalence: 0.0001)
#   - Atopic/contact dermatitis due to other or unspecified (prevalence: 0.0003)
#   - Other tests (prevalence: 0.0003)
#
# Cluster 4:
#   - Septal Deviations/Turbinate Hypertrophy (prevalence: 0.0003)
#   - Nasal polyps (prevalence: 0.0002)
#   - Chronic pharyngitis and nasopharyngitis (prevalence: 0.0001)
#   - Chronic sinusitis (prevalence: 0.0002)
#   - Other upper respiratory disease (prevalence: 0.0003)
#
# Cluster 5:
#   - Hypercholesterolemia (prevalence: 0.0034)
#   - Unstable angina (intermediate coronary syndrome) (prevalence: 0.0004)
#   - Myocardial infarction (prevalence: 0.0012)
#   - Angina pectoris (prevalence: 0.0015)
#   - Coronary atherosclerosis (prevalence: 0.0018)
#   - Other chronic ischemic heart disease, unspecified (prevalence: 0.0015)
#   - Other acute and subacute forms of ischemic heart disease (prevalence: 0.0002)
#
# Cluster 6:
#   - Cancer of bronchus; lung (prevalence: 0.0003)
#   - Malignant neoplasm, other (prevalence: 0.0002)
#   - Secondary malignant neoplasm (prevalence: 0.0002)
#   - Secondary malignancy of lymph nodes (prevalence: 0.0006)
#   - Secondary malignancy of respiratory organs (prevalence: 0.0003)
#   - Secondary malignant neoplasm of digestive systems (prevalence: 0.0002)
#   - Secondary malignant neoplasm of liver (prevalence: 0.0004)
#   - Secondary malignancy of bone (prevalence: 0.0003)
#
# Cluster 7:
#   - Hypothyroidism NOS (prevalence: 0.0014)
#   - Hyperlipidemia (prevalence: 0.0007)
#   - Obesity (prevalence: 0.0018)
#   - Major depressive disorder (prevalence: 0.0014)
#   - Anxiety disorder (prevalence: 0.0010)
#   - Sleep apnea (prevalence: 0.0005)
#   - Migraine (prevalence: 0.0003)
#   - Essential hypertension (prevalence: 0.0073)
#   - Asthma (prevalence: 0.0022)
#   - GERD (prevalence: 0.0020)
#   - Irritable Bowel Syndrome (prevalence: 0.0006)
#   - Other chronic nonalcoholic liver disease (prevalence: 0.0003)
#   - Other inflammatory spondylopathies (prevalence: 0.0001)
#   - Spondylosis and allied disorders (prevalence: 0.0004)
#   - Other disorders of soft tissues (prevalence: 0.0005)
#   - Rheumatism, unspecified and fibrositis (prevalence: 0.0000)
#   - Other disorders of bone and cartilage (prevalence: 0.0004)
#   - Osteoporosis NOS (prevalence: 0.0008)
#   - Cervicalgia (prevalence: 0.0002)
#   - Myalgia and myositis unspecified (prevalence: 0.0002)
#   - Pain in limb (prevalence: 0.0006)
#   - Abdominal pain (prevalence: 0.0008)
#
# Cluster 8:
#   - Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia] (prevalence: 0.0001)
#   - Malignant neoplasm of uterus (prevalence: 0.0001)
#   - Malignant neoplasm of ovary (prevalence: 0.0001)
#   - Uterine leiomyoma (prevalence: 0.0007)
#   - Benign neoplasm of ovary (prevalence: 0.0001)
#   - Pelvic peritoneal adhesions, female (postoperative) (postinfection) (prevalence: 0.0002)
#   - Cervicitis and endocervicitis (prevalence: 0.0001)
#   - Endometriosis (prevalence: 0.0003)
#   - Prolapse of vaginal walls (prevalence: 0.0005)
#   - Uterine/Uterovaginal prolapse (prevalence: 0.0004)
#   - Disorders of uterus, NEC (prevalence: 0.0002)
#   - Noninflammatory disorders of cervix (prevalence: 0.0002)
#   - Noninflammatory disorders of vagina (prevalence: 0.0001)
#   - Endometrial hyperplasia (prevalence: 0.0001)
#   - Polyp of corpus uteri (prevalence: 0.0005)
#   - Mucous polyp of cervix (prevalence: 0.0002)
#   - Hypertrophy of female genital organs (prevalence: 0.0001)
#   - Pain and other symptoms associated with female genital organs (prevalence: 0.0001)
#   - Dyspareunia (prevalence: 0.0001)
#   - Disorders of menstruation and other abnormal bleeding from female genital tract (prevalence: 0.0001)
#   - Irregular menstrual cycle/bleeding (prevalence: 0.0001)
#   - Excessive or frequent menstruation (prevalence: 0.0005)
#   - Irregular menstrual cycle (prevalence: 0.0001)
#   - Irregular menstrual bleeding (prevalence: 0.0002)
#   - Dysmenorrhea (prevalence: 0.0001)
#   - Postmenopausal bleeding (prevalence: 0.0006)
#   - Postmenopausal atrophic vaginitis (prevalence: 0.0001)
#   - Ovarian cyst (prevalence: 0.0004)
#
# Cluster 9:
#   - Degenerative disease of the spinal cord (prevalence: 0.0002)
#   - Spinal stenosis (prevalence: 0.0005)
#   - Spondylosis without myelopathy (prevalence: 0.0007)
#   - Displacement of intervertebral disc (prevalence: 0.0003)
#   - Degeneration of intervertebral disc (prevalence: 0.0004)
#   - Other and unspecified disc disorder (prevalence: 0.0005)
#   - Kyphoscoliosis and scoliosis (prevalence: 0.0002)
#   - Acquired spondylolisthesis (prevalence: 0.0002)
#   - Back pain (prevalence: 0.0012)
#   - Thoracic or lumbosacral neuritis or radiculitis, unspecified (prevalence: 0.0003)
#   - Sciatica (prevalence: 0.0002)
#   - Neuralgia, neuritis, and radiculitis NOS (prevalence: 0.0002)
#
# Cluster 10:
#   - Retinal detachments and defects (prevalence: 0.0002)
#   - Retinal detachment with retinal defect (prevalence: 0.0001)
#   - Other retinal disorders (prevalence: 0.0001)
#   - Macular degeneration (senile) of retina NOS (prevalence: 0.0005)
#   - Retinal vascular changes and abnomalities (prevalence: 0.0001)
#   - Glaucoma (prevalence: 0.0006)
#   - Primary open angle glaucoma (prevalence: 0.0002)
#   - Cataract (prevalence: 0.0019)
#   - Senile cataract (prevalence: 0.0016)
#   - Myopia (prevalence: 0.0002)
#   - Disorders of vitreous body (prevalence: 0.0002)
#
# Cluster 11:
#   - Hemiplegia (prevalence: 0.0002)
#   - Cerebrovascular disease (prevalence: 0.0002)
#   - Occlusion and stenosis of precerebral arteries (prevalence: 0.0001)
#   - Occlusion of cerebral arteries (prevalence: 0.0002)
#   - Cerebral artery occlusion, with cerebral infarction (prevalence: 0.0002)
#   - Cerebral ischemia (prevalence: 0.0003)
#   - Transient cerebral ischemia (prevalence: 0.0002)
#   - Late effects of cerebrovascular disease (prevalence: 0.0002)
#
# Cluster 12:
#   - Other disorders of the kidney and ureters (prevalence: 0.0002)
#   - Stricture/obstruction of ureter (prevalence: 0.0001)
#   - Pyelonephritis (prevalence: 0.0001)
#   - Calculus of kidney (prevalence: 0.0003)
#   - Calculus of ureter (prevalence: 0.0002)
#   - Renal colic (prevalence: 0.0001)
#   - Hydronephrosis (prevalence: 0.0003)
#
# Cluster 13:
#   - Cancer of prostate (prevalence: 0.0008)
#   - Malignant neoplasm of bladder (prevalence: 0.0002)
#   - Cystitis (prevalence: 0.0001)
#   - Chronic cystitis (prevalence: 0.0001)
#   - Other disorders of bladder (prevalence: 0.0007)
#   - Bladder neck obstruction (prevalence: 0.0002)
#   - Functional disorders of bladder (prevalence: 0.0001)
#   - Urethral stricture (not specified as infectious) (prevalence: 0.0003)
#   - Other symptoms/disorders or the urinary system (prevalence: 0.0001)
#   - Urinary incontinence (prevalence: 0.0005)
#   - Hyperplasia of prostate (prevalence: 0.0013)
#   - Chronic prostatitis (prevalence: 0.0001)
#   - Other disorders of prostate (prevalence: 0.0001)
#
# Cluster 14:
#   - Tobacco use disorder (prevalence: 0.0011)
#   - Pneumonia (prevalence: 0.0005)
#   - Pneumococcal pneumonia (prevalence: 0.0008)
#   - Chronic airway obstruction (prevalence: 0.0009)
#   - Emphysema (prevalence: 0.0002)
#   - Obstructive chronic bronchitis (prevalence: 0.0004)
#   - Bronchiectasis (prevalence: 0.0003)
#   - Postinflammatory pulmonary fibrosis (prevalence: 0.0001)
#   - Empyema and pneumothorax (prevalence: 0.0001)
#   - Respiratory failure (prevalence: 0.0004)
#
# Cluster 15:
#   - Type 1 diabetes (prevalence: 0.0002)
#   - Type 2 diabetes (prevalence: 0.0019)
#   - Type 2 diabetes with ophthalmic manifestations (prevalence: 0.0002)
#   - Diabetic retinopathy (prevalence: 0.0002)
#   - Hypoglycemia (prevalence: 0.0002)
#
# Cluster 16:
#   - Gram negative septicemia (prevalence: 0.0002)
#   - Bacterial infection NOS (prevalence: 0.0006)
#   - Staphylococcus infections (prevalence: 0.0003)
#   - Streptococcus infection (prevalence: 0.0002)
#   - E. coli (prevalence: 0.0004)
#   - Candidiasis (prevalence: 0.0003)
#   - Disorders of calcium/phosphorus metabolism (prevalence: 0.0003)
#   - Hyposmolality and/or hyponatremia (prevalence: 0.0005)
#   - Hyperpotassemia (prevalence: 0.0002)
#   - Hypopotassemia (prevalence: 0.0004)
#   - Acidosis (prevalence: 0.0002)
#   - Hypovolemia (prevalence: 0.0005)
#   - Other anemias (prevalence: 0.0013)
#   - Thrombocytopenia (prevalence: 0.0002)
#   - Neutropenia (prevalence: 0.0003)
#   - Orthostatic hypotension (prevalence: 0.0003)
#   - Hypotension NOS (prevalence: 0.0006)
#   - Bacterial pneumonia (prevalence: 0.0001)
#   - Pulmonary collapse; interstitial and compensatory emphysema (prevalence: 0.0004)
#   - Other diseases of respiratory system, NEC (prevalence: 0.0008)
#   - Constipation (prevalence: 0.0015)
#   - Peritonitis and retroperitoneal infections (prevalence: 0.0001)
#   - Acute renal failure (prevalence: 0.0011)
#   - Urinary tract infection (prevalence: 0.0014)
#   - Cellulitis and abscess of arm/hand (prevalence: 0.0006)
#   - Other local infections of skin and subcutaneous tissue (prevalence: 0.0002)
#   - Chronic ulcer of skin (prevalence: 0.0002)
#   - Decubitus ulcer (prevalence: 0.0003)
#   - Sepsis (prevalence: 0.0006)
#
# Cluster 17:
#   - Colon cancer (prevalence: 0.0003)
#   - Malignant neoplasm of rectum, rectosigmoid junction, and anus (prevalence: 0.0002)
#   - Neoplasm of unspecified nature of digestive system (prevalence: 0.0001)
#   - Benign neoplasm of colon (prevalence: 0.0023)
#   - Hemorrhoids (prevalence: 0.0021)
#   - Ventral hernia (prevalence: 0.0003)
#   - Regional enteritis (prevalence: 0.0001)
#   - Ulcerative colitis (prevalence: 0.0002)
#   - Noninfectious gastroenteritis (prevalence: 0.0011)
#   - Other intestinal obstruction (prevalence: 0.0004)
#   - Diverticulosis (prevalence: 0.0030)
#   - Anal and rectal conditions (prevalence: 0.0007)
#   - Anal and rectal polyp (prevalence: 0.0008)
#   - Other disorders of intestine (prevalence: 0.0004)
#   - Gastrointestinal complications (prevalence: 0.0001)
#   - Hemorrhage of rectum and anus (prevalence: 0.0008)
#   - Hemorrhage of gastrointestinal tract (prevalence: 0.0006)
#
# Cluster 18:
#   - Peritoneal adhesions (postoperative) (postinfection) (prevalence: 0.0004)
#   - Cholelithiasis (prevalence: 0.0008)
#   - Cholelithiasis with acute cholecystitis (prevalence: 0.0002)
#   - Cholelithiasis with other cholecystitis (prevalence: 0.0005)
#   - Calculus of bile duct (prevalence: 0.0002)
#   - Cholecystitis without cholelithiasis (prevalence: 0.0002)
#   - Other disorders of gallbladder (prevalence: 0.0002)
#   - Other disorders of biliary tract (prevalence: 0.0001)
#   - Acute pancreatitis (prevalence: 0.0002)
#
# Cluster 19:
#   - Viral warts & HPV (prevalence: 0.0001)
#   - Melanomas of skin (prevalence: 0.0002)
#   - Other non-epithelial cancer of skin (prevalence: 0.0012)
#   - Breast cancer [female] (prevalence: 0.0002)
#   - Malignant neoplasm of female breast (prevalence: 0.0009)
#   - Benign neoplasm of skin (prevalence: 0.0006)
#   - Thyrotoxicosis with or without goiter (prevalence: 0.0001)
#   - Secondary hypothyroidism (prevalence: 0.0001)
#   - Other disorders of eyelids (prevalence: 0.0003)
#   - Ectropion or entropion (prevalence: 0.0001)
#   - Disorders of lacrimal system (prevalence: 0.0002)
#   - Epiphora (prevalence: 0.0001)
#   - Hypertensive chronic kidney disease (prevalence: 0.0001)
#   - Chronic glomerulonephritis, NOS (prevalence: 0.0000)
#   - Renal failure NOS (prevalence: 0.0001)
#   - Chronic renal failure [CKD] (prevalence: 0.0005)
#   - Chronic Kidney Disease, Stage III (prevalence: 0.0006)
#   - Lump or mass in breast (prevalence: 0.0001)
#   - Disorder of skin and subcutaneous tissue NOS (prevalence: 0.0005)
#   - Other hypertrophic and atrophic conditions of skin (prevalence: 0.0002)
#   - Scar conditions and fibrosis of skin (prevalence: 0.0001)
#   - Actinic keratosis (prevalence: 0.0003)
#   - Seborrheic keratosis (prevalence: 0.0003)

# %%
model.visualize_initialization()
# Out:
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi_flatlam_healthtoo.py:841: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
initial_gamma = model.gamma.detach().clone()
initial_phi = model.phi.detach().clone()
initial_lambda = model.lambda_.detach().clone()
initial_psi = model.psi.detach().clone()

# %%
# 1. Get predictions and actual values
predicted = model.forward()
pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
pi_pred = pi_pred.cpu().detach().numpy()
Y = model.Y.cpu().detach().numpy()

# 2. Calculate marginal risks directly
# Assuming dimensions are: [N, D, T] for both Y and pi_pred
observed_risk = Y.mean(axis=0).flatten()  # average across individuals
predicted_risk = pi_pred.mean(axis=0).flatten()

# 3. Apply calibration
scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
calibrated_risk = predicted_risk * scale_factor

# 4. Plot
plt.figure(figsize=(12, 5))

# Original predictions
plt.subplot(121)
plt.scatter(observed_risk, predicted_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Original Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Predicted Risk')

# Calibrated predictions
plt.subplot(122)
plt.scatter(observed_risk, calibrated_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Calibrated Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Calibrated Risk')

plt.tight_layout()
plt.show()

# Print statistics
print(f"Mean observed risk: {np.mean(observed_risk):.6f}")
print(f"Mean predicted risk (original): {np.mean(predicted_risk):.6f}")
print(f"Mean predicted risk (calibrated): {np.mean(calibrated_risk):.6f}")
print(f"Calibration scale factor: {scale_factor:.3f}")
# Out:
# Mean observed risk: 0.000439
# Mean predicted risk (original): 0.000176
# Mean predicted risk (calibrated): 0.000439
# Calibration scale factor: 2.493

# %%
ss_res = np.sum((observed_risk - calibrated_risk) ** 2)
ss_tot = np.sum((observed_risk - np.mean(observed_risk)) ** 2)
r2 = 1 - (ss_res / ss_tot)

print(f"R^2: {r2:.3f}")
# Out:
# R^2: 0.619

# %%
history_new = model.fit(E_100k, num_epochs=100, learning_rate=1e-4, lambda_reg=1e-2)
# Out:
# Starting training...
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi_flatlam_healthtoo.py:232: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   event_times_tensor = torch.tensor(event_times, dtype=torch.long)
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 0
# Loss: 585.3965
# Psi gradient stats:
# Mean: -2.2658e-05
# Std:  4.7114e-03
# Max:  1.6238e-02
# Min:  -1.6248e-02
# Epoch 0, Loss: 585.3965, Gradients - Lambda: 5.350e-03, Phi: 1.284e+01, Gamma: 6.624e-04, Psi: 1.625e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 1
# Loss: 584.5966
# Psi gradient stats:
# Mean: -2.2649e-05
# Std:  4.7113e-03
# Max:  1.6240e-02
# Min:  -1.6249e-02
# Epoch 1, Loss: 584.5966, Gradients - Lambda: 5.082e-03, Phi: 1.284e+01, Gamma: 6.525e-04, Psi: 1.625e-02
#
# Estimated total training time: 59.0 minutes
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 2
# Loss: 576.2389
# Psi gradient stats:
# Mean: -2.2714e-05
# Std:  4.7103e-03
# Max:  1.6242e-02
# Min:  -1.6251e-02
# Epoch 2, Loss: 576.2389, Gradients - Lambda: 3.824e-03, Phi: 1.279e+01, Gamma: 5.415e-04, Psi: 1.625e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 3
# Loss: 560.0959
# Psi gradient stats:
# Mean: -2.2847e-05
# Std:  4.7085e-03
# Max:  1.6254e-02
# Min:  -1.6254e-02
# Epoch 3, Loss: 560.0959, Gradients - Lambda: 5.077e-03, Phi: 1.269e+01, Gamma: 4.350e-04, Psi: 1.625e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 4
# Loss: 537.4276
# Psi gradient stats:
# Mean: -2.3006e-05
# Std:  4.7058e-03
# Max:  1.6267e-02
# Min:  -1.6261e-02
# Epoch 4, Loss: 537.4276, Gradients - Lambda: 5.809e-03, Phi: 1.255e+01, Gamma: 4.538e-04, Psi: 1.627e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 5
# Loss: 509.1030
# Psi gradient stats:
# Mean: -2.3159e-05
# Std:  4.7024e-03
# Max:  1.6280e-02
# Min:  -1.6268e-02
# Epoch 5, Loss: 509.1030, Gradients - Lambda: 6.436e-03, Phi: 1.235e+01, Gamma: 6.755e-04, Psi: 1.628e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 6
# Loss: 476.1169
# Psi gradient stats:
# Mean: -2.3354e-05
# Std:  4.6983e-03
# Max:  1.6294e-02
# Min:  -1.6277e-02
# Epoch 6, Loss: 476.1169, Gradients - Lambda: 6.024e-03, Phi: 1.211e+01, Gamma: 9.275e-04, Psi: 1.629e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 7
# Loss: 440.1911
# Psi gradient stats:
# Mean: -2.3503e-05
# Std:  4.6936e-03
# Max:  1.6301e-02
# Min:  -1.6291e-02
# Epoch 7, Loss: 440.1911, Gradients - Lambda: 5.671e-03, Phi: 1.182e+01, Gamma: 1.221e-03, Psi: 1.630e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 8
# Loss: 402.8326
# Psi gradient stats:
# Mean: -2.3683e-05
# Std:  4.6882e-03
# Max:  1.6305e-02
# Min:  -1.6310e-02
# Epoch 8, Loss: 402.8326, Gradients - Lambda: 6.155e-03, Phi: 1.150e+01, Gamma: 1.516e-03, Psi: 1.631e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 9
# Loss: 365.5821
# Psi gradient stats:
# Mean: -2.3811e-05
# Std:  4.6822e-03
# Max:  1.6307e-02
# Min:  -1.6336e-02
# Epoch 9, Loss: 365.5821, Gradients - Lambda: 6.388e-03, Phi: 1.114e+01, Gamma: 1.825e-03, Psi: 1.634e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 10
# Loss: 329.8860
# Psi gradient stats:
# Mean: -2.3895e-05
# Std:  4.6756e-03
# Max:  1.6298e-02
# Min:  -1.6367e-02
# Epoch 10, Loss: 329.8860, Gradients - Lambda: 6.307e-03, Phi: 1.074e+01, Gamma: 2.106e-03, Psi: 1.637e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 11
# Loss: 299.9480
# Psi gradient stats:
# Mean: -2.3927e-05
# Std:  4.6692e-03
# Max:  1.6291e-02
# Min:  -1.6407e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 12
# Loss: 275.0119
# Psi gradient stats:
# Mean: -2.3925e-05
# Std:  4.6629e-03
# Max:  1.6282e-02
# Min:  -1.6450e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 13
# Loss: 254.3567
# Psi gradient stats:
# Mean: -2.3916e-05
# Std:  4.6568e-03
# Max:  1.6271e-02
# Min:  -1.6495e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 14
# Loss: 237.3258
# Psi gradient stats:
# Mean: -2.3881e-05
# Std:  4.6508e-03
# Max:  1.6260e-02
# Min:  -1.6544e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 15
# Loss: 223.3332
# Psi gradient stats:
# Mean: -2.3834e-05
# Std:  4.6449e-03
# Max:  1.6250e-02
# Min:  -1.6594e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 16
# Loss: 211.8677
# Psi gradient stats:
# Mean: -2.3788e-05
# Std:  4.6390e-03
# Max:  1.6240e-02
# Min:  -1.6644e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 17
# Loss: 202.4881
# Psi gradient stats:
# Mean: -2.3742e-05
# Std:  4.6333e-03
# Max:  1.6230e-02
# Min:  -1.6693e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 18
# Loss: 194.8221
# Psi gradient stats:
# Mean: -2.3679e-05
# Std:  4.6276e-03
# Max:  1.6219e-02
# Min:  -1.6739e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 19
# Loss: 188.5525
# Psi gradient stats:
# Mean: -2.3648e-05
# Std:  4.6219e-03
# Max:  1.6209e-02
# Min:  -1.6782e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 20
# Loss: 183.4155
# Psi gradient stats:
# Mean: -2.3626e-05
# Std:  4.6163e-03
# Max:  1.6198e-02
# Min:  -1.6823e-02
# Epoch 20, Loss: 183.4155, Gradients - Lambda: 3.603e-03, Phi: 7.185e+00, Gamma: 2.410e-03, Psi: 1.682e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 21
# Loss: 179.1897
# Psi gradient stats:
# Mean: -2.3607e-05
# Std:  4.6108e-03
# Max:  1.6187e-02
# Min:  -1.6858e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 22
# Loss: 175.6925
# Psi gradient stats:
# Mean: -2.3612e-05
# Std:  4.6054e-03
# Max:  1.6176e-02
# Min:  -1.6889e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 history_new = model.fit(E_100k, num_epochs=100, learning_rate=1e-4, lambda_reg=1e-2)
#
# File ~/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi_flatlam_healthtoo.py:388, in AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest.fit(self, event_times, num_epochs, learning_rate, lambda_reg, convergence_threshold, patience, warmup_epochs)
#     386 loss_val = loss.item()
#     387 history['loss'].append(loss_val)
# --> 388 loss.backward()
#     391 # Get and track gradients
#     392 grad_lambda = self.lambda_.grad.abs().max().item() if self.lambda_.grad is not None else 0
#
# File /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/autograd/graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
final_lambda = model.lambda_.detach().clone()
diff = torch.abs(final_lambda - initial_lambda)

print(f"Lambda changes with lr=1e-4:")
print(f"Mean absolute change: {torch.mean(diff):.3e}")
print(f"Max absolute change: {torch.max(diff):.3e}")
print(f"Std of changes: {torch.std(diff):.3e}")
# Out:
# Lambda changes with lr=1e-4:
# Mean absolute change: 1.588e-05
# Max absolute change: 7.261e-04
# Std of changes: 1.484e-05

# %%
clusters_match = np.array_equal(initial_clusters, model.clusters)
print(f"\nClusters match exactly: {clusters_match}")
# Out:
# Clusters match exactly: True

# %%
import matplotlib.pyplot as plt

# Create figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Plot loss
ax1.plot(history_new['loss'])
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('Training Loss')
ax1.grid(True)

# Plot gradients
ax2.plot(history_new['max_grad_lambda'], label='Lambda')
ax2.plot(history_new['max_grad_phi'], label='Phi')
ax2.plot(history_new['max_grad_psi'], label='Psi')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Max Gradient Magnitude')
ax2.set_title('Parameter Gradients')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 7
#       4 fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
#       6 # Plot loss
# ----> 7 ax1.plot(history_new['loss'])
#       8 ax1.set_xlabel('Epoch')
#       9 ax1.set_ylabel('Loss')
#
# NameError: name 'history_new' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Convert gamma tensors to numpy arrays
initial_gamma_np = initial_gamma.detach().numpy()
final_gamma_np = model.gamma.detach().numpy()

# Create a figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plot initial gamma
sns.heatmap(initial_gamma_np, ax=ax1, cmap='RdBu_r', center=0)
ax1.set_title('Initial Gamma')

# Plot final gamma
sns.heatmap(final_gamma_np, ax=ax2, cmap='RdBu_r', center=0)
ax2.set_title('Final Gamma')

# Add a title to the figure
plt.suptitle('Comparison of Initial vs Final Gamma Values', fontsize=16)

# You can also add a colorbar
plt.tight_layout()

# To see the actual difference, you can also create a difference heatmap
plt.figure(figsize=(10, 8))
diff = final_gamma_np - initial_gamma_np
sns.heatmap(diff, cmap='RdBu_r', center=0)
plt.title('Difference (Final - Initial Gamma)')
plt.show()

# Print some summary statistics
print(f"Mean absolute difference: {np.abs(diff).mean():.4f}")
print(f"Max absolute difference: {np.abs(diff).max():.4f}")
print(f"Standard deviation of differences: {np.std(diff):.4f}")
# Out:
# Mean absolute difference: 0.0001
# Max absolute difference: 0.0011
# Standard deviation of differences: 0.0001

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Convert phi tensors to numpy arrays
initial_phi_np = initial_phi.detach().numpy()  # Shape: (K, D, T)
final_phi_np = model.phi.detach().numpy()

# Take mean over time dimension
initial_phi_mean = initial_phi_np.mean(axis=2)  # Shape: (K, D)
final_phi_mean = final_phi_np.mean(axis=2)

# Create figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plot initial phi (averaged over time)
sns.heatmap(initial_phi_mean, ax=ax1, cmap='RdBu_r', center=0)
ax1.set_title('Initial Phi (Mean over Time)')
ax1.set_xlabel('Disease')
ax1.set_ylabel('Signature')

# Plot final phi (averaged over time)
sns.heatmap(final_phi_mean, ax=ax2, cmap='RdBu_r', center=0)
ax2.set_title('Final Phi (Mean over Time)')
ax2.set_xlabel('Disease')
ax2.set_ylabel('Signature')

plt.suptitle('Comparison of Initial vs Final Phi Values (Averaged over Time)', fontsize=16)
plt.tight_layout()

# Plot difference
plt.figure(figsize=(10, 8))
diff_mean = final_phi_mean - initial_phi_mean
sns.heatmap(diff_mean, cmap='RdBu_r', center=0)
plt.title('Difference in Phi (Final - Initial), Mean over Time')
plt.xlabel('Disease')
plt.ylabel('Signature')
plt.show()

# Print summary statistics for both full tensor and time-averaged differences
print("Full tensor statistics:")
diff_full = final_phi_np - initial_phi_np
print(f"Mean absolute difference: {np.abs(diff_full).mean():.4f}")
print(f"Max absolute difference: {np.abs(diff_full).max():.4f}")
print(f"Standard deviation of differences: {np.std(diff_full):.4f}")

print("\nTime-averaged statistics:")
print(f"Mean absolute difference: {np.abs(diff_mean).mean():.4f}")
print(f"Max absolute difference: {np.abs(diff_mean).max():.4f}")
print(f"Standard deviation of differences: {np.std(diff_mean):.4f}")

# Optionally, look at temporal variation
temporal_std = np.std(diff_full, axis=2)
plt.figure(figsize=(10, 8))
sns.heatmap(temporal_std, cmap='viridis')
plt.title('Standard Deviation of Changes Across Time')
plt.xlabel('Disease')
plt.ylabel('Signature')
plt.show()
# Out:
# Full tensor statistics:
# Mean absolute difference: 0.0008
# Max absolute difference: 0.0018
# Standard deviation of differences: 0.0010
#
# Time-averaged statistics:
# Mean absolute difference: 0.0001
# Max absolute difference: 0.0004
# Standard deviation of differences: 0.0001

# %%
model_save_path='/Users/sarahurbut/Dropbox (Personal)/model_with_poptrajectory_lr1e-3.pt'
torch.save({
    'model_state_dict': model.state_dict(),
    'clusters': model.clusters,
    'initial_phi': initial_phi, 
    'initial_lambda': initial_lambda, 
    'psi': model.psi,
    'Y': Y_100k,
    'prevalence_t': essentials['prevalence_t'],
    'logit_prevalence_t': model.logit_prev_t,
    'G': G_100k,
    'E': E_100k,
    'indices': indices,
    'disease_names': disease_names,
    'hyperparameters': {
        'N': Y_100k.shape[0],
        'D': Y_100k.shape[1],
        'T': Y_100k.shape[2],
        'P': G_100k.shape[1],
        'K': model.phi.shape[0]
    }
}, model_save_path)

# %%
# 1. Get predictions and actual values
predicted = model.forward()
pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
pi_pred = pi_pred.cpu().detach().numpy()
Y = model.Y.cpu().detach().numpy()

# 2. Calculate marginal risks directly
# Assuming dimensions are: [N, D, T] for both Y and pi_pred
observed_risk = Y.mean(axis=0).flatten()  # average across individuals
predicted_risk = pi_pred.mean(axis=0).flatten()

# 3. Apply calibration
scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
calibrated_risk = predicted_risk * scale_factor

# 4. Plot
plt.figure(figsize=(12, 5))

# Original predictions
plt.subplot(121)
plt.scatter(observed_risk, predicted_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Original Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Predicted Risk')

# Calibrated predictions
plt.subplot(122)
plt.scatter(observed_risk, calibrated_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Calibrated Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Calibrated Risk')

plt.tight_layout()
plt.show()

# Print statistics
print(f"Mean observed risk: {np.mean(observed_risk):.6f}")
print(f"Mean predicted risk (original): {np.mean(predicted_risk):.6f}")
print(f"Mean predicted risk (calibrated): {np.mean(calibrated_risk):.6f}")
print(f"Calibration scale factor: {scale_factor:.3f}")
# Out:
# Mean observed risk: 0.000439
# Mean predicted risk (original): 0.000176
# Mean predicted risk (calibrated): 0.000439
# Calibration scale factor: 2.493

# %%
ss_res = np.sum((observed_risk - calibrated_risk) ** 2)
ss_tot = np.sum((observed_risk - np.mean(observed_risk)) ** 2)
r2 = 1 - (ss_res / ss_tot)

print(f"R^2: {r2:.3f}")
# Out:
# R^2: 0.619

# %%
def plot_signature_top_diseases_centered(model, disease_names, n_top=10):
    """
    Show top diseases for each signature, centered relative to prevalence
    """
    # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # For each signature, get top diseases
    for k in range(phi_avg.shape[0]):
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        print(f"\nTop {n_top} diseases in Signature {k} (relative to baseline):")
        for idx in top_indices:
            avg_effect = scores[idx]
            temporal_std = np.std(phi_centered[k, idx, :])
            # Convert to odds ratio for interpretability
            odds_ratio = np.exp(avg_effect)
            print(f"{disease_names[idx]}: effect={avg_effect:.3f} (OR={odds_ratio:.2f}), std={temporal_std:.3f}")

# Run visualization
plot_signature_top_diseases_centered(model, essentials['disease_names'])
# Out:
# Top 10 diseases in Signature 0 (relative to baseline):
# Mitral valve disease: effect=2.744 (OR=15.54), std=0.378
# Primary/intrinsic cardiomyopathies: effect=2.358 (OR=10.57), std=0.632
# Cardiomegaly: effect=2.133 (OR=8.44), std=0.695
# Heart failure NOS: effect=1.533 (OR=4.63), std=0.504
# Aortic valve disease: effect=1.519 (OR=4.57), std=0.566
# Left bundle branch block: effect=1.445 (OR=4.24), std=0.628
# Rheumatic disease of the heart valves: effect=1.421 (OR=4.14), std=0.579
# Paroxysmal ventricular tachycardia: effect=1.311 (OR=3.71), std=0.445
# Pericarditis: effect=0.923 (OR=2.52), std=0.488
# Paroxysmal supraventricular tachycardia: effect=0.793 (OR=2.21), std=0.463
#
# Top 10 diseases in Signature 1 (relative to baseline):
# Other peripheral nerve disorders: effect=2.378 (OR=10.79), std=0.955
# Hallux rigidus: effect=2.246 (OR=9.45), std=0.935
# Internal derangement of knee: effect=2.199 (OR=9.01), std=0.599
# Peripheral enthesopathies and allied syndromes: effect=2.075 (OR=7.96), std=0.918
# Other acquired deformities of limbs: effect=1.951 (OR=7.04), std=0.375
# Arthropathy NOS: effect=1.855 (OR=6.39), std=1.089
# Enthesopathy: effect=1.748 (OR=5.74), std=0.880
# Synovitis and tenosynovitis: effect=1.660 (OR=5.26), std=0.418
# Acquired toe deformities: effect=1.514 (OR=4.55), std=1.232
# Pain in joint: effect=1.279 (OR=3.59), std=1.078
#
# Top 10 diseases in Signature 2 (relative to baseline):
# Benign neoplasm of other parts of digestive system: effect=1.782 (OR=5.94), std=1.740
# Gastritis and duodenitis: effect=1.776 (OR=5.91), std=0.382
# Barrett's esophagus: effect=1.485 (OR=4.41), std=0.385
# Diaphragmatic hernia: effect=1.456 (OR=4.29), std=0.296
# Iron deficiency anemias, unspecified or not due to blood loss: effect=1.454 (OR=4.28), std=0.624
# Esophagitis, GERD and related diseases: effect=1.454 (OR=4.28), std=0.526
# Other specified gastritis: effect=1.150 (OR=3.16), std=0.392
# Stricture and stenosis of esophagus: effect=1.118 (OR=3.06), std=0.509
# Esophageal bleeding (varices/hemorrhage): effect=0.963 (OR=2.62), std=0.808
# Duodenitis: effect=0.762 (OR=2.14), std=0.205
#
# Top 10 diseases in Signature 3 (relative to baseline):
# Celiac disease: effect=2.803 (OR=16.49), std=1.321
# Sleep disorders: effect=2.640 (OR=14.01), std=0.262
# Cyst of kidney, acquired: effect=2.594 (OR=13.38), std=0.630
# Multiple sclerosis: effect=2.524 (OR=12.47), std=0.267
# Acute gastritis: effect=2.511 (OR=12.32), std=0.293
# Dental caries: effect=2.375 (OR=10.75), std=0.467
# Lipoma: effect=2.331 (OR=10.29), std=0.492
# Viral Enteritis: effect=2.200 (OR=9.02), std=0.205
# Other diseases of the teeth and supporting structures: effect=2.082 (OR=8.02), std=1.116
# Varicose veins of lower extremity: effect=1.930 (OR=6.89), std=0.258
#
# Top 10 diseases in Signature 4 (relative to baseline):
# Other upper respiratory disease: effect=1.406 (OR=4.08), std=0.664
# Septal Deviations/Turbinate Hypertrophy: effect=1.091 (OR=2.98), std=0.504
# Nasal polyps: effect=0.407 (OR=1.50), std=0.317
# Irregular menstrual bleeding: effect=0.389 (OR=1.48), std=0.556
# Chronic sinusitis: effect=0.286 (OR=1.33), std=0.083
# Malignant neoplasm of uterus: effect=0.179 (OR=1.20), std=0.811
# Chronic pharyngitis and nasopharyngitis: effect=0.171 (OR=1.19), std=0.539
# Diseases and other conditions of the tongue: effect=0.160 (OR=1.17), std=0.335
# Other disorders of male genital organs: effect=-0.014 (OR=0.99), std=0.512
# Spondylosis without myelopathy: effect=-0.345 (OR=0.71), std=0.756
#
# Top 10 diseases in Signature 5 (relative to baseline):
# Hypercholesterolemia: effect=1.894 (OR=6.65), std=0.611
# Coronary atherosclerosis: effect=1.400 (OR=4.06), std=0.764
# Myocardial infarction: effect=1.297 (OR=3.66), std=0.086
# Other chronic ischemic heart disease, unspecified: effect=1.139 (OR=3.12), std=0.248
# Hyperlipidemia: effect=0.338 (OR=1.40), std=0.350
# Ptosis of eyelid: effect=0.137 (OR=1.15), std=0.656
# Other acute and subacute forms of ischemic heart disease: effect=0.063 (OR=1.07), std=0.681
# Hearing loss: effect=-0.019 (OR=0.98), std=0.197
# Unstable angina (intermediate coronary syndrome): effect=-0.103 (OR=0.90), std=0.461
# Other disorders of bone and cartilage: effect=-0.297 (OR=0.74), std=0.729
#
# Top 10 diseases in Signature 6 (relative to baseline):
# Secondary malignant neoplasm of digestive systems: effect=2.421 (OR=11.25), std=0.156
# Secondary malignant neoplasm of liver: effect=2.412 (OR=11.15), std=0.637
# Secondary malignancy of lymph nodes: effect=1.767 (OR=5.85), std=0.935
# Malignant neoplasm, other: effect=1.404 (OR=4.07), std=0.454
# Secondary malignancy of respiratory organs: effect=1.353 (OR=3.87), std=0.166
# Cancer of bronchus; lung: effect=1.322 (OR=3.75), std=0.313
# Secondary malignant neoplasm: effect=1.258 (OR=3.52), std=0.424
# Secondary malignancy of bone: effect=1.025 (OR=2.79), std=0.150
# Disorders of lacrimal system: effect=0.640 (OR=1.90), std=0.593
# Endometriosis: effect=0.263 (OR=1.30), std=0.983
#
# Top 10 diseases in Signature 7 (relative to baseline):
# Hyperlipidemia: effect=3.236 (OR=25.43), std=0.465
# Obesity: effect=1.946 (OR=7.00), std=0.360
# Migraine: effect=1.788 (OR=5.98), std=0.222
# Other disorders of bone and cartilage: effect=1.666 (OR=5.29), std=0.774
# Asthma: effect=1.429 (OR=4.18), std=0.459
# Other disorders of soft tissues: effect=1.337 (OR=3.81), std=0.953
# Abdominal pain: effect=1.321 (OR=3.75), std=0.315
# Osteoporosis NOS: effect=0.647 (OR=1.91), std=0.679
# Rheumatism, unspecified and fibrositis: effect=0.641 (OR=1.90), std=0.325
# Spondylosis and allied disorders: effect=0.617 (OR=1.85), std=0.379
#
# Top 10 diseases in Signature 8 (relative to baseline):
# Irregular menstrual cycle: effect=2.030 (OR=7.62), std=0.124
# Ovarian cyst: effect=1.934 (OR=6.92), std=0.348
# Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia]: effect=1.803 (OR=6.07), std=0.473
# Disorders of menstruation and other abnormal bleeding from female genital tract: effect=1.782 (OR=5.94), std=1.194
# Postmenopausal bleeding: effect=1.779 (OR=5.92), std=0.354
# Irregular menstrual cycle/bleeding: effect=1.674 (OR=5.33), std=0.576
# Pelvic peritoneal adhesions, female (postoperative) (postinfection): effect=1.396 (OR=4.04), std=0.439
# Excessive or frequent menstruation: effect=1.382 (OR=3.98), std=0.437
# Malignant neoplasm of ovary: effect=1.380 (OR=3.98), std=0.782
# Malignant neoplasm of uterus: effect=1.293 (OR=3.65), std=0.996
#
# Top 10 diseases in Signature 9 (relative to baseline):
# Spinal stenosis: effect=2.462 (OR=11.73), std=0.874
# Degeneration of intervertebral disc: effect=1.806 (OR=6.08), std=0.938
# Spondylosis without myelopathy: effect=1.763 (OR=5.83), std=0.457
# Thoracic or lumbosacral neuritis or radiculitis, unspecified: effect=1.540 (OR=4.67), std=0.528
# Other and unspecified disc disorder: effect=1.452 (OR=4.27), std=0.673
# Sciatica: effect=1.374 (OR=3.95), std=0.364
# Displacement of intervertebral disc: effect=1.109 (OR=3.03), std=0.587
# Secondary malignant neoplasm of liver: effect=1.013 (OR=2.75), std=0.578
# Degenerative disease of the spinal cord: effect=0.873 (OR=2.39), std=0.152
# Back pain: effect=0.823 (OR=2.28), std=0.659
#
# Top 10 diseases in Signature 10 (relative to baseline):
# Primary open angle glaucoma: effect=2.411 (OR=11.14), std=0.897
# Myopia: effect=1.891 (OR=6.62), std=0.843
# Disorders of vitreous body: effect=1.523 (OR=4.59), std=0.379
# Glaucoma: effect=1.362 (OR=3.90), std=0.141
# Retinal detachment with retinal defect: effect=1.286 (OR=3.62), std=0.389
# Cataract: effect=1.262 (OR=3.53), std=0.180
# Senile cataract: effect=1.249 (OR=3.49), std=0.425
# Macular degeneration (senile) of retina NOS: effect=0.946 (OR=2.57), std=0.770
# Retinal vascular changes and abnomalities: effect=0.925 (OR=2.52), std=0.555
# Bacterial enteritis: effect=0.922 (OR=2.52), std=0.756
#
# Top 10 diseases in Signature 11 (relative to baseline):
# Cerebrovascular disease: effect=1.991 (OR=7.32), std=0.718
# Late effects of cerebrovascular disease: effect=1.776 (OR=5.90), std=0.946
# Cerebral ischemia: effect=1.434 (OR=4.20), std=0.785
# Hemiplegia: effect=1.303 (OR=3.68), std=0.218
# Occlusion and stenosis of precerebral arteries: effect=0.995 (OR=2.70), std=0.380
# Chronic prostatitis: effect=0.532 (OR=1.70), std=0.609
# Occlusion of cerebral arteries: effect=0.457 (OR=1.58), std=0.243
# Other derangement of joint: effect=0.355 (OR=1.43), std=0.542
# Transient cerebral ischemia: effect=0.350 (OR=1.42), std=0.659
# Cerebral artery occlusion, with cerebral infarction: effect=0.087 (OR=1.09), std=0.417
#
# Top 10 diseases in Signature 12 (relative to baseline):
# Hydronephrosis: effect=1.733 (OR=5.66), std=0.760
# Renal colic: effect=1.719 (OR=5.58), std=0.872
# Calculus of ureter: effect=1.233 (OR=3.43), std=0.386
# Other disorders of the kidney and ureters: effect=0.760 (OR=2.14), std=0.553
# Anal and rectal polyp: effect=0.688 (OR=1.99), std=1.034
# Pyelonephritis: effect=0.318 (OR=1.37), std=0.534
# Calculus of kidney: effect=0.107 (OR=1.11), std=0.869
# Seborrheic keratosis: effect=-0.016 (OR=0.98), std=0.371
# Stricture/obstruction of ureter: effect=-0.086 (OR=0.92), std=0.194
# Malunion and nonunion of fracture: effect=-0.127 (OR=0.88), std=0.350
#
# Top 10 diseases in Signature 13 (relative to baseline):
# Other disorders of bladder: effect=1.937 (OR=6.94), std=0.263
# Cystitis: effect=1.744 (OR=5.72), std=0.136
# Chronic cystitis: effect=1.669 (OR=5.31), std=0.836
# Bladder neck obstruction: effect=1.480 (OR=4.39), std=0.418
# Chronic prostatitis: effect=1.384 (OR=3.99), std=0.553
# Cancer of prostate: effect=1.144 (OR=3.14), std=0.856
# Hyperplasia of prostate: effect=0.986 (OR=2.68), std=1.048
# Urinary incontinence: effect=0.785 (OR=2.19), std=0.518
# Other disorders of prostate: effect=0.697 (OR=2.01), std=0.757
# Functional disorders of bladder: effect=0.491 (OR=1.63), std=0.309
#
# Top 10 diseases in Signature 14 (relative to baseline):
# Empyema and pneumothorax: effect=2.200 (OR=9.02), std=0.388
# Postinflammatory pulmonary fibrosis: effect=1.716 (OR=5.56), std=0.332
# Tobacco use disorder: effect=1.193 (OR=3.30), std=0.741
# Pneumonia: effect=0.793 (OR=2.21), std=0.243
# Obstructive chronic bronchitis: effect=0.419 (OR=1.52), std=0.753
# Internal derangement of knee: effect=0.338 (OR=1.40), std=1.069
# Bronchiectasis: effect=0.307 (OR=1.36), std=0.188
# Benign neoplasm of breast: effect=0.175 (OR=1.19), std=0.617
# Septal Deviations/Turbinate Hypertrophy: effect=0.119 (OR=1.13), std=0.287
# Emphysema: effect=0.104 (OR=1.11), std=0.318
#
# Top 10 diseases in Signature 15 (relative to baseline):
# Type 2 diabetes with ophthalmic manifestations: effect=1.635 (OR=5.13), std=0.662
# Type 1 diabetes: effect=1.562 (OR=4.77), std=0.253
# Type 2 diabetes: effect=0.955 (OR=2.60), std=0.873
# Hypoglycemia: effect=0.284 (OR=1.33), std=0.362
# Benign neoplasm of ovary: effect=0.154 (OR=1.17), std=0.505
# Blood in stool: effect=0.011 (OR=1.01), std=0.676
# Visual disturbances: effect=-0.081 (OR=0.92), std=0.675
# Chronic periodontitis: effect=-0.081 (OR=0.92), std=0.609
# Pulmonary collapse; interstitial and compensatory emphysema: effect=-0.086 (OR=0.92), std=0.995
# Congestive heart failure (CHF) NOS: effect=-0.121 (OR=0.89), std=1.044
#
# Top 10 diseases in Signature 16 (relative to baseline):
# Orthostatic hypotension: effect=2.966 (OR=19.42), std=0.747
# Other anemias: effect=2.382 (OR=10.83), std=0.558
# Urinary tract infection: effect=1.975 (OR=7.21), std=0.828
# Thrombocytopenia: effect=1.796 (OR=6.03), std=1.047
# Disorders of calcium/phosphorus metabolism: effect=1.778 (OR=5.92), std=0.235
# Bacterial infection NOS: effect=1.741 (OR=5.70), std=0.531
# Sepsis: effect=1.681 (OR=5.37), std=0.505
# Decubitus ulcer: effect=1.298 (OR=3.66), std=0.357
# Gram negative septicemia: effect=1.265 (OR=3.54), std=0.382
# Hypopotassemia: effect=1.210 (OR=3.35), std=0.813
#
# Top 10 diseases in Signature 17 (relative to baseline):
# Hemorrhage of rectum and anus: effect=2.582 (OR=13.23), std=0.515
# Diverticulosis: effect=2.358 (OR=10.57), std=1.000
# Anal and rectal polyp: effect=2.105 (OR=8.21), std=0.587
# Other disorders of intestine: effect=1.673 (OR=5.33), std=0.086
# Malignant neoplasm of rectum, rectosigmoid junction, and anus: effect=1.603 (OR=4.97), std=0.478
# Anal and rectal conditions: effect=1.039 (OR=2.83), std=0.785
# Other intestinal obstruction: effect=0.736 (OR=2.09), std=0.356
# Noninfectious gastroenteritis: effect=0.731 (OR=2.08), std=0.880
# Gastrointestinal complications: effect=0.624 (OR=1.87), std=0.520
# Ventral hernia: effect=0.546 (OR=1.73), std=0.532
#
# Top 10 diseases in Signature 18 (relative to baseline):
# Cholelithiasis with acute cholecystitis: effect=3.532 (OR=34.20), std=1.290
# Cholelithiasis: effect=2.035 (OR=7.65), std=0.704
# Peritoneal adhesions (postoperative) (postinfection): effect=1.993 (OR=7.34), std=1.063
# Calculus of bile duct: effect=1.293 (OR=3.64), std=0.643
# Other disorders of gallbladder: effect=1.074 (OR=2.93), std=0.692
# Other disorders of biliary tract: effect=1.066 (OR=2.90), std=0.743
# Cholelithiasis with other cholecystitis: effect=0.690 (OR=1.99), std=0.560
# Acute upper respiratory infections of multiple or unspecified sites: effect=0.165 (OR=1.18), std=1.269
# Peripheral vascular disease, unspecified: effect=-0.153 (OR=0.86), std=0.629
# Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia]: effect=-0.298 (OR=0.74), std=0.745
#
# Top 10 diseases in Signature 19 (relative to baseline):
# Seborrheic keratosis: effect=2.730 (OR=15.33), std=1.209
# Actinic keratosis: effect=2.483 (OR=11.98), std=0.686
# Disorder of skin and subcutaneous tissue NOS: effect=2.226 (OR=9.26), std=0.370
# Other disorders of eyelids: effect=1.936 (OR=6.93), std=0.979
# Scar conditions and fibrosis of skin: effect=1.722 (OR=5.59), std=0.120
# Epiphora: effect=1.669 (OR=5.31), std=0.963
# Thyrotoxicosis with or without goiter: effect=1.373 (OR=3.95), std=0.999
# Other non-epithelial cancer of skin: effect=1.344 (OR=3.83), std=0.497
# Ectropion or entropion: effect=1.242 (OR=3.46), std=0.509
# Hypertensive chronic kidney disease: effect=1.221 (OR=3.39), std=0.588

# %%
def compare_disease_rankings(model, disease_names, n_top=10):
    """
    Compare initial vs final disease rankings for each signature
    """
    # Get initial rankings from psi
    psi = model.psi.detach().numpy()  # Shape: (K, D)
    
    # Get final rankings from centered phi
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Compare rankings for each signature
    for k in range(phi_avg.shape[0]):
        print(f"\nSignature {k}:")
        
        # Get initial top diseases from psi
        initial_scores = psi[k, :]
        initial_top = np.argsort(initial_scores)[-n_top:][::-1]
        
        # Get final top diseases from phi
        final_scores = phi_avg[k, :]
        final_top = np.argsort(final_scores)[-n_top:][::-1]
        
        print("\nInitial top diseases:")
        for i, idx in enumerate(initial_top):
            print(f"{i+1}. {disease_names[idx]}: {initial_scores[idx]:.3f}")
            
        print("\nFinal top diseases:")
        for i, idx in enumerate(final_top):
            print(f"{i+1}. {disease_names[idx]}: {final_scores[idx]:.3f}")
            
        # Calculate rank changes
        initial_ranks = {disease: rank for rank, disease in enumerate(initial_top)}
        final_ranks = {disease: rank for rank, disease in enumerate(final_top)}
        
        # Find diseases that changed ranks significantly
        changed_diseases = set(initial_top) | set(final_top)
        for disease in changed_diseases:
            initial_rank = initial_ranks.get(disease, n_top+1)
            final_rank = final_ranks.get(disease, n_top+1)
            if abs(final_rank - initial_rank) > 2:  # Threshold for significant change
                print(f"\n{disease_names[disease]} changed from rank {initial_rank+1} to {final_rank+1}")

# Run comparison
compare_disease_rankings(model, essentials['disease_names'])

# %%
def plot_signature_temporal_patterns(model, disease_names, n_top=10, selected_signatures=None):
    """
    Show temporal patterns of top diseases for each signature
    """
    #phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    #phi_avg = phi.mean(axis=2)  # Average over time

     # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Select which signatures to plot
    if selected_signatures is None:
        selected_signatures = range(phi_avg.shape[0])
    
    # Create subplots for each selected signature
    n_sigs = len(selected_signatures)
    fig, axes = plt.subplots(n_sigs, 1, figsize=(15, 5*n_sigs))
    if n_sigs == 1:
        axes = [axes]
    
    for i, k in enumerate(selected_signatures):
        # Get top diseases
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        # Plot temporal patterns
        ax = axes[i]
        for idx in top_indices:
            temporal_pattern = phi[k, idx, :]
            ax.plot(temporal_pattern, label=disease_names[idx])
        
        ax.set_title(f'Signature {k} - Top Disease Temporal Patterns')
        ax.set_xlabel('Time')
        ax.set_ylabel('Phi Value')
        ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# First show the top diseases


# Then show their temporal patterns
# You can select specific signatures of interest:
disease_names=essentials['disease_names']
plot_signature_temporal_patterns(model, disease_names, selected_signatures=[0,1,14,15,16,13,17])

# %%
Y_avg_global = torch.mean(torch.tensor(Y) if isinstance(Y,np.ndarray) else Y, dim=2)
Y_avg_batch = torch.mean(torch.tensor(Y_100k) if isinstance(Y_100k, np.ndarray) else Y_100k, dim=2)

# %%
def compare_disease_patterns(k, true_psi, Y_avg_global, Y_avg_batch):
    """Compare disease patterns between global and batch data"""
    strong_diseases = (true_psi[k] > 0)
    
    # Get mean pattern for each dataset (average across patients)
    pattern_large = Y_avg_global[:, strong_diseases].mean(dim=0)  # Average across all patients
    pattern_small = Y_avg_batch[:, strong_diseases].mean(dim=0)  # Average across batch patients
    
    # Now both patterns are just length of strong_diseases
    correlation = torch.corrcoef(
        torch.stack([pattern_large, pattern_small])
    )[0,1]
    
    print(f"Signature {k} pattern correlation: {correlation:.3f}")
    print(f"Mean pattern difference: {(pattern_large - pattern_small).abs().mean():.3f}")

# Now use it
print("Comparing disease sharing patterns between global and batch data:")
for k in range(model.K):
    print(f"\nSignature {k}:")
    compare_disease_patterns(k, model.psi, Y_avg_global, Y_avg_batch)

# %%
# Sample patients and set parameters
n_samples = 2
sample_patients = [4376, 6640]  # Use specific patients
n_top_states = 5  # Show only top 5 states per patient

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))
time_points = np.arange(model.T)

# Get dominant states for these patients
lambda_patients = model.lambda_[sample_patients]  # [2, K, T]
patient_props = torch.softmax(lambda_patients, dim=1)  # [2, K, T]
mean_props = patient_props.mean(dim=-1)  # Average over time, now [2, K]
top_states = mean_props.topk(n_top_states, dim=-1).indices  # Get top states for each patient

# Color map for consistent colors across patients
colors = plt.cm.tab20(np.linspace(0, 1, model.K))

# Plot for each patient
for i, patient in enumerate(sample_patients):
    for j, k in enumerate(top_states[i]):
        k = k.item()  # Convert tensor to int
        color = colors[k]
        
        # Plot lambda values
        ax1.plot(time_points, signature_refs[k], '--', color=color, alpha=0.3, 
                label=f'Ref {k}')
        ax1.plot(time_points, model.lambda_[patient, k].detach(), '-', color=color,
                label=f'Patient {patient} - State {k}')
        
        # Plot proportions
        ref_props = torch.softmax(signature_refs, dim=0)[k]
        patient_props = torch.softmax(model.lambda_[patient].detach(), dim=0)[k]
        ax2.plot(time_points, ref_props, '--', color=color, alpha=0.3, 
                label=f'Ref {k}')
        ax2.plot(time_points, patient_props, '-', color=color,
                label=f'Patient {patient} - State {k}')

# Customize plots
ax1.set_title('Final Lambda Values\n(dashed=reference, solid=patient-specific)')
ax1.set_xlabel('Time')
ax1.set_ylabel('Lambda (logit scale)')
ax1.grid(True, alpha=0.3)
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

ax2.set_title('Final Proportions\n(dashed=reference, solid=patient-specific)')
ax2.set_xlabel('Time')
ax2.set_ylabel('Proportion')
ax2.grid(True, alpha=0.3)
ax2.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# Print genetic effects for these patients
print("\nGenetic Effect Statistics for Sample Patients:")
for i, patient in enumerate(sample_patients):
    genetic_effects = model.genetic_scale * (model.G[patient] @ model.gamma).detach()
    print(f"\nPatient {patient}:")
    print(f"Mean shift: {genetic_effects.mean():.3f}")
    print(f"Std of shifts: {genetic_effects.std():.3f}")
    print(f"Range of shifts: [{genetic_effects.min():.3f}, {genetic_effects.max():.3f}]")
    
    # Print top states and their proportions
    patient_mean_props = mean_props[i]  # Already computed above
    top_props, top_indices = patient_mean_props.topk(n_top_states)
    print("\nTop states and average proportions:")
    for state, prop in zip(top_indices, top_props):
        print(f"State {state.item()}: {prop:.3f}")
